# %% [markdown]
# # Binary Classification Model for Homesite Quote Conversion Using Scikit-learn Take 1
# ### David Lowe
# ### June 1, 2020
#
# Template Credit: Adapted from a template made available by Dr. Jason Brownlee of Machine Learning Mastery. [https://machinelearningmastery.com/]
#
# SUMMARY: The purpose of this project is to construct a predictive model using various machine learning algorithms and to document the end-to-end steps using a template. The Homesite Quote Conversion dataset is a binary classification situation where we are trying to predict one of the two possible outcomes.
#
# INTRODUCTION: Homesite, a leading provider of homeowners' insurance, is looking for a dynamic conversion rate model that can give them indications of whether a quoted price will lead to a purchase. By using an anonymized database of information on customer and sales activity, the purpose of the exercise is to predict which customers will purchase a given quote. Accurate prediction of conversion would help Homesite better understand the impact of proposed pricing changes and maintain an ideal portfolio of customer segments. Submissions are evaluated on the area under the ROC curve between the predicted probability and the observed target.
#
# In this Take1 iteration, we will construct and tune several machine learning models using the Scikit-learn library. Furthermore, we will apply the best-performing machine learning model to Kaggle's test dataset and submit a list of predictions for evaluation.
#
# ANALYSIS: In this Take1 iteration, the performance of the machine learning algorithms achieved an average ROC-AUC of 92.02%. Two algorithms (Random Forest and Gradient Boosting) produced the top accuracy metrics after the first round of modeling. After a series of tuning trials, Gradient Boosting turned in a better overall result than Random Forest. Gradient Boosting achieved a ROC-AUC metric of 96.43%. When configured with the optimized parameters, the Gradient Boosting algorithm processed the test dataset with a ROC-AUC of 96.42%. However, when we applied the Gradient Boosting model to the test dataset from Kaggle, we obtained a ROC-AUC score of 96.52%.
#
# CONCLUSION: For this iteration, the Gradient Boosting algorithm achieved the best overall results using the training and test datasets. For this dataset, we should continue to experiment with Gradient Boosting and other algorithms for our modeling effort.
#
# Dataset Used: Homesite Quote Conversion Data Set
#
# Dataset ML Model: Binary classification with numerical and categorical attributes
#
# Dataset Reference: https://www.kaggle.com/c/homesite-quote-conversion/data
#
# One potential source of performance benchmark: https://www.kaggle.com/c/homesite-quote-conversion/leaderboard
#
# Any predictive modeling machine learning project generally can be broken down into about six major tasks:
#
# 1. Prepare Environment
# 2. Summarize Data
# 3. Prepare Data
# 4. Model and Evaluate Algorithms
# 5. Improve Accuracy or Results
# 6. Finalize Model and Present Results

# %% [markdown]
# ## Section 1 - Prepare Environment

# %%
# Retrieve CPU information from the system
ncpu = !nproc
print("The number of available CPUs is:", ncpu[0])
# Out:
# The number of available CPUs is: 4

# %%
# Retrieve GPU configuration information from Colab
# gpu_info = !nvidia-smi
# gpu_info = '\n'.join(gpu_info)
# if gpu_info.find('failed') >= 0:
#     print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
#     print('and then re-execute this cell.')
# else:
#     print(gpu_info)

# %%
# Retrieve memory configuration information from Colab
# from psutil import virtual_memory
# ram_gb = virtual_memory().total / 1e9
# print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

# if ram_gb < 20:
#     print('To enable a high-RAM runtime, select the Runtime → "Change runtime type"')
#     print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
#     print('re-execute this cell.')
# else:
#     print('You are using a high-RAM runtime!')

# %% [markdown]
# ### 1.a) Load libraries and modules

# %%
# Set the random seed number for reproducible results
seedNum = 888

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import sys
import smtplib
from datetime import datetime
from email.message import EmailMessage
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
# from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
# from sklearn.pipeline import Pipeline
# from sklearn.feature_selection import RFE
# from imblearn.over_sampling import SMOTE
# from imblearn.combine import SMOTEENN
# from imblearn.combine import SMOTETomek

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
# from imblearn.ensemble import BalancedRandomForestClassifier
# from imblearn.ensemble import RUSBoostClassifier
# from imblearn.ensemble import BalancedBaggingClassifier
# from xgboost import XGBClassifier

# %% [markdown]
# ### 1.b) Set up the controlling parameters and functions

# %%
# Begin the timer for the script processing
startTimeScript = datetime.now()

# Set up the number of CPU cores available for multi-thread processing
n_jobs = int(ncpu[0])

# Set up the flag to stop sending progress emails (setting to True will send status emails!)
notifyStatus = False

# Set the flag for splitting the dataset
splitDataset = True
splitPercentage = 0.25

# Set the number of folds for cross validation
n_folds = 5

# Set various default modeling parameters
# scoring = 'accuracy'
scoring = 'roc_auc'

# Set Pandas options
pd.set_option("display.max_rows", 500)

# %%
# Set up the email notification function
def email_notify(msg_text):
    sender = os.environ.get('MAIL_SENDER')
    receiver = os.environ.get('MAIL_RECEIVER')
    gateway = os.environ.get('SMTP_GATEWAY')
    smtpuser = os.environ.get('SMTP_USERNAME')
    password = os.environ.get('SMTP_PASSWORD')
    if (sender is None) or (receiver is None) or (gateway is None) or (smtpuser is None) or (password is None):
        sys.exit("Incomplete email setup info. Script Processing Aborted!!!")
    msg = EmailMessage()
    msg.set_content(msg_text)
    msg['Subject'] = 'Notification from Python Binary Classification Script'
    msg['From'] = sender
    msg['To'] = receiver
    server = smtplib.SMTP(gateway, 587)
    server.starttls()
    server.login(smtpuser, password)
    server.send_message(msg)
    server.quit()

# %%
if notifyStatus: email_notify("Library and Data Loading has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 1.c) Load dataset

# %%
dataset_path = 'https://dainesanalytics.com/datasets/kaggle-homesite-quote-conversion/train.csv'
Xy_original = pd.read_csv(dataset_path, sep=',')

# Take a peek at the dataframe after import
Xy_original.head(10)
# Out:
#    QuoteNumber Original_Quote_Date  QuoteConversion_Flag Field6  Field7  \
# 0            1          2013-08-16                     0      B      23
# 1            2          2014-04-22                     0      F       7
# 2            4          2014-08-25                     0      F       7
# 3            6          2013-04-15                     0      J      10
# 4            8          2014-01-25                     0      E      23
# 5           12          2014-01-18                     0      E      14
# 6           13          2013-11-01                     0      J      23
# 7           14          2014-05-14                     0      B      25
# 8           18          2013-06-19                     0      J      10
# 9           19          2013-06-18                     0      F      11
#
#    Field8  Field9 Field10  Field11 Field12  ...  GeographicField59A  \
# 0  0.9403  0.0006     965   1.0200       N  ...                   9
# 1  1.0006  0.0040     548   1.2433       N  ...                  10
# 2  1.0006  0.0040     548   1.2433       N  ...                  15
# 3  0.9769  0.0004   1,165   1.2665       N  ...                   6
# 4  0.9472  0.0006   1,487   1.3045       N  ...                  18
# 5  0.9472  0.0006   1,487   1.3045       N  ...                  10
# 6  0.9258  0.0004   1,165   1.2665       N  ...                  18
# 7  0.9153  0.0007     935   1.0200       N  ...                   6
# 8  0.9691  0.0004   1,165   1.2665       N  ...                   2
# 9  0.9919  0.0038     564   1.1886       N  ...                  10
#
#    GeographicField59B  GeographicField60A  GeographicField60B  \
# 0                   9                  -1                   8
# 1                  10                  -1                  11
# 2                  18                  -1                  21
# 3                   5                  -1                  10
# 4                  22                  -1                  10
# 5                  11                  -1                  23
# 6                  22                  -1                  19
# 7                   5                  -1                   3
# 8                   1                  -1                   3
# 9                  11                  -1                   9
#
#    GeographicField61A  GeographicField61B  GeographicField62A  \
# 0                  -1                  18                  -1
# 1                  -1                  17                  -1
# 2                  -1                  11                  -1
# 3                  -1                   9                  -1
# 4                  -1                  11                  -1
# 5                  -1                  25                  -1
# 6                  -1                  13                  -1
# 7                  -1                  12                  -1
# 8                  -1                   2                  -1
# 9                  -1                  22                  -1
#
#    GeographicField62B  GeographicField63  GeographicField64
# 0                  10                  N                 CA
# 1                  20                  N                 NJ
# 2                   8                  N                 NJ
# 3                  21                  N                 TX
# 4                  12                  N                 IL
# 5                  14                  N                 IL
# 6                   8                  N                 TX
# 7                  13                  N                 CA
# 8                  13                  N                 TX
# 9                  18                  N                 NJ
#
# [10 rows x 299 columns]

# %%
Xy_original.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260753 entries, 0 to 260752
# Data columns (total 299 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   QuoteNumber           int64
#  1   Original_Quote_Date   object
#  2   QuoteConversion_Flag  int64
#  3   Field6                object
#  4   Field7                int64
#  5   Field8                float64
#  6   Field9                float64
#  7   Field10               object
#  8   Field11               float64
#  9   Field12               object
#  10  CoverageField1A       int64
#  11  CoverageField1B       int64
#  12  CoverageField2A       int64
#  13  CoverageField2B       int64
#  14  CoverageField3A       int64
#  15  CoverageField3B       int64
#  16  CoverageField4A       int64
#  17  CoverageField4B       int64
#  18  CoverageField5A       int64
#  19  CoverageField5B       int64
#  20  CoverageField6A       int64
#  21  CoverageField6B       int64
#  22  CoverageField8        object
#  23  CoverageField9        object
#  24  CoverageField11A      int64
#  25  CoverageField11B      int64
#  26  SalesField1A          int64
#  27  SalesField1B          int64
#  28  SalesField2A          int64
#  29  SalesField2B          int64
#  30  SalesField3           int64
#  31  SalesField4           int64
#  32  SalesField5           int64
#  33  SalesField6           int64
#  34  SalesField7           object
#  35  SalesField8           int64
#  36  SalesField9           int64
#  37  SalesField10          int64
#  38  SalesField11          int64
#  39  SalesField12          int64
#  40  SalesField13          int64
#  41  SalesField14          int64
#  42  SalesField15          int64
#  43  PersonalField1        int64
#  44  PersonalField2        int64
#  45  PersonalField4A       int64
#  46  PersonalField4B       int64
#  47  PersonalField5        int64
#  48  PersonalField6        int64
#  49  PersonalField7        object
#  50  PersonalField8        int64
#  51  PersonalField9        int64
#  52  PersonalField10A      int64
#  53  PersonalField10B      int64
#  54  PersonalField11       int64
#  55  PersonalField12       int64
#  56  PersonalField13       int64
#  57  PersonalField14       int64
#  58  PersonalField15       int64
#  59  PersonalField16       object
#  60  PersonalField17       object
#  61  PersonalField18       object
#  62  PersonalField19       object
#  63  PersonalField22       int64
#  64  PersonalField23       int64
#  65  PersonalField24       int64
#  66  PersonalField25       int64
#  67  PersonalField26       int64
#  68  PersonalField27       int64
#  69  PersonalField28       int64
#  70  PersonalField29       int64
#  71  PersonalField30       int64
#  72  PersonalField31       int64
#  73  PersonalField32       int64
#  74  PersonalField33       int64
#  75  PersonalField34       int64
#  76  PersonalField35       int64
#  77  PersonalField36       int64
#  78  PersonalField37       int64
#  79  PersonalField38       int64
#  80  PersonalField39       int64
#  81  PersonalField40       int64
#  82  PersonalField41       int64
#  83  PersonalField42       int64
#  84  PersonalField43       int64
#  85  PersonalField44       int64
#  86  PersonalField45       int64
#  87  PersonalField46       int64
#  88  PersonalField47       int64
#  89  PersonalField48       int64
#  90  PersonalField49       int64
#  91  PersonalField50       int64
#  92  PersonalField51       int64
#  93  PersonalField52       int64
#  94  PersonalField53       int64
#  95  PersonalField54       int64
#  96  PersonalField55       int64
#  97  PersonalField56       int64
#  98  PersonalField57       int64
#  99  PersonalField58       int64
#  100 PersonalField59       int64
#  101 PersonalField60       int64
#  102 PersonalField61       int64
#  103 PersonalField62       int64
#  104 PersonalField63       int64
#  105 PersonalField64       int64
#  106 PersonalField65       int64
#  107 PersonalField66       int64
#  108 PersonalField67       int64
#  109 PersonalField68       int64
#  110 PersonalField69       int64
#  111 PersonalField70       int64
#  112 PersonalField71       int64
#  113 PersonalField72       int64
#  114 PersonalField73       int64
#  115 PersonalField74       int64
#  116 PersonalField75       int64
#  117 PersonalField76       int64
#  118 PersonalField77       int64
#  119 PersonalField78       int64
#  120 PersonalField79       int64
#  121 PersonalField80       int64
#  122 PersonalField81       int64
#  123 PersonalField82       int64
#  124 PersonalField83       int64
#  125 PersonalField84       float64
#  126 PropertyField1A       int64
#  127 PropertyField1B       int64
#  128 PropertyField2A       int64
#  129 PropertyField2B       int64
#  130 PropertyField3        object
#  131 PropertyField4        object
#  132 PropertyField5        object
#  133 PropertyField6        int64
#  134 PropertyField7        object
#  135 PropertyField8        int64
#  136 PropertyField9        int64
#  137 PropertyField10       int64
#  138 PropertyField11A      int64
#  139 PropertyField11B      int64
#  140 PropertyField12       int64
#  141 PropertyField13       int64
#  142 PropertyField14       object
#  143 PropertyField15       int64
#  144 PropertyField16A      int64
#  145 PropertyField16B      int64
#  146 PropertyField17       int64
#  147 PropertyField18       int64
#  148 PropertyField19       int64
#  149 PropertyField20       int64
#  150 PropertyField21A      int64
#  151 PropertyField21B      int64
#  152 PropertyField22       int64
#  153 PropertyField23       int64
#  154 PropertyField24A      int64
#  155 PropertyField24B      int64
#  156 PropertyField25       float64
#  157 PropertyField26A      int64
#  158 PropertyField26B      int64
#  159 PropertyField27       int64
#  160 PropertyField28       object
#  161 PropertyField29       float64
#  162 PropertyField30       object
#  163 PropertyField31       object
#  164 PropertyField32       object
#  165 PropertyField33       object
#  166 PropertyField34       object
#  167 PropertyField35       int64
#  168 PropertyField36       object
#  169 PropertyField37       object
#  170 PropertyField38       object
#  171 PropertyField39A      int64
#  172 PropertyField39B      int64
#  173 GeographicField1A     int64
#  174 GeographicField1B     int64
#  175 GeographicField2A     int64
#  176 GeographicField2B     int64
#  177 GeographicField3A     int64
#  178 GeographicField3B     int64
#  179 GeographicField4A     int64
#  180 GeographicField4B     int64
#  181 GeographicField5A     int64
#  182 GeographicField5B     int64
#  183 GeographicField6A     int64
#  184 GeographicField6B     int64
#  185 GeographicField7A     int64
#  186 GeographicField7B     int64
#  187 GeographicField8A     int64
#  188 GeographicField8B     int64
#  189 GeographicField9A     int64
#  190 GeographicField9B     int64
#  191 GeographicField10A    int64
#  192 GeographicField10B    int64
#  193 GeographicField11A    int64
#  194 GeographicField11B    int64
#  195 GeographicField12A    int64
#  196 GeographicField12B    int64
#  197 GeographicField13A    int64
#  198 GeographicField13B    int64
#  199 GeographicField14A    int64
#  200 GeographicField14B    int64
#  201 GeographicField15A    int64
#  202 GeographicField15B    int64
#  203 GeographicField16A    int64
#  204 GeographicField16B    int64
#  205 GeographicField17A    int64
#  206 GeographicField17B    int64
#  207 GeographicField18A    int64
#  208 GeographicField18B    int64
#  209 GeographicField19A    int64
#  210 GeographicField19B    int64
#  211 GeographicField20A    int64
#  212 GeographicField20B    int64
#  213 GeographicField21A    int64
#  214 GeographicField21B    int64
#  215 GeographicField22A    int64
#  216 GeographicField22B    int64
#  217 GeographicField23A    int64
#  218 GeographicField23B    int64
#  219 GeographicField24A    int64
#  220 GeographicField24B    int64
#  221 GeographicField25A    int64
#  222 GeographicField25B    int64
#  223 GeographicField26A    int64
#  224 GeographicField26B    int64
#  225 GeographicField27A    int64
#  226 GeographicField27B    int64
#  227 GeographicField28A    int64
#  228 GeographicField28B    int64
#  229 GeographicField29A    int64
#  230 GeographicField29B    int64
#  231 GeographicField30A    int64
#  232 GeographicField30B    int64
#  233 GeographicField31A    int64
#  234 GeographicField31B    int64
#  235 GeographicField32A    int64
#  236 GeographicField32B    int64
#  237 GeographicField33A    int64
#  238 GeographicField33B    int64
#  239 GeographicField34A    int64
#  240 GeographicField34B    int64
#  241 GeographicField35A    int64
#  242 GeographicField35B    int64
#  243 GeographicField36A    int64
#  244 GeographicField36B    int64
#  245 GeographicField37A    int64
#  246 GeographicField37B    int64
#  247 GeographicField38A    int64
#  248 GeographicField38B    int64
#  249 GeographicField39A    int64
#  250 GeographicField39B    int64
#  251 GeographicField40A    int64
#  252 GeographicField40B    int64
#  253 GeographicField41A    int64
#  254 GeographicField41B    int64
#  255 GeographicField42A    int64
#  256 GeographicField42B    int64
#  257 GeographicField43A    int64
#  258 GeographicField43B    int64
#  259 GeographicField44A    int64
#  260 GeographicField44B    int64
#  261 GeographicField45A    int64
#  262 GeographicField45B    int64
#  263 GeographicField46A    int64
#  264 GeographicField46B    int64
#  265 GeographicField47A    int64
#  266 GeographicField47B    int64
#  267 GeographicField48A    int64
#  268 GeographicField48B    int64
#  269 GeographicField49A    int64
#  270 GeographicField49B    int64
#  271 GeographicField50A    int64
#  272 GeographicField50B    int64
#  273 GeographicField51A    int64
#  274 GeographicField51B    int64
#  275 GeographicField52A    int64
#  276 GeographicField52B    int64
#  277 GeographicField53A    int64
#  278 GeographicField53B    int64
#  279 GeographicField54A    int64
#  280 GeographicField54B    int64
#  281 GeographicField55A    int64
#  282 GeographicField55B    int64
#  283 GeographicField56A    int64
#  284 GeographicField56B    int64
#  285 GeographicField57A    int64
#  286 GeographicField57B    int64
#  287 GeographicField58A    int64
#  288 GeographicField58B    int64
#  289 GeographicField59A    int64
#  290 GeographicField59B    int64
#  291 GeographicField60A    int64
#  292 GeographicField60B    int64
#  293 GeographicField61A    int64
#  294 GeographicField61B    int64
#  295 GeographicField62A    int64
#  296 GeographicField62B    int64
#  297 GeographicField63     object
#  298 GeographicField64     object
# dtypes: float64(6), int64(265), object(28)
# memory usage: 594.8+ MB

# %%
Xy_original.describe()
# Out:
#          QuoteNumber  QuoteConversion_Flag         Field7         Field8  \
# count  260753.000000         260753.000000  260753.000000  260753.000000
# mean   217201.246011              0.187511      18.293339       0.938346
# std    125478.522633              0.390322       7.382803       0.037086
# min         1.000000              0.000000       1.000000       0.874600
# 25%    108517.000000              0.000000      11.000000       0.915300
# 50%    217012.000000              0.000000      23.000000       0.940300
# 75%    325905.000000              0.000000      24.000000       0.968500
# max    434588.000000              1.000000      28.000000       1.010100
#
#               Field9        Field11  CoverageField1A  CoverageField1B  \
# count  260753.000000  260753.000000    260753.000000    260753.000000
# mean        0.001451       1.162718         9.012533        13.000403
# std         0.001486       0.116833         5.576509         7.219264
# min         0.000400       1.000000        -1.000000        -1.000000
# 25%         0.000600       1.020000         5.000000         7.000000
# 50%         0.000600       1.188600         8.000000        13.000000
# 75%         0.003800       1.266500        12.000000        19.000000
# max         0.004000       1.304500        25.000000        25.000000
#
#        CoverageField2A  CoverageField2B  ...  GeographicField58A  \
# count    260753.000000    260753.000000  ...       260753.000000
# mean          9.054005        13.015240  ...           11.567756
# std           5.560521         7.211717  ...            5.448425
# min           1.000000         1.000000  ...           -1.000000
# 25%           5.000000         7.000000  ...            8.000000
# 50%           8.000000        13.000000  ...           11.000000
# 75%          12.000000        19.000000  ...           15.000000
# max          25.000000        25.000000  ...           25.000000
#
#        GeographicField58B  GeographicField59A  GeographicField59B  \
# count       260753.000000       260753.000000       260753.000000
# mean            12.985695           11.694903           13.049882
# std              7.216091            5.626092            7.213636
# min             -1.000000           -1.000000           -1.000000
# 25%              7.000000            7.000000            7.000000
# 50%             13.000000           11.000000           13.000000
# 75%             19.000000           15.000000           19.000000
# max             25.000000           25.000000           25.000000
#
#        GeographicField60A  GeographicField60B  GeographicField61A  \
# count       260753.000000       260753.000000       260753.000000
# mean            -0.350481           12.994362           -0.343601
# std              4.057792            7.219943            4.078673
# min             -1.000000           -1.000000           -1.000000
# 25%             -1.000000            7.000000           -1.000000
# 50%             -1.000000           13.000000           -1.000000
# 75%             -1.000000           19.000000           -1.000000
# max             25.000000           25.000000           25.000000
#
#        GeographicField61B  GeographicField62A  GeographicField62B
# count       260753.000000       260753.000000       260753.000000
# mean            13.042734           -0.341009           14.122948
# std              7.145248            4.086511            5.829091
# min             -1.000000           -1.000000           -1.000000
# 25%              7.000000           -1.000000            8.000000
# 50%             13.000000           -1.000000           13.000000
# 75%             19.000000           -1.000000           19.000000
# max             25.000000           25.000000           25.000000
#
# [8 rows x 271 columns]

# %%
null_counts = Xy_original.isnull().sum()
null_counts[null_counts > 0]
# Out:
# PersonalField7        113
# PersonalField84    124208
# PropertyField3         81
# PropertyField4         63
# PropertyField29    200685
# PropertyField32        70
# PropertyField34        70
# PropertyField36       113
# PropertyField38      1220
# dtype: int64

# %%
print('Total number of NaN in the dataframe: ', Xy_original.isnull().sum().sum())
# Out:
# Total number of NaN in the dataframe:  326623

# %% [markdown]
# ### 1.d) Data Cleaning

# %%
# Standardize the class column to the name of targetVar if required
Xy_original = Xy_original.rename(columns={'QuoteConversion_Flag': 'targetVar'})

# Dropping features due to lack of prediction value
Xy_original.drop(columns=['QuoteNumber','Original_Quote_Date'], inplace=True)
Xy_original.drop(columns=['PersonalField84','PropertyField29'], inplace=True)
Xy_original.drop(columns=['SalesField8'], inplace=True)

# Impute missing attributes with the "majority" value for each attribute
Xy_original['PersonalField7'].fillna('N', inplace=True)
Xy_original['PropertyField3'].fillna('N', inplace=True)
Xy_original['PropertyField4'].fillna('N', inplace=True)
Xy_original['PropertyField32'].fillna('Y', inplace=True)
Xy_original['PropertyField34'].fillna('Y', inplace=True)
Xy_original['PropertyField36'].fillna('N', inplace=True)
Xy_original['PropertyField38'].fillna('N', inplace=True)

# Correct non-ASCII characters in some attribute columns
Xy_original['GeographicField63'] = Xy_original['GeographicField63'].apply(lambda x: ''.join(["N" if ord(i) < 65 or ord(i) > 90 else i for i in x]))

# Correct mis-coding for some features
Xy_original.loc[(Xy_original.PersonalField16 == 'XN'), 'PersonalField16'] = 'OTHER'
Xy_original.loc[(Xy_original.PersonalField16 == 'XU'), 'PersonalField16'] = 'OTHER'
Xy_original.loc[(Xy_original.PersonalField16 == 'XY'), 'PersonalField16'] = 'OTHER'
Xy_original.loc[(Xy_original.PersonalField16 == 'ZL'), 'PersonalField16'] = 'OTHER'
Xy_original.loc[(Xy_original.PersonalField16 == 'ZO'), 'PersonalField16'] = 'OTHER'
Xy_original.loc[(Xy_original.PersonalField16 == 'ZP'), 'PersonalField16'] = 'OTHER'
Xy_original.loc[(Xy_original.PersonalField16 == 'ZQ'), 'PersonalField16'] = 'OTHER'
Xy_original.loc[(Xy_original.PersonalField16 == 'ZS'), 'PersonalField16'] = 'OTHER'
Xy_original.loc[(Xy_original.PersonalField16 == 'ZV'), 'PersonalField16'] = 'OTHER'
Xy_original.loc[(Xy_original.PersonalField17 == 'XJ'), 'PersonalField17'] = 'OTHER'
Xy_original.loc[(Xy_original.PersonalField17 == 'XO'), 'PersonalField17'] = 'OTHER'
Xy_original.loc[(Xy_original.PersonalField17 == 'XP'), 'PersonalField17'] = 'OTHER'
Xy_original.loc[(Xy_original.PersonalField17 == 'XY'), 'PersonalField17'] = 'OTHER'
Xy_original.loc[(Xy_original.PersonalField17 == 'YP'), 'PersonalField17'] = 'OTHER'
Xy_original.loc[(Xy_original.PersonalField17 == 'ZR'), 'PersonalField17'] = 'OTHER'
Xy_original.loc[(Xy_original.PersonalField18 == 'XH'), 'PersonalField18'] = 'OTHER'
Xy_original.loc[(Xy_original.PersonalField18 == 'XV'), 'PersonalField18'] = 'OTHER'
Xy_original.loc[(Xy_original.PersonalField18 == 'ZG'), 'PersonalField18'] = 'OTHER'
Xy_original.loc[(Xy_original.PersonalField18 == 'ZI'), 'PersonalField18'] = 'OTHER'
Xy_original.loc[(Xy_original.PersonalField19 == 'XL'), 'PersonalField19'] = 'OTHER'
Xy_original.loc[(Xy_original.PersonalField19 == 'YI'), 'PersonalField19'] = 'OTHER'
Xy_original.loc[(Xy_original.PersonalField19 == 'ZC'), 'PersonalField19'] = 'OTHER'
Xy_original.loc[(Xy_original.PropertyField7 == 'B'), 'PropertyField7'] = 'OTHER'

# Convert columns from one data type to another
Xy_original['Field6'] = Xy_original['Field6'].astype('category')
Xy_original['Field10'] = Xy_original['Field10'].str.replace(',','')
Xy_original['Field10'] = Xy_original['Field10'].astype('int')
Xy_original['Field12'] = Xy_original['Field12'].astype('category')
Xy_original['CoverageField8'] = Xy_original['CoverageField8'].astype('category')
Xy_original['CoverageField9'] = Xy_original['CoverageField9'].astype('category')
Xy_original['SalesField7'] = Xy_original['SalesField7'].astype('category')
Xy_original['PersonalField7'] = Xy_original['PersonalField7'].astype('category')
Xy_original['PersonalField16'] = Xy_original['PersonalField16'].astype('category')
Xy_original['PersonalField17'] = Xy_original['PersonalField17'].astype('category')
Xy_original['PersonalField18'] = Xy_original['PersonalField18'].astype('category')
Xy_original['PersonalField19'] = Xy_original['PersonalField19'].astype('category')
Xy_original['PropertyField3'] = Xy_original['PropertyField3'].astype('category')
Xy_original['PropertyField4'] = Xy_original['PropertyField4'].astype('category')
Xy_original['PropertyField5'] = Xy_original['PropertyField5'].astype('category')
Xy_original['PropertyField7'] = Xy_original['PropertyField7'].astype('category')
Xy_original['PropertyField14'] = Xy_original['PropertyField14'].astype('category')
Xy_original['PropertyField28'] = Xy_original['PropertyField28'].astype('category')
Xy_original['PropertyField30'] = Xy_original['PropertyField30'].astype('category')
Xy_original['PropertyField31'] = Xy_original['PropertyField31'].astype('category')
Xy_original['PropertyField32'] = Xy_original['PropertyField32'].astype('category')
Xy_original['PropertyField33'] = Xy_original['PropertyField33'].astype('category')
Xy_original['PropertyField34'] = Xy_original['PropertyField34'].astype('category')
Xy_original['PropertyField36'] = Xy_original['PropertyField36'].astype('category')
Xy_original['PropertyField37'] = Xy_original['PropertyField37'].astype('category')
Xy_original['PropertyField38'] = Xy_original['PropertyField38'].astype('category')
Xy_original['GeographicField63'] = Xy_original['GeographicField63'].astype('category')
Xy_original['GeographicField64'] = Xy_original['GeographicField64'].astype('category')

# Take a peek at the dataframe after cleaning
Xy_original.head(10)
# Out:
#    targetVar Field6  Field7  Field8  Field9  Field10  Field11 Field12  \
# 0          0      B      23  0.9403  0.0006      965   1.0200       N
# 1          0      F       7  1.0006  0.0040      548   1.2433       N
# 2          0      F       7  1.0006  0.0040      548   1.2433       N
# 3          0      J      10  0.9769  0.0004     1165   1.2665       N
# 4          0      E      23  0.9472  0.0006     1487   1.3045       N
# 5          0      E      14  0.9472  0.0006     1487   1.3045       N
# 6          0      J      23  0.9258  0.0004     1165   1.2665       N
# 7          0      B      25  0.9153  0.0007      935   1.0200       N
# 8          0      J      10  0.9691  0.0004     1165   1.2665       N
# 9          0      F      11  0.9919  0.0038      564   1.1886       N
#
#    CoverageField1A  CoverageField1B  ...  GeographicField59A  \
# 0               17               23  ...                   9
# 1                6                8  ...                  10
# 2                7               12  ...                  15
# 3                3                2  ...                   6
# 4                8               13  ...                  18
# 5               13               20  ...                  10
# 6               16               23  ...                  18
# 7                5                8  ...                   6
# 8                5                8  ...                   2
# 9               11               19  ...                  10
#
#    GeographicField59B  GeographicField60A  GeographicField60B  \
# 0                   9                  -1                   8
# 1                  10                  -1                  11
# 2                  18                  -1                  21
# 3                   5                  -1                  10
# 4                  22                  -1                  10
# 5                  11                  -1                  23
# 6                  22                  -1                  19
# 7                   5                  -1                   3
# 8                   1                  -1                   3
# 9                  11                  -1                   9
#
#    GeographicField61A  GeographicField61B  GeographicField62A  \
# 0                  -1                  18                  -1
# 1                  -1                  17                  -1
# 2                  -1                  11                  -1
# 3                  -1                   9                  -1
# 4                  -1                  11                  -1
# 5                  -1                  25                  -1
# 6                  -1                  13                  -1
# 7                  -1                  12                  -1
# 8                  -1                   2                  -1
# 9                  -1                  22                  -1
#
#    GeographicField62B  GeographicField63  GeographicField64
# 0                  10                  N                 CA
# 1                  20                  N                 NJ
# 2                   8                  N                 NJ
# 3                  21                  N                 TX
# 4                  12                  N                 IL
# 5                  14                  N                 IL
# 6                   8                  N                 TX
# 7                  13                  N                 CA
# 8                  13                  N                 TX
# 9                  18                  N                 NJ
#
# [10 rows x 294 columns]

# %%
Xy_original.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260753 entries, 0 to 260752
# Data columns (total 294 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   targetVar           int64
#  1   Field6              category
#  2   Field7              int64
#  3   Field8              float64
#  4   Field9              float64
#  5   Field10             int64
#  6   Field11             float64
#  7   Field12             category
#  8   CoverageField1A     int64
#  9   CoverageField1B     int64
#  10  CoverageField2A     int64
#  11  CoverageField2B     int64
#  12  CoverageField3A     int64
#  13  CoverageField3B     int64
#  14  CoverageField4A     int64
#  15  CoverageField4B     int64
#  16  CoverageField5A     int64
#  17  CoverageField5B     int64
#  18  CoverageField6A     int64
#  19  CoverageField6B     int64
#  20  CoverageField8      category
#  21  CoverageField9      category
#  22  CoverageField11A    int64
#  23  CoverageField11B    int64
#  24  SalesField1A        int64
#  25  SalesField1B        int64
#  26  SalesField2A        int64
#  27  SalesField2B        int64
#  28  SalesField3         int64
#  29  SalesField4         int64
#  30  SalesField5         int64
#  31  SalesField6         int64
#  32  SalesField7         category
#  33  SalesField9         int64
#  34  SalesField10        int64
#  35  SalesField11        int64
#  36  SalesField12        int64
#  37  SalesField13        int64
#  38  SalesField14        int64
#  39  SalesField15        int64
#  40  PersonalField1      int64
#  41  PersonalField2      int64
#  42  PersonalField4A     int64
#  43  PersonalField4B     int64
#  44  PersonalField5      int64
#  45  PersonalField6      int64
#  46  PersonalField7      category
#  47  PersonalField8      int64
#  48  PersonalField9      int64
#  49  PersonalField10A    int64
#  50  PersonalField10B    int64
#  51  PersonalField11     int64
#  52  PersonalField12     int64
#  53  PersonalField13     int64
#  54  PersonalField14     int64
#  55  PersonalField15     int64
#  56  PersonalField16     category
#  57  PersonalField17     category
#  58  PersonalField18     category
#  59  PersonalField19     category
#  60  PersonalField22     int64
#  61  PersonalField23     int64
#  62  PersonalField24     int64
#  63  PersonalField25     int64
#  64  PersonalField26     int64
#  65  PersonalField27     int64
#  66  PersonalField28     int64
#  67  PersonalField29     int64
#  68  PersonalField30     int64
#  69  PersonalField31     int64
#  70  PersonalField32     int64
#  71  PersonalField33     int64
#  72  PersonalField34     int64
#  73  PersonalField35     int64
#  74  PersonalField36     int64
#  75  PersonalField37     int64
#  76  PersonalField38     int64
#  77  PersonalField39     int64
#  78  PersonalField40     int64
#  79  PersonalField41     int64
#  80  PersonalField42     int64
#  81  PersonalField43     int64
#  82  PersonalField44     int64
#  83  PersonalField45     int64
#  84  PersonalField46     int64
#  85  PersonalField47     int64
#  86  PersonalField48     int64
#  87  PersonalField49     int64
#  88  PersonalField50     int64
#  89  PersonalField51     int64
#  90  PersonalField52     int64
#  91  PersonalField53     int64
#  92  PersonalField54     int64
#  93  PersonalField55     int64
#  94  PersonalField56     int64
#  95  PersonalField57     int64
#  96  PersonalField58     int64
#  97  PersonalField59     int64
#  98  PersonalField60     int64
#  99  PersonalField61     int64
#  100 PersonalField62     int64
#  101 PersonalField63     int64
#  102 PersonalField64     int64
#  103 PersonalField65     int64
#  104 PersonalField66     int64
#  105 PersonalField67     int64
#  106 PersonalField68     int64
#  107 PersonalField69     int64
#  108 PersonalField70     int64
#  109 PersonalField71     int64
#  110 PersonalField72     int64
#  111 PersonalField73     int64
#  112 PersonalField74     int64
#  113 PersonalField75     int64
#  114 PersonalField76     int64
#  115 PersonalField77     int64
#  116 PersonalField78     int64
#  117 PersonalField79     int64
#  118 PersonalField80     int64
#  119 PersonalField81     int64
#  120 PersonalField82     int64
#  121 PersonalField83     int64
#  122 PropertyField1A     int64
#  123 PropertyField1B     int64
#  124 PropertyField2A     int64
#  125 PropertyField2B     int64
#  126 PropertyField3      category
#  127 PropertyField4      category
#  128 PropertyField5      category
#  129 PropertyField6      int64
#  130 PropertyField7      category
#  131 PropertyField8      int64
#  132 PropertyField9      int64
#  133 PropertyField10     int64
#  134 PropertyField11A    int64
#  135 PropertyField11B    int64
#  136 PropertyField12     int64
#  137 PropertyField13     int64
#  138 PropertyField14     category
#  139 PropertyField15     int64
#  140 PropertyField16A    int64
#  141 PropertyField16B    int64
#  142 PropertyField17     int64
#  143 PropertyField18     int64
#  144 PropertyField19     int64
#  145 PropertyField20     int64
#  146 PropertyField21A    int64
#  147 PropertyField21B    int64
#  148 PropertyField22     int64
#  149 PropertyField23     int64
#  150 PropertyField24A    int64
#  151 PropertyField24B    int64
#  152 PropertyField25     float64
#  153 PropertyField26A    int64
#  154 PropertyField26B    int64
#  155 PropertyField27     int64
#  156 PropertyField28     category
#  157 PropertyField30     category
#  158 PropertyField31     category
#  159 PropertyField32     category
#  160 PropertyField33     category
#  161 PropertyField34     category
#  162 PropertyField35     int64
#  163 PropertyField36     category
#  164 PropertyField37     category
#  165 PropertyField38     category
#  166 PropertyField39A    int64
#  167 PropertyField39B    int64
#  168 GeographicField1A   int64
#  169 GeographicField1B   int64
#  170 GeographicField2A   int64
#  171 GeographicField2B   int64
#  172 GeographicField3A   int64
#  173 GeographicField3B   int64
#  174 GeographicField4A   int64
#  175 GeographicField4B   int64
#  176 GeographicField5A   int64
#  177 GeographicField5B   int64
#  178 GeographicField6A   int64
#  179 GeographicField6B   int64
#  180 GeographicField7A   int64
#  181 GeographicField7B   int64
#  182 GeographicField8A   int64
#  183 GeographicField8B   int64
#  184 GeographicField9A   int64
#  185 GeographicField9B   int64
#  186 GeographicField10A  int64
#  187 GeographicField10B  int64
#  188 GeographicField11A  int64
#  189 GeographicField11B  int64
#  190 GeographicField12A  int64
#  191 GeographicField12B  int64
#  192 GeographicField13A  int64
#  193 GeographicField13B  int64
#  194 GeographicField14A  int64
#  195 GeographicField14B  int64
#  196 GeographicField15A  int64
#  197 GeographicField15B  int64
#  198 GeographicField16A  int64
#  199 GeographicField16B  int64
#  200 GeographicField17A  int64
#  201 GeographicField17B  int64
#  202 GeographicField18A  int64
#  203 GeographicField18B  int64
#  204 GeographicField19A  int64
#  205 GeographicField19B  int64
#  206 GeographicField20A  int64
#  207 GeographicField20B  int64
#  208 GeographicField21A  int64
#  209 GeographicField21B  int64
#  210 GeographicField22A  int64
#  211 GeographicField22B  int64
#  212 GeographicField23A  int64
#  213 GeographicField23B  int64
#  214 GeographicField24A  int64
#  215 GeographicField24B  int64
#  216 GeographicField25A  int64
#  217 GeographicField25B  int64
#  218 GeographicField26A  int64
#  219 GeographicField26B  int64
#  220 GeographicField27A  int64
#  221 GeographicField27B  int64
#  222 GeographicField28A  int64
#  223 GeographicField28B  int64
#  224 GeographicField29A  int64
#  225 GeographicField29B  int64
#  226 GeographicField30A  int64
#  227 GeographicField30B  int64
#  228 GeographicField31A  int64
#  229 GeographicField31B  int64
#  230 GeographicField32A  int64
#  231 GeographicField32B  int64
#  232 GeographicField33A  int64
#  233 GeographicField33B  int64
#  234 GeographicField34A  int64
#  235 GeographicField34B  int64
#  236 GeographicField35A  int64
#  237 GeographicField35B  int64
#  238 GeographicField36A  int64
#  239 GeographicField36B  int64
#  240 GeographicField37A  int64
#  241 GeographicField37B  int64
#  242 GeographicField38A  int64
#  243 GeographicField38B  int64
#  244 GeographicField39A  int64
#  245 GeographicField39B  int64
#  246 GeographicField40A  int64
#  247 GeographicField40B  int64
#  248 GeographicField41A  int64
#  249 GeographicField41B  int64
#  250 GeographicField42A  int64
#  251 GeographicField42B  int64
#  252 GeographicField43A  int64
#  253 GeographicField43B  int64
#  254 GeographicField44A  int64
#  255 GeographicField44B  int64
#  256 GeographicField45A  int64
#  257 GeographicField45B  int64
#  258 GeographicField46A  int64
#  259 GeographicField46B  int64
#  260 GeographicField47A  int64
#  261 GeographicField47B  int64
#  262 GeographicField48A  int64
#  263 GeographicField48B  int64
#  264 GeographicField49A  int64
#  265 GeographicField49B  int64
#  266 GeographicField50A  int64
#  267 GeographicField50B  int64
#  268 GeographicField51A  int64
#  269 GeographicField51B  int64
#  270 GeographicField52A  int64
#  271 GeographicField52B  int64
#  272 GeographicField53A  int64
#  273 GeographicField53B  int64
#  274 GeographicField54A  int64
#  275 GeographicField54B  int64
#  276 GeographicField55A  int64
#  277 GeographicField55B  int64
#  278 GeographicField56A  int64
#  279 GeographicField56B  int64
#  280 GeographicField57A  int64
#  281 GeographicField57B  int64
#  282 GeographicField58A  int64
#  283 GeographicField58B  int64
#  284 GeographicField59A  int64
#  285 GeographicField59B  int64
#  286 GeographicField60A  int64
#  287 GeographicField60B  int64
#  288 GeographicField61A  int64
#  289 GeographicField61B  int64
#  290 GeographicField62A  int64
#  291 GeographicField62B  int64
#  292 GeographicField63   category
#  293 GeographicField64   category
# dtypes: category(26), float64(4), int64(264)
# memory usage: 539.6 MB

# %%
Xy_original.describe()
# Out:
#            targetVar         Field7         Field8         Field9  \
# count  260753.000000  260753.000000  260753.000000  260753.000000
# mean        0.187511      18.293339       0.938346       0.001451
# std         0.390322       7.382803       0.037086       0.001486
# min         0.000000       1.000000       0.874600       0.000400
# 25%         0.000000      11.000000       0.915300       0.000600
# 50%         0.000000      23.000000       0.940300       0.000600
# 75%         0.000000      24.000000       0.968500       0.003800
# max         1.000000      28.000000       1.010100       0.004000
#
#              Field10        Field11  CoverageField1A  CoverageField1B  \
# count  260753.000000  260753.000000    260753.000000    260753.000000
# mean      954.110829       1.162718         9.012533        13.000403
# std       290.571712       0.116833         5.576509         7.219264
# min       548.000000       1.000000        -1.000000        -1.000000
# 25%       564.000000       1.020000         5.000000         7.000000
# 50%       965.000000       1.188600         8.000000        13.000000
# 75%      1113.000000       1.266500        12.000000        19.000000
# max      1487.000000       1.304500        25.000000        25.000000
#
#        CoverageField2A  CoverageField2B  ...  GeographicField58A  \
# count    260753.000000    260753.000000  ...       260753.000000
# mean          9.054005        13.015240  ...           11.567756
# std           5.560521         7.211717  ...            5.448425
# min           1.000000         1.000000  ...           -1.000000
# 25%           5.000000         7.000000  ...            8.000000
# 50%           8.000000        13.000000  ...           11.000000
# 75%          12.000000        19.000000  ...           15.000000
# max          25.000000        25.000000  ...           25.000000
#
#        GeographicField58B  GeographicField59A  GeographicField59B  \
# count       260753.000000       260753.000000       260753.000000
# mean            12.985695           11.694903           13.049882
# std              7.216091            5.626092            7.213636
# min             -1.000000           -1.000000           -1.000000
# 25%              7.000000            7.000000            7.000000
# 50%             13.000000           11.000000           13.000000
# 75%             19.000000           15.000000           19.000000
# max             25.000000           25.000000           25.000000
#
#        GeographicField60A  GeographicField60B  GeographicField61A  \
# count       260753.000000       260753.000000       260753.000000
# mean            -0.350481           12.994362           -0.343601
# std              4.057792            7.219943            4.078673
# min             -1.000000           -1.000000           -1.000000
# 25%             -1.000000            7.000000           -1.000000
# 50%             -1.000000           13.000000           -1.000000
# 75%             -1.000000           19.000000           -1.000000
# max             25.000000           25.000000           25.000000
#
#        GeographicField61B  GeographicField62A  GeographicField62B
# count       260753.000000       260753.000000       260753.000000
# mean            13.042734           -0.341009           14.122948
# std              7.145248            4.086511            5.829091
# min             -1.000000           -1.000000           -1.000000
# 25%              7.000000           -1.000000            8.000000
# 50%             13.000000           -1.000000           13.000000
# 75%             19.000000           -1.000000           19.000000
# max             25.000000           25.000000           25.000000
#
# [8 rows x 268 columns]

# %%
null_counts = Xy_original.isnull().sum()
null_counts[null_counts > 0]
# Out:
# Series([], dtype: int64)

# %%
print('Total number of NaN in the dataframe: ', Xy_original.isnull().sum().sum())
# Out:
# Total number of NaN in the dataframe:  0

# %% [markdown]
# ### 1.e) Splitting Data into Attribute-only and Target-only Sets

# %%
# Use variable totCol to hold the number of columns in the dataframe
totCol = len(Xy_original.columns)

# Set up variable totAttr for the total number of attribute columns
totAttr = totCol-1

# targetCol variable indicates the column location of the target/class variable
# If the first column, set targetCol to 1. If the last column, set targetCol to totCol
# If (targetCol <> 1) and (targetCol <> totCol), be aware when slicing up the dataframes for visualization
targetCol = 1

# %%
# We create attribute-only and target-only datasets (X_original and y_original)
# for various visualization and cleaning/transformation operations

if targetCol == totCol:
    X_original = Xy_original.iloc[:,0:totAttr]
    y_original = Xy_original.iloc[:,totAttr]
else:
    X_original = Xy_original.iloc[:,1:totCol]
    y_original = Xy_original.iloc[:,0]

print("Xy_original.shape: {} X_original.shape: {} y_original.shape: {}".format(Xy_original.shape, X_original.shape, y_original.shape))
# Out:
# Xy_original.shape: (260753, 294) X_original.shape: (260753, 293) y_original.shape: (260753,)

# %% [markdown]
# ### 1.f) Set up the parameters for data visualization

# %%
# Set up the number of row and columns for visualization display. dispRow * dispCol should be >= totAttr
dispCol = 4
if totAttr % dispCol == 0 :
    dispRow = totAttr // dispCol
else :
    dispRow = (totAttr // dispCol) + 1
    
# Set figure width to display the data visualization plots
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = dispCol*4
fig_size[1] = dispRow*4
plt.rcParams["figure.figsize"] = fig_size

# %%
if notifyStatus: email_notify("Library and Data Loading completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 2 - Summarize Data

# %%
if notifyStatus: email_notify("Data Summarization and Visualization has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 2.a) Descriptive Statistics

# %% [markdown]
# #### 2.a.i) Peek at the attribute columns

# %%
X_original.head(10)
# Out:
#   Field6  Field7  Field8  Field9  Field10  Field11 Field12  CoverageField1A  \
# 0      B      23  0.9403  0.0006      965   1.0200       N               17
# 1      F       7  1.0006  0.0040      548   1.2433       N                6
# 2      F       7  1.0006  0.0040      548   1.2433       N                7
# 3      J      10  0.9769  0.0004     1165   1.2665       N                3
# 4      E      23  0.9472  0.0006     1487   1.3045       N                8
# 5      E      14  0.9472  0.0006     1487   1.3045       N               13
# 6      J      23  0.9258  0.0004     1165   1.2665       N               16
# 7      B      25  0.9153  0.0007      935   1.0200       N                5
# 8      J      10  0.9691  0.0004     1165   1.2665       N                5
# 9      F      11  0.9919  0.0038      564   1.1886       N               11
#
#    CoverageField1B  CoverageField2A  ...  GeographicField59A  \
# 0               23               17  ...                   9
# 1                8                6  ...                  10
# 2               12                7  ...                  15
# 3                2                3  ...                   6
# 4               13                8  ...                  18
# 5               20               13  ...                  10
# 6               23               17  ...                  18
# 7                8                5  ...                   6
# 8                8                6  ...                   2
# 9               19               11  ...                  10
#
#    GeographicField59B  GeographicField60A  GeographicField60B  \
# 0                   9                  -1                   8
# 1                  10                  -1                  11
# 2                  18                  -1                  21
# 3                   5                  -1                  10
# 4                  22                  -1                  10
# 5                  11                  -1                  23
# 6                  22                  -1                  19
# 7                   5                  -1                   3
# 8                   1                  -1                   3
# 9                  11                  -1                   9
#
#    GeographicField61A  GeographicField61B  GeographicField62A  \
# 0                  -1                  18                  -1
# 1                  -1                  17                  -1
# 2                  -1                  11                  -1
# 3                  -1                   9                  -1
# 4                  -1                  11                  -1
# 5                  -1                  25                  -1
# 6                  -1                  13                  -1
# 7                  -1                  12                  -1
# 8                  -1                   2                  -1
# 9                  -1                  22                  -1
#
#    GeographicField62B  GeographicField63 GeographicField64
# 0                  10                  N                CA
# 1                  20                  N                NJ
# 2                   8                  N                NJ
# 3                  21                  N                TX
# 4                  12                  N                IL
# 5                  14                  N                IL
# 6                   8                  N                TX
# 7                  13                  N                CA
# 8                  13                  N                TX
# 9                  18                  N                NJ
#
# [10 rows x 293 columns]

# %% [markdown]
# #### 2.a.ii) Dimensions and attribute types

# %%
X_original.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260753 entries, 0 to 260752
# Data columns (total 293 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Field6              category
#  1   Field7              int64
#  2   Field8              float64
#  3   Field9              float64
#  4   Field10             int64
#  5   Field11             float64
#  6   Field12             category
#  7   CoverageField1A     int64
#  8   CoverageField1B     int64
#  9   CoverageField2A     int64
#  10  CoverageField2B     int64
#  11  CoverageField3A     int64
#  12  CoverageField3B     int64
#  13  CoverageField4A     int64
#  14  CoverageField4B     int64
#  15  CoverageField5A     int64
#  16  CoverageField5B     int64
#  17  CoverageField6A     int64
#  18  CoverageField6B     int64
#  19  CoverageField8      category
#  20  CoverageField9      category
#  21  CoverageField11A    int64
#  22  CoverageField11B    int64
#  23  SalesField1A        int64
#  24  SalesField1B        int64
#  25  SalesField2A        int64
#  26  SalesField2B        int64
#  27  SalesField3         int64
#  28  SalesField4         int64
#  29  SalesField5         int64
#  30  SalesField6         int64
#  31  SalesField7         category
#  32  SalesField9         int64
#  33  SalesField10        int64
#  34  SalesField11        int64
#  35  SalesField12        int64
#  36  SalesField13        int64
#  37  SalesField14        int64
#  38  SalesField15        int64
#  39  PersonalField1      int64
#  40  PersonalField2      int64
#  41  PersonalField4A     int64
#  42  PersonalField4B     int64
#  43  PersonalField5      int64
#  44  PersonalField6      int64
#  45  PersonalField7      category
#  46  PersonalField8      int64
#  47  PersonalField9      int64
#  48  PersonalField10A    int64
#  49  PersonalField10B    int64
#  50  PersonalField11     int64
#  51  PersonalField12     int64
#  52  PersonalField13     int64
#  53  PersonalField14     int64
#  54  PersonalField15     int64
#  55  PersonalField16     category
#  56  PersonalField17     category
#  57  PersonalField18     category
#  58  PersonalField19     category
#  59  PersonalField22     int64
#  60  PersonalField23     int64
#  61  PersonalField24     int64
#  62  PersonalField25     int64
#  63  PersonalField26     int64
#  64  PersonalField27     int64
#  65  PersonalField28     int64
#  66  PersonalField29     int64
#  67  PersonalField30     int64
#  68  PersonalField31     int64
#  69  PersonalField32     int64
#  70  PersonalField33     int64
#  71  PersonalField34     int64
#  72  PersonalField35     int64
#  73  PersonalField36     int64
#  74  PersonalField37     int64
#  75  PersonalField38     int64
#  76  PersonalField39     int64
#  77  PersonalField40     int64
#  78  PersonalField41     int64
#  79  PersonalField42     int64
#  80  PersonalField43     int64
#  81  PersonalField44     int64
#  82  PersonalField45     int64
#  83  PersonalField46     int64
#  84  PersonalField47     int64
#  85  PersonalField48     int64
#  86  PersonalField49     int64
#  87  PersonalField50     int64
#  88  PersonalField51     int64
#  89  PersonalField52     int64
#  90  PersonalField53     int64
#  91  PersonalField54     int64
#  92  PersonalField55     int64
#  93  PersonalField56     int64
#  94  PersonalField57     int64
#  95  PersonalField58     int64
#  96  PersonalField59     int64
#  97  PersonalField60     int64
#  98  PersonalField61     int64
#  99  PersonalField62     int64
#  100 PersonalField63     int64
#  101 PersonalField64     int64
#  102 PersonalField65     int64
#  103 PersonalField66     int64
#  104 PersonalField67     int64
#  105 PersonalField68     int64
#  106 PersonalField69     int64
#  107 PersonalField70     int64
#  108 PersonalField71     int64
#  109 PersonalField72     int64
#  110 PersonalField73     int64
#  111 PersonalField74     int64
#  112 PersonalField75     int64
#  113 PersonalField76     int64
#  114 PersonalField77     int64
#  115 PersonalField78     int64
#  116 PersonalField79     int64
#  117 PersonalField80     int64
#  118 PersonalField81     int64
#  119 PersonalField82     int64
#  120 PersonalField83     int64
#  121 PropertyField1A     int64
#  122 PropertyField1B     int64
#  123 PropertyField2A     int64
#  124 PropertyField2B     int64
#  125 PropertyField3      category
#  126 PropertyField4      category
#  127 PropertyField5      category
#  128 PropertyField6      int64
#  129 PropertyField7      category
#  130 PropertyField8      int64
#  131 PropertyField9      int64
#  132 PropertyField10     int64
#  133 PropertyField11A    int64
#  134 PropertyField11B    int64
#  135 PropertyField12     int64
#  136 PropertyField13     int64
#  137 PropertyField14     category
#  138 PropertyField15     int64
#  139 PropertyField16A    int64
#  140 PropertyField16B    int64
#  141 PropertyField17     int64
#  142 PropertyField18     int64
#  143 PropertyField19     int64
#  144 PropertyField20     int64
#  145 PropertyField21A    int64
#  146 PropertyField21B    int64
#  147 PropertyField22     int64
#  148 PropertyField23     int64
#  149 PropertyField24A    int64
#  150 PropertyField24B    int64
#  151 PropertyField25     float64
#  152 PropertyField26A    int64
#  153 PropertyField26B    int64
#  154 PropertyField27     int64
#  155 PropertyField28     category
#  156 PropertyField30     category
#  157 PropertyField31     category
#  158 PropertyField32     category
#  159 PropertyField33     category
#  160 PropertyField34     category
#  161 PropertyField35     int64
#  162 PropertyField36     category
#  163 PropertyField37     category
#  164 PropertyField38     category
#  165 PropertyField39A    int64
#  166 PropertyField39B    int64
#  167 GeographicField1A   int64
#  168 GeographicField1B   int64
#  169 GeographicField2A   int64
#  170 GeographicField2B   int64
#  171 GeographicField3A   int64
#  172 GeographicField3B   int64
#  173 GeographicField4A   int64
#  174 GeographicField4B   int64
#  175 GeographicField5A   int64
#  176 GeographicField5B   int64
#  177 GeographicField6A   int64
#  178 GeographicField6B   int64
#  179 GeographicField7A   int64
#  180 GeographicField7B   int64
#  181 GeographicField8A   int64
#  182 GeographicField8B   int64
#  183 GeographicField9A   int64
#  184 GeographicField9B   int64
#  185 GeographicField10A  int64
#  186 GeographicField10B  int64
#  187 GeographicField11A  int64
#  188 GeographicField11B  int64
#  189 GeographicField12A  int64
#  190 GeographicField12B  int64
#  191 GeographicField13A  int64
#  192 GeographicField13B  int64
#  193 GeographicField14A  int64
#  194 GeographicField14B  int64
#  195 GeographicField15A  int64
#  196 GeographicField15B  int64
#  197 GeographicField16A  int64
#  198 GeographicField16B  int64
#  199 GeographicField17A  int64
#  200 GeographicField17B  int64
#  201 GeographicField18A  int64
#  202 GeographicField18B  int64
#  203 GeographicField19A  int64
#  204 GeographicField19B  int64
#  205 GeographicField20A  int64
#  206 GeographicField20B  int64
#  207 GeographicField21A  int64
#  208 GeographicField21B  int64
#  209 GeographicField22A  int64
#  210 GeographicField22B  int64
#  211 GeographicField23A  int64
#  212 GeographicField23B  int64
#  213 GeographicField24A  int64
#  214 GeographicField24B  int64
#  215 GeographicField25A  int64
#  216 GeographicField25B  int64
#  217 GeographicField26A  int64
#  218 GeographicField26B  int64
#  219 GeographicField27A  int64
#  220 GeographicField27B  int64
#  221 GeographicField28A  int64
#  222 GeographicField28B  int64
#  223 GeographicField29A  int64
#  224 GeographicField29B  int64
#  225 GeographicField30A  int64
#  226 GeographicField30B  int64
#  227 GeographicField31A  int64
#  228 GeographicField31B  int64
#  229 GeographicField32A  int64
#  230 GeographicField32B  int64
#  231 GeographicField33A  int64
#  232 GeographicField33B  int64
#  233 GeographicField34A  int64
#  234 GeographicField34B  int64
#  235 GeographicField35A  int64
#  236 GeographicField35B  int64
#  237 GeographicField36A  int64
#  238 GeographicField36B  int64
#  239 GeographicField37A  int64
#  240 GeographicField37B  int64
#  241 GeographicField38A  int64
#  242 GeographicField38B  int64
#  243 GeographicField39A  int64
#  244 GeographicField39B  int64
#  245 GeographicField40A  int64
#  246 GeographicField40B  int64
#  247 GeographicField41A  int64
#  248 GeographicField41B  int64
#  249 GeographicField42A  int64
#  250 GeographicField42B  int64
#  251 GeographicField43A  int64
#  252 GeographicField43B  int64
#  253 GeographicField44A  int64
#  254 GeographicField44B  int64
#  255 GeographicField45A  int64
#  256 GeographicField45B  int64
#  257 GeographicField46A  int64
#  258 GeographicField46B  int64
#  259 GeographicField47A  int64
#  260 GeographicField47B  int64
#  261 GeographicField48A  int64
#  262 GeographicField48B  int64
#  263 GeographicField49A  int64
#  264 GeographicField49B  int64
#  265 GeographicField50A  int64
#  266 GeographicField50B  int64
#  267 GeographicField51A  int64
#  268 GeographicField51B  int64
#  269 GeographicField52A  int64
#  270 GeographicField52B  int64
#  271 GeographicField53A  int64
#  272 GeographicField53B  int64
#  273 GeographicField54A  int64
#  274 GeographicField54B  int64
#  275 GeographicField55A  int64
#  276 GeographicField55B  int64
#  277 GeographicField56A  int64
#  278 GeographicField56B  int64
#  279 GeographicField57A  int64
#  280 GeographicField57B  int64
#  281 GeographicField58A  int64
#  282 GeographicField58B  int64
#  283 GeographicField59A  int64
#  284 GeographicField59B  int64
#  285 GeographicField60A  int64
#  286 GeographicField60B  int64
#  287 GeographicField61A  int64
#  288 GeographicField61B  int64
#  289 GeographicField62A  int64
#  290 GeographicField62B  int64
#  291 GeographicField63   category
#  292 GeographicField64   category
# dtypes: category(26), float64(4), int64(263)
# memory usage: 537.6 MB

# %% [markdown]
# #### 2.a.iii) Statistical summary of the attributes

# %%
X_original.describe()
# Out:
#               Field7         Field8         Field9        Field10  \
# count  260753.000000  260753.000000  260753.000000  260753.000000
# mean       18.293339       0.938346       0.001451     954.110829
# std         7.382803       0.037086       0.001486     290.571712
# min         1.000000       0.874600       0.000400     548.000000
# 25%        11.000000       0.915300       0.000600     564.000000
# 50%        23.000000       0.940300       0.000600     965.000000
# 75%        24.000000       0.968500       0.003800    1113.000000
# max        28.000000       1.010100       0.004000    1487.000000
#
#              Field11  CoverageField1A  CoverageField1B  CoverageField2A  \
# count  260753.000000    260753.000000    260753.000000    260753.000000
# mean        1.162718         9.012533        13.000403         9.054005
# std         0.116833         5.576509         7.219264         5.560521
# min         1.000000        -1.000000        -1.000000         1.000000
# 25%         1.020000         5.000000         7.000000         5.000000
# 50%         1.188600         8.000000        13.000000         8.000000
# 75%         1.266500        12.000000        19.000000        12.000000
# max         1.304500        25.000000        25.000000        25.000000
#
#        CoverageField2B  CoverageField3A  ...  GeographicField58A  \
# count    260753.000000    260753.000000  ...       260753.000000
# mean         13.015240         9.053150  ...           11.567756
# std           7.211717         5.579687  ...            5.448425
# min           1.000000         1.000000  ...           -1.000000
# 25%           7.000000         5.000000  ...            8.000000
# 50%          13.000000         8.000000  ...           11.000000
# 75%          19.000000        12.000000  ...           15.000000
# max          25.000000        25.000000  ...           25.000000
#
#        GeographicField58B  GeographicField59A  GeographicField59B  \
# count       260753.000000       260753.000000       260753.000000
# mean            12.985695           11.694903           13.049882
# std              7.216091            5.626092            7.213636
# min             -1.000000           -1.000000           -1.000000
# 25%              7.000000            7.000000            7.000000
# 50%             13.000000           11.000000           13.000000
# 75%             19.000000           15.000000           19.000000
# max             25.000000           25.000000           25.000000
#
#        GeographicField60A  GeographicField60B  GeographicField61A  \
# count       260753.000000       260753.000000       260753.000000
# mean            -0.350481           12.994362           -0.343601
# std              4.057792            7.219943            4.078673
# min             -1.000000           -1.000000           -1.000000
# 25%             -1.000000            7.000000           -1.000000
# 50%             -1.000000           13.000000           -1.000000
# 75%             -1.000000           19.000000           -1.000000
# max             25.000000           25.000000           25.000000
#
#        GeographicField61B  GeographicField62A  GeographicField62B
# count       260753.000000       260753.000000       260753.000000
# mean            13.042734           -0.341009           14.122948
# std              7.145248            4.086511            5.829091
# min             -1.000000           -1.000000           -1.000000
# 25%              7.000000           -1.000000            8.000000
# 50%             13.000000           -1.000000           13.000000
# 75%             19.000000           -1.000000           19.000000
# max             25.000000           25.000000           25.000000
#
# [8 rows x 267 columns]

# %% [markdown]
# #### 2.a.iv) Summarize the levels of the class attribute

# %%
Xy_original.groupby('targetVar').size()
# Out:
# targetVar
# 0    211859
# 1     48894
# dtype: int64

# %% [markdown]
# ### 2.b) Data Visualization

# %%
# Histograms for each attribute
# X_original.hist(layout=(dispRow,dispCol))
# plt.show()

# %%
# Box and Whisker plot for each attribute
# X_original.plot(kind='box', subplots=True, layout=(dispRow,dispCol))
# plt.show()

# %%
# Density plot for each attribute
# X_original.plot(kind='density', subplots=True, layout=(dispRow,dispCol))
# plt.show()

# %%
# Correlation matrix
# fig = plt.figure(figsize=(16,12))
# ax = fig.add_subplot(111)
# correlations = X_original.corr(method='pearson')
# cax = ax.matshow(correlations, vmin=-1, vmax=1)
# fig.colorbar(cax)
# plt.show()

# %%
if notifyStatus: email_notify("Data Summarization and Visualization completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 3 - Prepare Data

# %%
if notifyStatus: email_notify("Data Cleaning and Transformation has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 3.a) Feature Scaling and Data Pre-Processing

# %%
columns_to_scale = ['Field8','Field9','Field10','Field11']
scaler = preprocessing.MinMaxScaler()
X_original[columns_to_scale] = scaler.fit_transform(X_original[columns_to_scale])

print(X_original.head(-10))
# Out:
#        Field6  Field7    Field8    Field9   Field10   Field11 Field12  \
# 0           B      23  0.484871  0.055556  0.444089  0.065681       N
# 1           F       7  0.929889  1.000000  0.000000  0.799015       N
# 2           F       7  0.929889  1.000000  0.000000  0.799015       N
# 3           J      10  0.754982  0.000000  0.657082  0.875205       N
# 4           E      23  0.535793  0.055556  1.000000  1.000000       N
# ...       ...     ...       ...       ...       ...       ...     ...
# 260738      E      23  0.476753  0.055556  1.000000  1.000000       N
# 260739      B      25  0.484871  0.083333  0.412141  0.065681       N
# 260740      J      10  0.697417  0.000000  0.657082  0.875205       N
# 260741      F      23  0.204428  0.944444  0.017039  0.220033       N
# 260742      B      24  0.484871  0.055556  0.444089  0.065681       N
#
#         CoverageField1A  CoverageField1B  CoverageField2A  ...  \
# 0                    17               23               17  ...
# 1                     6                8                6  ...
# 2                     7               12                7  ...
# 3                     3                2                3  ...
# 4                     8               13                8  ...
# ...                 ...              ...              ...  ...
# 260738                7               11                7  ...
# 260739                7               12                7  ...
# 260740                7               11                7  ...
# 260741                5                7                5  ...
# 260742                7               12                7  ...
#
#         GeographicField59A  GeographicField59B  GeographicField60A  \
# 0                        9                   9                  -1
# 1                       10                  10                  -1
# 2                       15                  18                  -1
# 3                        6                   5                  -1
# 4                       18                  22                  -1
# ...                    ...                 ...                 ...
# 260738                  12                  14                  -1
# 260739                  16                  20                  25
# 260740                  25                  25                  -1
# 260741                  14                  16                  -1
# 260742                  18                  22                  -1
#
#         GeographicField60B  GeographicField61A  GeographicField61B  \
# 0                        8                  -1                  18
# 1                       11                  -1                  17
# 2                       21                  -1                  11
# 3                       10                  -1                   9
# 4                       10                  -1                  11
# ...                    ...                 ...                 ...
# 260738                   8                  -1                  21
# 260739                  25                  -1                   6
# 260740                  24                  -1                   9
# 260741                  20                  -1                  23
# 260742                  18                  -1                   7
#
#         GeographicField62A  GeographicField62B  GeographicField63  \
# 0                       -1                  10                  N
# 1                       -1                  20                  N
# 2                       -1                   8                  N
# 3                       -1                  21                  N
# 4                       -1                  12                  N
# ...                    ...                 ...                ...
# 260738                  -1                  10                  N
# 260739                  -1                   8                  N
# 260740                  25                  25                  N
# 260741                  -1                   8                  N
# 260742                  -1                  13                  N
#
#        GeographicField64
# 0                     CA
# 1                     NJ
# 2                     NJ
# 3                     TX
# 4                     IL
# ...                  ...
# 260738                IL
# 260739                CA
# 260740                TX
# 260741                NJ
# 260742                CA
#
# [260743 rows x 293 columns]

# %%
# Histograms for each pre-processed attribute
X_original[columns_to_scale].hist(layout=(dispRow,dispCol))
plt.show()

# %% [markdown]
# ### 3.b) Training Data Balancing

# %%
# Not applicable for this iteration of the project

# %% [markdown]
# ### 3.c) Feature Selection

# %%
# Not applicable for this iteration of the project

# %% [markdown]
# ### 3.d) Splitting Data into Training and Test Sets

# %%
# Not applicable for this iteration of the project
# Perform one-hot-encoding on the categorical attributes
X_original = pd.get_dummies(X_original)
X_original.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260753 entries, 0 to 260752
# Data columns (total 580 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Field7                 int64
#  1   Field8                 float64
#  2   Field9                 float64
#  3   Field10                float64
#  4   Field11                float64
#  5   CoverageField1A        int64
#  6   CoverageField1B        int64
#  7   CoverageField2A        int64
#  8   CoverageField2B        int64
#  9   CoverageField3A        int64
#  10  CoverageField3B        int64
#  11  CoverageField4A        int64
#  12  CoverageField4B        int64
#  13  CoverageField5A        int64
#  14  CoverageField5B        int64
#  15  CoverageField6A        int64
#  16  CoverageField6B        int64
#  17  CoverageField11A       int64
#  18  CoverageField11B       int64
#  19  SalesField1A           int64
#  20  SalesField1B           int64
#  21  SalesField2A           int64
#  22  SalesField2B           int64
#  23  SalesField3            int64
#  24  SalesField4            int64
#  25  SalesField5            int64
#  26  SalesField6            int64
#  27  SalesField9            int64
#  28  SalesField10           int64
#  29  SalesField11           int64
#  30  SalesField12           int64
#  31  SalesField13           int64
#  32  SalesField14           int64
#  33  SalesField15           int64
#  34  PersonalField1         int64
#  35  PersonalField2         int64
#  36  PersonalField4A        int64
#  37  PersonalField4B        int64
#  38  PersonalField5         int64
#  39  PersonalField6         int64
#  40  PersonalField8         int64
#  41  PersonalField9         int64
#  42  PersonalField10A       int64
#  43  PersonalField10B       int64
#  44  PersonalField11        int64
#  45  PersonalField12        int64
#  46  PersonalField13        int64
#  47  PersonalField14        int64
#  48  PersonalField15        int64
#  49  PersonalField22        int64
#  50  PersonalField23        int64
#  51  PersonalField24        int64
#  52  PersonalField25        int64
#  53  PersonalField26        int64
#  54  PersonalField27        int64
#  55  PersonalField28        int64
#  56  PersonalField29        int64
#  57  PersonalField30        int64
#  58  PersonalField31        int64
#  59  PersonalField32        int64
#  60  PersonalField33        int64
#  61  PersonalField34        int64
#  62  PersonalField35        int64
#  63  PersonalField36        int64
#  64  PersonalField37        int64
#  65  PersonalField38        int64
#  66  PersonalField39        int64
#  67  PersonalField40        int64
#  68  PersonalField41        int64
#  69  PersonalField42        int64
#  70  PersonalField43        int64
#  71  PersonalField44        int64
#  72  PersonalField45        int64
#  73  PersonalField46        int64
#  74  PersonalField47        int64
#  75  PersonalField48        int64
#  76  PersonalField49        int64
#  77  PersonalField50        int64
#  78  PersonalField51        int64
#  79  PersonalField52        int64
#  80  PersonalField53        int64
#  81  PersonalField54        int64
#  82  PersonalField55        int64
#  83  PersonalField56        int64
#  84  PersonalField57        int64
#  85  PersonalField58        int64
#  86  PersonalField59        int64
#  87  PersonalField60        int64
#  88  PersonalField61        int64
#  89  PersonalField62        int64
#  90  PersonalField63        int64
#  91  PersonalField64        int64
#  92  PersonalField65        int64
#  93  PersonalField66        int64
#  94  PersonalField67        int64
#  95  PersonalField68        int64
#  96  PersonalField69        int64
#  97  PersonalField70        int64
#  98  PersonalField71        int64
#  99  PersonalField72        int64
#  100 PersonalField73        int64
#  101 PersonalField74        int64
#  102 PersonalField75        int64
#  103 PersonalField76        int64
#  104 PersonalField77        int64
#  105 PersonalField78        int64
#  106 PersonalField79        int64
#  107 PersonalField80        int64
#  108 PersonalField81        int64
#  109 PersonalField82        int64
#  110 PersonalField83        int64
#  111 PropertyField1A        int64
#  112 PropertyField1B        int64
#  113 PropertyField2A        int64
#  114 PropertyField2B        int64
#  115 PropertyField6         int64
#  116 PropertyField8         int64
#  117 PropertyField9         int64
#  118 PropertyField10        int64
#  119 PropertyField11A       int64
#  120 PropertyField11B       int64
#  121 PropertyField12        int64
#  122 PropertyField13        int64
#  123 PropertyField15        int64
#  124 PropertyField16A       int64
#  125 PropertyField16B       int64
#  126 PropertyField17        int64
#  127 PropertyField18        int64
#  128 PropertyField19        int64
#  129 PropertyField20        int64
#  130 PropertyField21A       int64
#  131 PropertyField21B       int64
#  132 PropertyField22        int64
#  133 PropertyField23        int64
#  134 PropertyField24A       int64
#  135 PropertyField24B       int64
#  136 PropertyField25        float64
#  137 PropertyField26A       int64
#  138 PropertyField26B       int64
#  139 PropertyField27        int64
#  140 PropertyField35        int64
#  141 PropertyField39A       int64
#  142 PropertyField39B       int64
#  143 GeographicField1A      int64
#  144 GeographicField1B      int64
#  145 GeographicField2A      int64
#  146 GeographicField2B      int64
#  147 GeographicField3A      int64
#  148 GeographicField3B      int64
#  149 GeographicField4A      int64
#  150 GeographicField4B      int64
#  151 GeographicField5A      int64
#  152 GeographicField5B      int64
#  153 GeographicField6A      int64
#  154 GeographicField6B      int64
#  155 GeographicField7A      int64
#  156 GeographicField7B      int64
#  157 GeographicField8A      int64
#  158 GeographicField8B      int64
#  159 GeographicField9A      int64
#  160 GeographicField9B      int64
#  161 GeographicField10A     int64
#  162 GeographicField10B     int64
#  163 GeographicField11A     int64
#  164 GeographicField11B     int64
#  165 GeographicField12A     int64
#  166 GeographicField12B     int64
#  167 GeographicField13A     int64
#  168 GeographicField13B     int64
#  169 GeographicField14A     int64
#  170 GeographicField14B     int64
#  171 GeographicField15A     int64
#  172 GeographicField15B     int64
#  173 GeographicField16A     int64
#  174 GeographicField16B     int64
#  175 GeographicField17A     int64
#  176 GeographicField17B     int64
#  177 GeographicField18A     int64
#  178 GeographicField18B     int64
#  179 GeographicField19A     int64
#  180 GeographicField19B     int64
#  181 GeographicField20A     int64
#  182 GeographicField20B     int64
#  183 GeographicField21A     int64
#  184 GeographicField21B     int64
#  185 GeographicField22A     int64
#  186 GeographicField22B     int64
#  187 GeographicField23A     int64
#  188 GeographicField23B     int64
#  189 GeographicField24A     int64
#  190 GeographicField24B     int64
#  191 GeographicField25A     int64
#  192 GeographicField25B     int64
#  193 GeographicField26A     int64
#  194 GeographicField26B     int64
#  195 GeographicField27A     int64
#  196 GeographicField27B     int64
#  197 GeographicField28A     int64
#  198 GeographicField28B     int64
#  199 GeographicField29A     int64
#  200 GeographicField29B     int64
#  201 GeographicField30A     int64
#  202 GeographicField30B     int64
#  203 GeographicField31A     int64
#  204 GeographicField31B     int64
#  205 GeographicField32A     int64
#  206 GeographicField32B     int64
#  207 GeographicField33A     int64
#  208 GeographicField33B     int64
#  209 GeographicField34A     int64
#  210 GeographicField34B     int64
#  211 GeographicField35A     int64
#  212 GeographicField35B     int64
#  213 GeographicField36A     int64
#  214 GeographicField36B     int64
#  215 GeographicField37A     int64
#  216 GeographicField37B     int64
#  217 GeographicField38A     int64
#  218 GeographicField38B     int64
#  219 GeographicField39A     int64
#  220 GeographicField39B     int64
#  221 GeographicField40A     int64
#  222 GeographicField40B     int64
#  223 GeographicField41A     int64
#  224 GeographicField41B     int64
#  225 GeographicField42A     int64
#  226 GeographicField42B     int64
#  227 GeographicField43A     int64
#  228 GeographicField43B     int64
#  229 GeographicField44A     int64
#  230 GeographicField44B     int64
#  231 GeographicField45A     int64
#  232 GeographicField45B     int64
#  233 GeographicField46A     int64
#  234 GeographicField46B     int64
#  235 GeographicField47A     int64
#  236 GeographicField47B     int64
#  237 GeographicField48A     int64
#  238 GeographicField48B     int64
#  239 GeographicField49A     int64
#  240 GeographicField49B     int64
#  241 GeographicField50A     int64
#  242 GeographicField50B     int64
#  243 GeographicField51A     int64
#  244 GeographicField51B     int64
#  245 GeographicField52A     int64
#  246 GeographicField52B     int64
#  247 GeographicField53A     int64
#  248 GeographicField53B     int64
#  249 GeographicField54A     int64
#  250 GeographicField54B     int64
#  251 GeographicField55A     int64
#  252 GeographicField55B     int64
#  253 GeographicField56A     int64
#  254 GeographicField56B     int64
#  255 GeographicField57A     int64
#  256 GeographicField57B     int64
#  257 GeographicField58A     int64
#  258 GeographicField58B     int64
#  259 GeographicField59A     int64
#  260 GeographicField59B     int64
#  261 GeographicField60A     int64
#  262 GeographicField60B     int64
#  263 GeographicField61A     int64
#  264 GeographicField61B     int64
#  265 GeographicField62A     int64
#  266 GeographicField62B     int64
#  267 Field6_A               uint8
#  268 Field6_B               uint8
#  269 Field6_C               uint8
#  270 Field6_D               uint8
#  271 Field6_E               uint8
#  272 Field6_F               uint8
#  273 Field6_J               uint8
#  274 Field6_K               uint8
#  275 Field12_N              uint8
#  276 Field12_Y              uint8
#  277 CoverageField8_T       uint8
#  278 CoverageField8_U       uint8
#  279 CoverageField8_V       uint8
#  280 CoverageField8_W       uint8
#  281 CoverageField8_X       uint8
#  282 CoverageField8_Y       uint8
#  283 CoverageField8_Z       uint8
#  284 CoverageField9_A       uint8
#  285 CoverageField9_B       uint8
#  286 CoverageField9_C       uint8
#  287 CoverageField9_D       uint8
#  288 CoverageField9_E       uint8
#  289 CoverageField9_F       uint8
#  290 CoverageField9_G       uint8
#  291 CoverageField9_H       uint8
#  292 CoverageField9_I       uint8
#  293 CoverageField9_J       uint8
#  294 CoverageField9_K       uint8
#  295 CoverageField9_L       uint8
#  296 SalesField7_K          uint8
#  297 SalesField7_M          uint8
#  298 SalesField7_P          uint8
#  299 SalesField7_Q          uint8
#  300 SalesField7_R          uint8
#  301 SalesField7_T          uint8
#  302 SalesField7_V          uint8
#  303 PersonalField7_N       uint8
#  304 PersonalField7_Y       uint8
#  305 PersonalField16_OTHER  uint8
#  306 PersonalField16_XB     uint8
#  307 PersonalField16_XC     uint8
#  308 PersonalField16_XD     uint8
#  309 PersonalField16_XE     uint8
#  310 PersonalField16_XF     uint8
#  311 PersonalField16_XH     uint8
#  312 PersonalField16_XI     uint8
#  313 PersonalField16_XJ     uint8
#  314 PersonalField16_XK     uint8
#  315 PersonalField16_XL     uint8
#  316 PersonalField16_XM     uint8
#  317 PersonalField16_XO     uint8
#  318 PersonalField16_XP     uint8
#  319 PersonalField16_XQ     uint8
#  320 PersonalField16_XR     uint8
#  321 PersonalField16_XS     uint8
#  322 PersonalField16_XT     uint8
#  323 PersonalField16_XV     uint8
#  324 PersonalField16_XW     uint8
#  325 PersonalField16_XX     uint8
#  326 PersonalField16_XZ     uint8
#  327 PersonalField16_YE     uint8
#  328 PersonalField16_YF     uint8
#  329 PersonalField16_YH     uint8
#  330 PersonalField16_YI     uint8
#  331 PersonalField16_ZA     uint8
#  332 PersonalField16_ZB     uint8
#  333 PersonalField16_ZC     uint8
#  334 PersonalField16_ZD     uint8
#  335 PersonalField16_ZE     uint8
#  336 PersonalField16_ZF     uint8
#  337 PersonalField16_ZG     uint8
#  338 PersonalField16_ZH     uint8
#  339 PersonalField16_ZI     uint8
#  340 PersonalField16_ZJ     uint8
#  341 PersonalField16_ZK     uint8
#  342 PersonalField16_ZN     uint8
#  343 PersonalField16_ZR     uint8
#  344 PersonalField16_ZT     uint8
#  345 PersonalField16_ZU     uint8
#  346 PersonalField16_ZW     uint8
#  347 PersonalField17_OTHER  uint8
#  348 PersonalField17_XB     uint8
#  349 PersonalField17_XC     uint8
#  350 PersonalField17_XD     uint8
#  351 PersonalField17_XE     uint8
#  352 PersonalField17_XG     uint8
#  353 PersonalField17_XH     uint8
#  354 PersonalField17_XI     uint8
#  355 PersonalField17_XK     uint8
#  356 PersonalField17_XL     uint8
#  357 PersonalField17_XM     uint8
#  358 PersonalField17_XN     uint8
#  359 PersonalField17_XQ     uint8
#  360 PersonalField17_XR     uint8
#  361 PersonalField17_XS     uint8
#  362 PersonalField17_XT     uint8
#  363 PersonalField17_XU     uint8
#  364 PersonalField17_XV     uint8
#  365 PersonalField17_XW     uint8
#  366 PersonalField17_XX     uint8
#  367 PersonalField17_YE     uint8
#  368 PersonalField17_YF     uint8
#  369 PersonalField17_YG     uint8
#  370 PersonalField17_YH     uint8
#  371 PersonalField17_YI     uint8
#  372 PersonalField17_YJ     uint8
#  373 PersonalField17_YK     uint8
#  374 PersonalField17_YL     uint8
#  375 PersonalField17_YM     uint8
#  376 PersonalField17_YN     uint8
#  377 PersonalField17_YQ     uint8
#  378 PersonalField17_YR     uint8
#  379 PersonalField17_YS     uint8
#  380 PersonalField17_YT     uint8
#  381 PersonalField17_YU     uint8
#  382 PersonalField17_YV     uint8
#  383 PersonalField17_YW     uint8
#  384 PersonalField17_YX     uint8
#  385 PersonalField17_YY     uint8
#  386 PersonalField17_YZ     uint8
#  387 PersonalField17_ZA     uint8
#  388 PersonalField17_ZB     uint8
#  389 PersonalField17_ZC     uint8
#  390 PersonalField17_ZD     uint8
#  391 PersonalField17_ZE     uint8
#  392 PersonalField17_ZF     uint8
#  393 PersonalField17_ZG     uint8
#  394 PersonalField17_ZH     uint8
#  395 PersonalField17_ZI     uint8
#  396 PersonalField17_ZK     uint8
#  397 PersonalField17_ZL     uint8
#  398 PersonalField17_ZM     uint8
#  399 PersonalField17_ZN     uint8
#  400 PersonalField17_ZO     uint8
#  401 PersonalField17_ZP     uint8
#  402 PersonalField17_ZQ     uint8
#  403 PersonalField17_ZS     uint8
#  404 PersonalField17_ZT     uint8
#  405 PersonalField17_ZU     uint8
#  406 PersonalField17_ZV     uint8
#  407 PersonalField17_ZW     uint8
#  408 PersonalField18_OTHER  uint8
#  409 PersonalField18_XC     uint8
#  410 PersonalField18_XD     uint8
#  411 PersonalField18_XE     uint8
#  412 PersonalField18_XF     uint8
#  413 PersonalField18_XG     uint8
#  414 PersonalField18_XI     uint8
#  415 PersonalField18_XJ     uint8
#  416 PersonalField18_XK     uint8
#  417 PersonalField18_XL     uint8
#  418 PersonalField18_XM     uint8
#  419 PersonalField18_XN     uint8
#  420 PersonalField18_XO     uint8
#  421 PersonalField18_XP     uint8
#  422 PersonalField18_XQ     uint8
#  423 PersonalField18_XR     uint8
#  424 PersonalField18_XS     uint8
#  425 PersonalField18_XT     uint8
#  426 PersonalField18_XU     uint8
#  427 PersonalField18_XW     uint8
#  428 PersonalField18_XX     uint8
#  429 PersonalField18_XY     uint8
#  430 PersonalField18_XZ     uint8
#  431 PersonalField18_YE     uint8
#  432 PersonalField18_YF     uint8
#  433 PersonalField18_YG     uint8
#  434 PersonalField18_YH     uint8
#  435 PersonalField18_YI     uint8
#  436 PersonalField18_YJ     uint8
#  437 PersonalField18_YK     uint8
#  438 PersonalField18_YL     uint8
#  439 PersonalField18_YM     uint8
#  440 PersonalField18_YN     uint8
#  441 PersonalField18_YO     uint8
#  442 PersonalField18_YP     uint8
#  443 PersonalField18_YQ     uint8
#  444 PersonalField18_YR     uint8
#  445 PersonalField18_ZA     uint8
#  446 PersonalField18_ZB     uint8
#  447 PersonalField18_ZC     uint8
#  448 PersonalField18_ZD     uint8
#  449 PersonalField18_ZE     uint8
#  450 PersonalField18_ZF     uint8
#  451 PersonalField18_ZH     uint8
#  452 PersonalField18_ZJ     uint8
#  453 PersonalField18_ZK     uint8
#  454 PersonalField18_ZL     uint8
#  455 PersonalField18_ZM     uint8
#  456 PersonalField18_ZN     uint8
#  457 PersonalField18_ZO     uint8
#  458 PersonalField18_ZP     uint8
#  459 PersonalField18_ZQ     uint8
#  460 PersonalField18_ZR     uint8
#  461 PersonalField18_ZS     uint8
#  462 PersonalField18_ZT     uint8
#  463 PersonalField18_ZU     uint8
#  464 PersonalField18_ZV     uint8
#  465 PersonalField18_ZW     uint8
#  466 PersonalField19_OTHER  uint8
#  467 PersonalField19_XB     uint8
#  468 PersonalField19_XC     uint8
#  469 PersonalField19_XD     uint8
#  470 PersonalField19_XE     uint8
#  471 PersonalField19_XF     uint8
#  472 PersonalField19_XG     uint8
#  473 PersonalField19_XH     uint8
#  474 PersonalField19_XI     uint8
#  475 PersonalField19_XJ     uint8
#  476 PersonalField19_XK     uint8
#  477 PersonalField19_XM     uint8
#  478 PersonalField19_XN     uint8
#  479 PersonalField19_XO     uint8
#  480 PersonalField19_XP     uint8
#  481 PersonalField19_XQ     uint8
#  482 PersonalField19_XR     uint8
#  483 PersonalField19_XS     uint8
#  484 PersonalField19_XT     uint8
#  485 PersonalField19_XU     uint8
#  486 PersonalField19_XV     uint8
#  487 PersonalField19_XW     uint8
#  488 PersonalField19_XX     uint8
#  489 PersonalField19_XY     uint8
#  490 PersonalField19_XZ     uint8
#  491 PersonalField19_YE     uint8
#  492 PersonalField19_YF     uint8
#  493 PersonalField19_YG     uint8
#  494 PersonalField19_YH     uint8
#  495 PersonalField19_YJ     uint8
#  496 PersonalField19_YK     uint8
#  497 PersonalField19_YL     uint8
#  498 PersonalField19_YM     uint8
#  499 PersonalField19_YN     uint8
#  500 PersonalField19_ZA     uint8
#  501 PersonalField19_ZB     uint8
#  502 PersonalField19_ZD     uint8
#  503 PersonalField19_ZE     uint8
#  504 PersonalField19_ZF     uint8
#  505 PersonalField19_ZG     uint8
#  506 PersonalField19_ZH     uint8
#  507 PersonalField19_ZI     uint8
#  508 PersonalField19_ZJ     uint8
#  509 PersonalField19_ZK     uint8
#  510 PersonalField19_ZL     uint8
#  511 PersonalField19_ZM     uint8
#  512 PersonalField19_ZN     uint8
#  513 PersonalField19_ZO     uint8
#  514 PersonalField19_ZP     uint8
#  515 PersonalField19_ZQ     uint8
#  516 PersonalField19_ZR     uint8
#  517 PersonalField19_ZT     uint8
#  518 PersonalField19_ZU     uint8
#  519 PersonalField19_ZV     uint8
#  520 PersonalField19_ZW     uint8
#  521 PropertyField3_N       uint8
#  522 PropertyField3_Y       uint8
#  523 PropertyField4_N       uint8
#  524 PropertyField4_Y       uint8
#  525 PropertyField5_N       uint8
#  526 PropertyField5_Y       uint8
#  527 PropertyField7_A       uint8
#  528 PropertyField7_C       uint8
#  529 PropertyField7_D       uint8
#  530 PropertyField7_E       uint8
#  531 PropertyField7_F       uint8
#  532 PropertyField7_G       uint8
#  533 PropertyField7_H       uint8
#  534 PropertyField7_I       uint8
#  535 PropertyField7_J       uint8
#  536 PropertyField7_K       uint8
#  537 PropertyField7_L       uint8
#  538 PropertyField7_M       uint8
#  539 PropertyField7_N       uint8
#  540 PropertyField7_O       uint8
#  541 PropertyField7_OTHER   uint8
#  542 PropertyField7_P       uint8
#  543 PropertyField7_Q       uint8
#  544 PropertyField7_R       uint8
#  545 PropertyField7_S       uint8
#  546 PropertyField14_A      uint8
#  547 PropertyField14_B      uint8
#  548 PropertyField14_C      uint8
#  549 PropertyField14_D      uint8
#  550 PropertyField28_A      uint8
#  551 PropertyField28_B      uint8
#  552 PropertyField28_C      uint8
#  553 PropertyField28_D      uint8
#  554 PropertyField30_N      uint8
#  555 PropertyField30_Y      uint8
#  556 PropertyField31_K      uint8
#  557 PropertyField31_M      uint8
#  558 PropertyField31_N      uint8
#  559 PropertyField31_O      uint8
#  560 PropertyField32_N      uint8
#  561 PropertyField32_Y      uint8
#  562 PropertyField33_E      uint8
#  563 PropertyField33_F      uint8
#  564 PropertyField33_G      uint8
#  565 PropertyField33_H      uint8
#  566 PropertyField34_N      uint8
#  567 PropertyField34_Y      uint8
#  568 PropertyField36_N      uint8
#  569 PropertyField36_Y      uint8
#  570 PropertyField37_N      uint8
#  571 PropertyField37_Y      uint8
#  572 PropertyField38_N      uint8
#  573 PropertyField38_Y      uint8
#  574 GeographicField63_N    uint8
#  575 GeographicField63_Y    uint8
#  576 GeographicField64_CA   uint8
#  577 GeographicField64_IL   uint8
#  578 GeographicField64_NJ   uint8
#  579 GeographicField64_TX   uint8
# dtypes: float64(5), int64(262), uint8(313)
# memory usage: 609.0 MB

# %%
# Split the data further into training and test datasets
if splitDataset:
    X_train_df, X_test_df, y_train_df, y_test_df = train_test_split(X_original, y_original, test_size=splitPercentage, 
                                                                    stratify=y_original, random_state=seedNum)
else:
    X_train_df, y_train_df = X_original, y_original
    X_test_df, y_test_df = X_original, y_original
print("X_train_df.shape: {} y_train_df.shape: {}".format(X_train_df.shape, y_train_df.shape))
print("X_test_df.shape: {} y_test_df.shape: {}".format(X_test_df.shape, y_test_df.shape))
# Out:
# X_train_df.shape: (195564, 580) y_train_df.shape: (195564,)
# X_test_df.shape: (65189, 580) y_test_df.shape: (65189,)

# %% [markdown]
# ### 3.e) Display the Final Datasets for Model-Building

# %%
# Finalize the training and testing datasets for the modeling activities
X_train = X_train_df.to_numpy()
y_train = y_train_df.to_numpy()
X_test = X_test_df.to_numpy()
y_test = y_test_df.to_numpy()
print("X_train.shape: {} y_train.shape: {}".format(X_train.shape, y_train.shape))
print("X_test.shape: {} y_test.shape: {}".format(X_test.shape, y_test.shape))
# Out:
# X_train.shape: (195564, 580) y_train.shape: (195564,)
# X_test.shape: (65189, 580) y_test.shape: (65189,)

# %%
if notifyStatus: email_notify("Data Cleaning and Transformation completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## 4. Model and Evaluate Algorithms

# %% [markdown]
# ### 4.a) Set test options and evaluation metric

# %%
# Set up Algorithms Spot-Checking Array
startTimeModule = datetime.now()
train_models = []
train_results = []
train_model_names = []
train_metrics = []
train_models.append(('LGR', LogisticRegression(random_state=seedNum)))
train_models.append(('CART', DecisionTreeClassifier(random_state=seedNum)))
train_models.append(('BGT', BaggingClassifier(random_state=seedNum, n_jobs=n_jobs)))
train_models.append(('RNF', RandomForestClassifier(random_state=seedNum, n_jobs=n_jobs)))
train_models.append(('EXT', ExtraTreesClassifier(random_state=seedNum, n_jobs=n_jobs)))
train_models.append(('GBM', GradientBoostingClassifier(random_state=seedNum)))
# train_models.append(('XGB', XGBClassifier(random_state=seedNum, n_jobs=n_jobs, tree_method='gpu_hist')))

# %%
# Generate model in turn
for name, model in train_models:
	if notifyStatus: email_notify("Algorithm "+name+" modeling has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))
	startTimeModule = datetime.now()
	kfold = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=seedNum)
	cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring, n_jobs=n_jobs, verbose=1)
	train_results.append(cv_results)
	train_model_names.append(name)
	train_metrics.append(cv_results.mean())
	print("%s: %f (%f)" % (name, cv_results.mean(), cv_results.std()))
	print(model)
	print ('Model training time:', (datetime.now() - startTimeModule), '\n')
	if notifyStatus: email_notify("Algorithm "+name+" modeling completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))
print ('Average metrics ('+scoring+') from all models:',np.mean(train_metrics))
print ('Total training time for all models:',(datetime.now() - startTimeModule))
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   5 out of   5 | elapsed:   48.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# LGR: 0.901791 (0.002195)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=888, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# Model training time: 0:00:48.628315
# [Parallel(n_jobs=4)]: Done   5 out of   5 | elapsed:  2.3min finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# CART: 0.821535 (0.002501)
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=888, splitter='best')
# Model training time: 0:02:19.181967
# [Parallel(n_jobs=4)]: Done   5 out of   5 | elapsed: 10.1min finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# BGT: 0.935091 (0.000885)
# BaggingClassifier(base_estimator=None, bootstrap=True, bootstrap_features=False,
#                   max_features=1.0, max_samples=1.0, n_estimators=10, n_jobs=4,
#                   oob_score=False, random_state=888, verbose=0,
#                   warm_start=False)
# Model training time: 0:10:06.685926
# [Parallel(n_jobs=4)]: Done   5 out of   5 | elapsed:  4.4min finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# RNF: 0.951451 (0.000851)
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=4,
#                        oob_score=False, random_state=888, verbose=0,
#                        warm_start=False)
# Model training time: 0:04:25.619368
# [Parallel(n_jobs=4)]: Done   5 out of   5 | elapsed:  4.3min finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# EXT: 0.949504 (0.000819)
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=4,
#                      oob_score=False, random_state=888, verbose=0,
#                      warm_start=False)
# Model training time: 0:04:18.824600
#
# GBM: 0.958217 (0.000594)
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=888, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)
# Model training time: 0:41:39.202416
#
# Average metrics (roc_auc) from all models: 0.9195981834904056
# Total training time for all models: 0:41:39.203634
# [Parallel(n_jobs=4)]: Done   5 out of   5 | elapsed: 41.7min finished

# %% [markdown]
# ### 4.b) Spot-checking baseline algorithms

# %%
fig = plt.figure(figsize=(16,12))
fig.suptitle('Algorithm Comparison - Spot Checking')
ax = fig.add_subplot(111)
plt.boxplot(train_results)
ax.set_xticklabels(train_model_names)
plt.show()

# %% [markdown]
# ## Section 5 - Improve Accuracy

# %% [markdown]
# ### 5.a) Algorithm Tuning

# %%
# Set up the comparison array
tune_results = []
tune_model_names = []

# %%
# Tuning algorithm #1 - Random Forest
startTimeModule = datetime.now()
if notifyStatus: email_notify("Algorithm #1 tuning has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

tune_model1 = RandomForestClassifier(random_state=seedNum, n_jobs=n_jobs)
tune_model_names.append('RNF')
paramGrid1 = dict(n_estimators=np.array([100, 300, 500, 700, 900]))

kfold = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=seedNum)
grid1 = GridSearchCV(estimator=tune_model1, param_grid=paramGrid1, scoring=scoring, cv=kfold, n_jobs=n_jobs, verbose=1)
grid_result1 = grid1.fit(X_train, y_train)

print("Best: %f using %s" % (grid_result1.best_score_, grid_result1.best_params_))
tune_results.append(grid_result1.cv_results_['mean_test_score'])
means = grid_result1.cv_results_['mean_test_score']
stds = grid_result1.cv_results_['std_test_score']
params = grid_result1.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
print ('Model training time:',(datetime.now() - startTimeModule))
if notifyStatus: email_notify("Algorithm #1 tuning completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  25 out of  25 | elapsed: 100.9min finished
# Best: 0.954012 using {'n_estimators': 900}
# 0.951451 (0.000851) with: {'n_estimators': 100}
# 0.953373 (0.000754) with: {'n_estimators': 300}
# 0.953714 (0.000764) with: {'n_estimators': 500}
# 0.953918 (0.000759) with: {'n_estimators': 700}
# 0.954012 (0.000748) with: {'n_estimators': 900}
# Model training time: 1:49:53.925929

# %%
best_paramKey1 = list(grid_result1.best_params_.keys())[0]
best_paramValue1 = list(grid_result1.best_params_.values())[0]
print("Captured the best parameter for algorithm #1:", best_paramKey1, '=', best_paramValue1)
# Out:
# Captured the best parameter for algorithm #1: n_estimators = 900

# %%
# Tuning algorithm #2 - Gradient Boosting
startTimeModule = datetime.now()
if notifyStatus: email_notify("Algorithm #2 tuning has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

tune_model2 = GradientBoostingClassifier(random_state=seedNum)
tune_model_names.append('GBM')
paramGrid2 = dict(n_estimators=np.array([100, 300, 500, 700, 900]))

kfold = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=seedNum)
grid2 = GridSearchCV(estimator=tune_model2, param_grid=paramGrid2, scoring=scoring, cv=kfold, n_jobs=n_jobs, verbose=1)
grid_result2 = grid2.fit(X_train, y_train)

print("Best: %f using %s" % (grid_result2.best_score_, grid_result2.best_params_))
tune_results.append(grid_result2.cv_results_['mean_test_score'])
means = grid_result2.cv_results_['mean_test_score']
stds = grid_result2.cv_results_['std_test_score']
params = grid_result2.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
print ('Model training time:',(datetime.now() - startTimeModule))
if notifyStatus: email_notify("Algorithm #2 tuning completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  25 out of  25 | elapsed: 719.0min finished
# Best: 0.964309 using {'n_estimators': 900}
# 0.958217 (0.000594) with: {'n_estimators': 100}
# 0.962763 (0.000698) with: {'n_estimators': 300}
# 0.963696 (0.000734) with: {'n_estimators': 500}
# 0.964123 (0.000756) with: {'n_estimators': 700}
# 0.964309 (0.000767) with: {'n_estimators': 900}
# Model training time: 14:33:49.776525

# %%
best_paramKey2 = list(grid_result2.best_params_.keys())[0]
best_paramValue2 = list(grid_result2.best_params_.values())[0]
print("Captured the best parameter for algorithm #2:", best_paramKey2, '=', best_paramValue2)
# Out:
# Captured the best parameter for algorithm #2: n_estimators = 900

# %% [markdown]
# ### 5.b) Compare Algorithms After Tuning

# %%
fig = plt.figure(figsize=(16,12))
fig.suptitle('Algorithm Comparison - Post Tuning')
ax = fig.add_subplot(111)
plt.boxplot(tune_results)
ax.set_xticklabels(tune_model_names)
plt.show()

# %% [markdown]
# ## Section 6 - Finalize Model

# %%
if notifyStatus: email_notify("Model Validation and Final Model Creation has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 6.a) Measure predictions from the test dataset

# %%
test_model1 = RandomForestClassifier(n_estimators=best_paramValue1, random_state=seedNum, n_jobs=n_jobs)
test_model1.fit(X_train, y_train)
predictions1 = test_model1.predict(X_test)
print('Accuracy Score:', accuracy_score(y_test, predictions1))
probability1 = test_model1.predict_proba(X_test)[:,1]
print('ROC/AUC Score:', roc_auc_score(y_test, probability1))
print(confusion_matrix(y_test, predictions1))
print(classification_report(y_test, predictions1))
print(test_model1)
# Out:
# Accuracy Score: 0.9125926153185353
# ROC/AUC Score: 0.9539103202351845
# [[52125   840]
#  [ 4858  7366]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.95     52965
#            1       0.90      0.60      0.72     12224
#
#     accuracy                           0.91     65189
#    macro avg       0.91      0.79      0.83     65189
# weighted avg       0.91      0.91      0.91     65189
#
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=900, n_jobs=4,
#                        oob_score=False, random_state=888, verbose=0,
#                        warm_start=False)

# %%
test_model2 = GradientBoostingClassifier(n_estimators=best_paramValue2, random_state=seedNum)
test_model2.fit(X_train, y_train)
predictions2 = test_model2.predict(X_test)
print('Accuracy Score:', accuracy_score(y_test, predictions2))
probability2 = test_model2.predict_proba(X_test)[:,1]
print('ROC/AUC Score:', roc_auc_score(y_test, probability2))
print(confusion_matrix(y_test, predictions2))
print(classification_report(y_test, predictions2))
print(test_model2)
# Out:
# Accuracy Score: 0.9262298854101152
# ROC/AUC Score: 0.9642120920513053
# [[51938  1027]
#  [ 3782  8442]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96     52965
#            1       0.89      0.69      0.78     12224
#
#     accuracy                           0.93     65189
#    macro avg       0.91      0.84      0.87     65189
# weighted avg       0.92      0.93      0.92     65189
#
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=900,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=888, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %% [markdown]
# ### 6.b) Create a standalone model using all available data

# %%
# Combining the training and testing datasets to form the complete dataset that will be used for training the final model
X_complete = np.vstack((X_train, X_test))
y_complete = np.concatenate((y_train, y_test))
print("X_complete.shape: {} y_complete.shape: {}".format(X_complete.shape, y_complete.shape))
final_model = test_model2.fit(X_complete, y_complete)
print(final_model)
# Out:
# X_complete.shape: (260753, 580) y_complete.shape: (260753,)
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=900,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=888, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %% [markdown]
# ### 6.c) Create Submission Files for Kaggle Evaluation

# %%
dataset_path = 'https://dainesanalytics.com/datasets/kaggle-homesite-quote-conversion/test.csv'
X_kaggle_data = pd.read_csv(dataset_path, sep=',')

# Take a peek at the dataframe after import
X_kaggle_data.head(10)
# Out:
#    QuoteNumber Original_Quote_Date Field6  Field7  Field8  Field9 Field10  \
# 0            3          2014-08-12      E      16  0.9364  0.0006   1,487
# 1            5          2013-09-07      F      11  0.9919  0.0038     564
# 2            7          2013-03-29      F      15  0.8945  0.0038     564
# 3            9          2015-03-21      K      21  0.8870  0.0004   1,113
# 4           10          2014-12-10      B      25  0.9153  0.0007     935
# 5           11          2013-07-19      B      24  0.9403  0.0006     965
# 6           15          2014-07-28      E      23  0.9392  0.0006   1,487
# 7           16          2015-01-20      B      25  0.9153  0.0007     935
# 8           17          2014-05-28      J      23  0.8928  0.0004   1,113
# 9           21          2013-07-11      J      23  0.9691  0.0004   1,165
#
#    Field11 Field12  CoverageField1A  ...  GeographicField59A  \
# 0   1.3045       N                4  ...                   1
# 1   1.1886       N                8  ...                  10
# 2   1.0670       N               11  ...                  10
# 3   1.2665       Y               14  ...                   8
# 4   1.0200       N                4  ...                   7
# 5   1.0200       N               11  ...                   9
# 6   1.3045       N                5  ...                  11
# 7   1.0200       N                6  ...                  15
# 8   1.2665       N               12  ...                   7
# 9   1.2665       N                3  ...                   7
#
#    GeographicField59B  GeographicField60A  GeographicField60B  \
# 0                   1                  -1                   1
# 1                  10                  -1                   5
# 2                  11                  -1                  20
# 3                   8                  -1                  13
# 4                   7                  -1                   3
# 5                   9                  -1                   2
# 6                  12                  -1                   7
# 7                  19                  -1                  17
# 8                   7                  -1                  12
# 9                   6                  -1                   1
#
#    GeographicField61A  GeographicField61B  GeographicField62A  \
# 0                  -1                  20                  -1
# 1                  -1                   5                  -1
# 2                  -1                  22                  -1
# 3                  -1                   8                  -1
# 4                  -1                  22                  -1
# 5                  -1                  20                  -1
# 6                  -1                   4                  -1
# 7                  -1                  15                  -1
# 8                  -1                   5                  -1
# 9                  -1                   8                  -1
#
#    GeographicField62B  GeographicField63  GeographicField64
# 0                  25                  Y                 IL
# 1                  21                  N                 NJ
# 2                  11                  N                 NJ
# 3                  21                  N                 TX
# 4                  21                  N                 CA
# 5                   8                  N                 CA
# 6                   8                  N                 IL
# 7                   8                  N                 CA
# 8                   8                  N                 TX
# 9                  13                  N                 TX
#
# [10 rows x 298 columns]

# %%
# Set up the dataframe to capture predictions for Kaggle submission
y_submission_kaggle = pd.DataFrame(columns=['QuoteNumber', 'QuoteConversion_Flag'])
y_submission_kaggle['QuoteNumber'] = X_kaggle_data['QuoteNumber']
y_submission_kaggle.head()
# Out:
#    QuoteNumber QuoteConversion_Flag
# 0            3                  NaN
# 1            5                  NaN
# 2            7                  NaN
# 3            9                  NaN
# 4           10                  NaN

# %%
# Check to see whether the test dataset contains any NaN
null_counts = X_kaggle_data.isnull().sum()
null_counts[null_counts > 0]
# Out:
# PersonalField7         69
# PersonalField84     82812
# PropertyField3         69
# PropertyField4         52
# PropertyField5          1
# PropertyField29    133945
# PropertyField30         1
# PropertyField32        41
# PropertyField34        41
# PropertyField36        67
# PropertyField38       846
# dtype: int64

# %%
print('Total number of NaN in the dataframe: ', X_kaggle_data.isnull().sum().sum())
# Out:
# Total number of NaN in the dataframe:  217944

# %%
# Apply the same data pre-processing steps to the test data
X_kaggle_data.drop(columns=['QuoteNumber','Original_Quote_Date'], inplace=True)
X_kaggle_data.drop(columns=['PersonalField84','PropertyField29'], inplace=True)
X_kaggle_data.drop(columns=['SalesField8'], inplace=True)

# Impute missing attributes with the "majority" value for each attribute
X_kaggle_data['PersonalField7'].fillna('N', inplace=True)
X_kaggle_data['PropertyField3'].fillna('N', inplace=True)
X_kaggle_data['PropertyField4'].fillna('N', inplace=True)
X_kaggle_data['PropertyField5'].fillna('Y', inplace=True)
X_kaggle_data['PropertyField30'].fillna('N', inplace=True)
X_kaggle_data['PropertyField32'].fillna('Y', inplace=True)
X_kaggle_data['PropertyField34'].fillna('Y', inplace=True)
X_kaggle_data['PropertyField36'].fillna('N', inplace=True)
X_kaggle_data['PropertyField38'].fillna('N', inplace=True)

# Correct non-ASCII characters in some attribute columns
X_kaggle_data['PropertyField37'] = X_kaggle_data['PropertyField37'].apply(lambda x: ''.join(["N" if ord(i) < 65 or ord(i) > 90 else i for i in x]))
X_kaggle_data['GeographicField63'] = X_kaggle_data['GeographicField63'].apply(lambda x: ''.join(["N" if ord(i) < 65 or ord(i) > 90 else i for i in x]))

# Correct mis-coding for some features
X_kaggle_data.loc[(X_kaggle_data.PersonalField16 == 'XG'), 'PersonalField16'] = 'OTHER'
X_kaggle_data.loc[(X_kaggle_data.PersonalField16 == 'YG'), 'PersonalField16'] = 'OTHER'
X_kaggle_data.loc[(X_kaggle_data.PersonalField16 == 'ZM'), 'PersonalField16'] = 'OTHER'
X_kaggle_data.loc[(X_kaggle_data.PersonalField17 == 'XF'), 'PersonalField17'] = 'OTHER'
X_kaggle_data.loc[(X_kaggle_data.PersonalField17 == 'XZ'), 'PersonalField17'] = 'OTHER'
X_kaggle_data.loc[(X_kaggle_data.PersonalField17 == 'YO'), 'PersonalField17'] = 'OTHER'
X_kaggle_data.loc[(X_kaggle_data.PersonalField17 == 'ZJ'), 'PersonalField17'] = 'OTHER'
X_kaggle_data.loc[(X_kaggle_data.PersonalField18 == 'XB'), 'PersonalField18'] = 'OTHER'
X_kaggle_data.loc[(X_kaggle_data.PersonalField19 == 'ZS'), 'PersonalField19'] = 'OTHER'
X_kaggle_data.loc[(X_kaggle_data.PropertyField7 == 'T'), 'PropertyField7'] = 'OTHER'

# Convert columns from one data type to another
X_kaggle_data['Field6'] = X_kaggle_data['Field6'].astype('category')
X_kaggle_data['Field10'] = X_kaggle_data['Field10'].str.replace(',','')
X_kaggle_data['Field10'] = X_kaggle_data['Field10'].astype('int')
X_kaggle_data['Field12'] = X_kaggle_data['Field12'].astype('category')
X_kaggle_data['CoverageField8'] = X_kaggle_data['CoverageField8'].astype('category')
X_kaggle_data['CoverageField9'] = X_kaggle_data['CoverageField9'].astype('category')
X_kaggle_data['SalesField7'] = X_kaggle_data['SalesField7'].astype('category')
X_kaggle_data['PersonalField7'] = X_kaggle_data['PersonalField7'].astype('category')
X_kaggle_data['PersonalField16'] = X_kaggle_data['PersonalField16'].astype('category')
X_kaggle_data['PersonalField17'] = X_kaggle_data['PersonalField17'].astype('category')
X_kaggle_data['PersonalField18'] = X_kaggle_data['PersonalField18'].astype('category')
X_kaggle_data['PersonalField19'] = X_kaggle_data['PersonalField19'].astype('category')
X_kaggle_data['PropertyField3'] = X_kaggle_data['PropertyField3'].astype('category')
X_kaggle_data['PropertyField4'] = X_kaggle_data['PropertyField4'].astype('category')
X_kaggle_data['PropertyField5'] = X_kaggle_data['PropertyField5'].astype('category')
X_kaggle_data['PropertyField7'] = X_kaggle_data['PropertyField7'].astype('category')
X_kaggle_data['PropertyField14'] = X_kaggle_data['PropertyField14'].astype('category')
X_kaggle_data['PropertyField28'] = X_kaggle_data['PropertyField28'].astype('category')
X_kaggle_data['PropertyField30'] = X_kaggle_data['PropertyField30'].astype('category')
X_kaggle_data['PropertyField31'] = X_kaggle_data['PropertyField31'].astype('category')
X_kaggle_data['PropertyField32'] = X_kaggle_data['PropertyField32'].astype('category')
X_kaggle_data['PropertyField33'] = X_kaggle_data['PropertyField33'].astype('category')
X_kaggle_data['PropertyField34'] = X_kaggle_data['PropertyField34'].astype('category')
X_kaggle_data['PropertyField36'] = X_kaggle_data['PropertyField36'].astype('category')
X_kaggle_data['PropertyField37'] = X_kaggle_data['PropertyField37'].astype('category')
X_kaggle_data['PropertyField38'] = X_kaggle_data['PropertyField38'].astype('category')
X_kaggle_data['GeographicField63'] = X_kaggle_data['GeographicField63'].astype('category')
X_kaggle_data['GeographicField64'] = X_kaggle_data['GeographicField64'].astype('category')

X_kaggle_data[columns_to_scale] = scaler.fit_transform(X_kaggle_data[columns_to_scale])

X_kaggle_data.head(10)
# Out:
#   Field6  Field7    Field8    Field9   Field10   Field11 Field12  \
# 0      E      16  0.456089  0.055556  1.000000  1.000000       N
# 1      F      11  0.865683  0.944444  0.017039  0.619376       N
# 2      F      15  0.146863  0.944444  0.017039  0.220033       N
# 3      K      21  0.091513  0.000000  0.601704  0.875205       Y
# 4      B      25  0.300369  0.083333  0.412141  0.065681       N
# 5      B      24  0.484871  0.055556  0.444089  0.065681       N
# 6      E      23  0.476753  0.055556  1.000000  1.000000       N
# 7      B      25  0.300369  0.083333  0.412141  0.065681       N
# 8      J      23  0.134317  0.000000  0.601704  0.875205       N
# 9      J      23  0.697417  0.000000  0.657082  0.875205       N
#
#    CoverageField1A  CoverageField1B  CoverageField2A  ...  GeographicField59A  \
# 0                4                4                4  ...                   1
# 1                8               14                8  ...                  10
# 2               11               18               11  ...                  10
# 3               14               22               15  ...                   8
# 4                4                5                4  ...                   7
# 5               11               18               11  ...                   9
# 6                5                6                5  ...                  11
# 7                6                9                6  ...                  15
# 8               12               20               12  ...                   7
# 9                3                3                3  ...                   7
#
#    GeographicField59B  GeographicField60A  GeographicField60B  \
# 0                   1                  -1                   1
# 1                  10                  -1                   5
# 2                  11                  -1                  20
# 3                   8                  -1                  13
# 4                   7                  -1                   3
# 5                   9                  -1                   2
# 6                  12                  -1                   7
# 7                  19                  -1                  17
# 8                   7                  -1                  12
# 9                   6                  -1                   1
#
#    GeographicField61A  GeographicField61B  GeographicField62A  \
# 0                  -1                  20                  -1
# 1                  -1                   5                  -1
# 2                  -1                  22                  -1
# 3                  -1                   8                  -1
# 4                  -1                  22                  -1
# 5                  -1                  20                  -1
# 6                  -1                   4                  -1
# 7                  -1                  15                  -1
# 8                  -1                   5                  -1
# 9                  -1                   8                  -1
#
#    GeographicField62B  GeographicField63 GeographicField64
# 0                  25                  Y                IL
# 1                  21                  N                NJ
# 2                  11                  N                NJ
# 3                  21                  N                TX
# 4                  21                  N                CA
# 5                   8                  N                CA
# 6                   8                  N                IL
# 7                   8                  N                CA
# 8                   8                  N                TX
# 9                  13                  N                TX
#
# [10 rows x 293 columns]

# %%
# Check to see whether the test dataset contains any NaN
null_counts = X_kaggle_data.isnull().sum()
null_counts[null_counts > 0]
# Out:
# Series([], dtype: int64)

# %%
print('Total number of NaN in the dataframe: ', X_kaggle_data.isnull().sum().sum())
# Out:
# Total number of NaN in the dataframe:  0

# %%
# Perform the same pre-processing of the numeric attributes
X_kaggle_data[columns_to_scale] = scaler.fit_transform(X_kaggle_data[columns_to_scale])
X_kaggle_data[columns_to_scale].hist(layout=(dispRow,dispCol))
plt.show()

# %%
# Test the Kaggle dataframe to ensure it has the indentical set of columns with X_original
X_kaggle_data = pd.get_dummies(X_kaggle_data)
X_kaggle_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173836 entries, 0 to 173835
# Data columns (total 580 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Field7                 int64
#  1   Field8                 float64
#  2   Field9                 float64
#  3   Field10                float64
#  4   Field11                float64
#  5   CoverageField1A        int64
#  6   CoverageField1B        int64
#  7   CoverageField2A        int64
#  8   CoverageField2B        int64
#  9   CoverageField3A        int64
#  10  CoverageField3B        int64
#  11  CoverageField4A        int64
#  12  CoverageField4B        int64
#  13  CoverageField5A        int64
#  14  CoverageField5B        int64
#  15  CoverageField6A        int64
#  16  CoverageField6B        int64
#  17  CoverageField11A       int64
#  18  CoverageField11B       int64
#  19  SalesField1A           int64
#  20  SalesField1B           int64
#  21  SalesField2A           int64
#  22  SalesField2B           int64
#  23  SalesField3            int64
#  24  SalesField4            int64
#  25  SalesField5            int64
#  26  SalesField6            int64
#  27  SalesField9            int64
#  28  SalesField10           int64
#  29  SalesField11           int64
#  30  SalesField12           int64
#  31  SalesField13           int64
#  32  SalesField14           int64
#  33  SalesField15           int64
#  34  PersonalField1         int64
#  35  PersonalField2         int64
#  36  PersonalField4A        int64
#  37  PersonalField4B        int64
#  38  PersonalField5         int64
#  39  PersonalField6         int64
#  40  PersonalField8         int64
#  41  PersonalField9         int64
#  42  PersonalField10A       int64
#  43  PersonalField10B       int64
#  44  PersonalField11        int64
#  45  PersonalField12        int64
#  46  PersonalField13        int64
#  47  PersonalField14        int64
#  48  PersonalField15        int64
#  49  PersonalField22        int64
#  50  PersonalField23        int64
#  51  PersonalField24        int64
#  52  PersonalField25        int64
#  53  PersonalField26        int64
#  54  PersonalField27        int64
#  55  PersonalField28        int64
#  56  PersonalField29        int64
#  57  PersonalField30        int64
#  58  PersonalField31        int64
#  59  PersonalField32        int64
#  60  PersonalField33        int64
#  61  PersonalField34        int64
#  62  PersonalField35        int64
#  63  PersonalField36        int64
#  64  PersonalField37        int64
#  65  PersonalField38        int64
#  66  PersonalField39        int64
#  67  PersonalField40        int64
#  68  PersonalField41        int64
#  69  PersonalField42        int64
#  70  PersonalField43        int64
#  71  PersonalField44        int64
#  72  PersonalField45        int64
#  73  PersonalField46        int64
#  74  PersonalField47        int64
#  75  PersonalField48        int64
#  76  PersonalField49        int64
#  77  PersonalField50        int64
#  78  PersonalField51        int64
#  79  PersonalField52        int64
#  80  PersonalField53        int64
#  81  PersonalField54        int64
#  82  PersonalField55        int64
#  83  PersonalField56        int64
#  84  PersonalField57        int64
#  85  PersonalField58        int64
#  86  PersonalField59        int64
#  87  PersonalField60        int64
#  88  PersonalField61        int64
#  89  PersonalField62        int64
#  90  PersonalField63        int64
#  91  PersonalField64        int64
#  92  PersonalField65        int64
#  93  PersonalField66        int64
#  94  PersonalField67        int64
#  95  PersonalField68        int64
#  96  PersonalField69        int64
#  97  PersonalField70        int64
#  98  PersonalField71        int64
#  99  PersonalField72        int64
#  100 PersonalField73        int64
#  101 PersonalField74        int64
#  102 PersonalField75        int64
#  103 PersonalField76        int64
#  104 PersonalField77        int64
#  105 PersonalField78        int64
#  106 PersonalField79        int64
#  107 PersonalField80        int64
#  108 PersonalField81        int64
#  109 PersonalField82        int64
#  110 PersonalField83        int64
#  111 PropertyField1A        int64
#  112 PropertyField1B        int64
#  113 PropertyField2A        int64
#  114 PropertyField2B        int64
#  115 PropertyField6         int64
#  116 PropertyField8         int64
#  117 PropertyField9         int64
#  118 PropertyField10        int64
#  119 PropertyField11A       int64
#  120 PropertyField11B       int64
#  121 PropertyField12        int64
#  122 PropertyField13        int64
#  123 PropertyField15        int64
#  124 PropertyField16A       int64
#  125 PropertyField16B       int64
#  126 PropertyField17        int64
#  127 PropertyField18        int64
#  128 PropertyField19        int64
#  129 PropertyField20        int64
#  130 PropertyField21A       int64
#  131 PropertyField21B       int64
#  132 PropertyField22        int64
#  133 PropertyField23        int64
#  134 PropertyField24A       int64
#  135 PropertyField24B       int64
#  136 PropertyField25        float64
#  137 PropertyField26A       int64
#  138 PropertyField26B       int64
#  139 PropertyField27        int64
#  140 PropertyField35        int64
#  141 PropertyField39A       int64
#  142 PropertyField39B       int64
#  143 GeographicField1A      int64
#  144 GeographicField1B      int64
#  145 GeographicField2A      int64
#  146 GeographicField2B      int64
#  147 GeographicField3A      int64
#  148 GeographicField3B      int64
#  149 GeographicField4A      int64
#  150 GeographicField4B      int64
#  151 GeographicField5A      int64
#  152 GeographicField5B      int64
#  153 GeographicField6A      int64
#  154 GeographicField6B      int64
#  155 GeographicField7A      int64
#  156 GeographicField7B      int64
#  157 GeographicField8A      int64
#  158 GeographicField8B      int64
#  159 GeographicField9A      int64
#  160 GeographicField9B      int64
#  161 GeographicField10A     int64
#  162 GeographicField10B     int64
#  163 GeographicField11A     int64
#  164 GeographicField11B     int64
#  165 GeographicField12A     int64
#  166 GeographicField12B     int64
#  167 GeographicField13A     int64
#  168 GeographicField13B     int64
#  169 GeographicField14A     int64
#  170 GeographicField14B     int64
#  171 GeographicField15A     int64
#  172 GeographicField15B     int64
#  173 GeographicField16A     int64
#  174 GeographicField16B     int64
#  175 GeographicField17A     int64
#  176 GeographicField17B     int64
#  177 GeographicField18A     int64
#  178 GeographicField18B     int64
#  179 GeographicField19A     int64
#  180 GeographicField19B     int64
#  181 GeographicField20A     int64
#  182 GeographicField20B     int64
#  183 GeographicField21A     int64
#  184 GeographicField21B     int64
#  185 GeographicField22A     int64
#  186 GeographicField22B     int64
#  187 GeographicField23A     int64
#  188 GeographicField23B     int64
#  189 GeographicField24A     int64
#  190 GeographicField24B     int64
#  191 GeographicField25A     int64
#  192 GeographicField25B     int64
#  193 GeographicField26A     int64
#  194 GeographicField26B     int64
#  195 GeographicField27A     int64
#  196 GeographicField27B     int64
#  197 GeographicField28A     int64
#  198 GeographicField28B     int64
#  199 GeographicField29A     int64
#  200 GeographicField29B     int64
#  201 GeographicField30A     int64
#  202 GeographicField30B     int64
#  203 GeographicField31A     int64
#  204 GeographicField31B     int64
#  205 GeographicField32A     int64
#  206 GeographicField32B     int64
#  207 GeographicField33A     int64
#  208 GeographicField33B     int64
#  209 GeographicField34A     int64
#  210 GeographicField34B     int64
#  211 GeographicField35A     int64
#  212 GeographicField35B     int64
#  213 GeographicField36A     int64
#  214 GeographicField36B     int64
#  215 GeographicField37A     int64
#  216 GeographicField37B     int64
#  217 GeographicField38A     int64
#  218 GeographicField38B     int64
#  219 GeographicField39A     int64
#  220 GeographicField39B     int64
#  221 GeographicField40A     int64
#  222 GeographicField40B     int64
#  223 GeographicField41A     int64
#  224 GeographicField41B     int64
#  225 GeographicField42A     int64
#  226 GeographicField42B     int64
#  227 GeographicField43A     int64
#  228 GeographicField43B     int64
#  229 GeographicField44A     int64
#  230 GeographicField44B     int64
#  231 GeographicField45A     int64
#  232 GeographicField45B     int64
#  233 GeographicField46A     int64
#  234 GeographicField46B     int64
#  235 GeographicField47A     int64
#  236 GeographicField47B     int64
#  237 GeographicField48A     int64
#  238 GeographicField48B     int64
#  239 GeographicField49A     int64
#  240 GeographicField49B     int64
#  241 GeographicField50A     int64
#  242 GeographicField50B     int64
#  243 GeographicField51A     int64
#  244 GeographicField51B     int64
#  245 GeographicField52A     int64
#  246 GeographicField52B     int64
#  247 GeographicField53A     int64
#  248 GeographicField53B     int64
#  249 GeographicField54A     int64
#  250 GeographicField54B     int64
#  251 GeographicField55A     int64
#  252 GeographicField55B     int64
#  253 GeographicField56A     int64
#  254 GeographicField56B     int64
#  255 GeographicField57A     int64
#  256 GeographicField57B     int64
#  257 GeographicField58A     int64
#  258 GeographicField58B     int64
#  259 GeographicField59A     int64
#  260 GeographicField59B     int64
#  261 GeographicField60A     int64
#  262 GeographicField60B     int64
#  263 GeographicField61A     int64
#  264 GeographicField61B     int64
#  265 GeographicField62A     int64
#  266 GeographicField62B     int64
#  267 Field6_A               uint8
#  268 Field6_B               uint8
#  269 Field6_C               uint8
#  270 Field6_D               uint8
#  271 Field6_E               uint8
#  272 Field6_F               uint8
#  273 Field6_J               uint8
#  274 Field6_K               uint8
#  275 Field12_N              uint8
#  276 Field12_Y              uint8
#  277 CoverageField8_T       uint8
#  278 CoverageField8_U       uint8
#  279 CoverageField8_V       uint8
#  280 CoverageField8_W       uint8
#  281 CoverageField8_X       uint8
#  282 CoverageField8_Y       uint8
#  283 CoverageField8_Z       uint8
#  284 CoverageField9_A       uint8
#  285 CoverageField9_B       uint8
#  286 CoverageField9_C       uint8
#  287 CoverageField9_D       uint8
#  288 CoverageField9_E       uint8
#  289 CoverageField9_F       uint8
#  290 CoverageField9_G       uint8
#  291 CoverageField9_H       uint8
#  292 CoverageField9_I       uint8
#  293 CoverageField9_J       uint8
#  294 CoverageField9_K       uint8
#  295 CoverageField9_L       uint8
#  296 SalesField7_K          uint8
#  297 SalesField7_M          uint8
#  298 SalesField7_P          uint8
#  299 SalesField7_Q          uint8
#  300 SalesField7_R          uint8
#  301 SalesField7_T          uint8
#  302 SalesField7_V          uint8
#  303 PersonalField7_N       uint8
#  304 PersonalField7_Y       uint8
#  305 PersonalField16_OTHER  uint8
#  306 PersonalField16_XB     uint8
#  307 PersonalField16_XC     uint8
#  308 PersonalField16_XD     uint8
#  309 PersonalField16_XE     uint8
#  310 PersonalField16_XF     uint8
#  311 PersonalField16_XH     uint8
#  312 PersonalField16_XI     uint8
#  313 PersonalField16_XJ     uint8
#  314 PersonalField16_XK     uint8
#  315 PersonalField16_XL     uint8
#  316 PersonalField16_XM     uint8
#  317 PersonalField16_XO     uint8
#  318 PersonalField16_XP     uint8
#  319 PersonalField16_XQ     uint8
#  320 PersonalField16_XR     uint8
#  321 PersonalField16_XS     uint8
#  322 PersonalField16_XT     uint8
#  323 PersonalField16_XV     uint8
#  324 PersonalField16_XW     uint8
#  325 PersonalField16_XX     uint8
#  326 PersonalField16_XZ     uint8
#  327 PersonalField16_YE     uint8
#  328 PersonalField16_YF     uint8
#  329 PersonalField16_YH     uint8
#  330 PersonalField16_YI     uint8
#  331 PersonalField16_ZA     uint8
#  332 PersonalField16_ZB     uint8
#  333 PersonalField16_ZC     uint8
#  334 PersonalField16_ZD     uint8
#  335 PersonalField16_ZE     uint8
#  336 PersonalField16_ZF     uint8
#  337 PersonalField16_ZG     uint8
#  338 PersonalField16_ZH     uint8
#  339 PersonalField16_ZI     uint8
#  340 PersonalField16_ZJ     uint8
#  341 PersonalField16_ZK     uint8
#  342 PersonalField16_ZN     uint8
#  343 PersonalField16_ZR     uint8
#  344 PersonalField16_ZT     uint8
#  345 PersonalField16_ZU     uint8
#  346 PersonalField16_ZW     uint8
#  347 PersonalField17_OTHER  uint8
#  348 PersonalField17_XB     uint8
#  349 PersonalField17_XC     uint8
#  350 PersonalField17_XD     uint8
#  351 PersonalField17_XE     uint8
#  352 PersonalField17_XG     uint8
#  353 PersonalField17_XH     uint8
#  354 PersonalField17_XI     uint8
#  355 PersonalField17_XK     uint8
#  356 PersonalField17_XL     uint8
#  357 PersonalField17_XM     uint8
#  358 PersonalField17_XN     uint8
#  359 PersonalField17_XQ     uint8
#  360 PersonalField17_XR     uint8
#  361 PersonalField17_XS     uint8
#  362 PersonalField17_XT     uint8
#  363 PersonalField17_XU     uint8
#  364 PersonalField17_XV     uint8
#  365 PersonalField17_XW     uint8
#  366 PersonalField17_XX     uint8
#  367 PersonalField17_YE     uint8
#  368 PersonalField17_YF     uint8
#  369 PersonalField17_YG     uint8
#  370 PersonalField17_YH     uint8
#  371 PersonalField17_YI     uint8
#  372 PersonalField17_YJ     uint8
#  373 PersonalField17_YK     uint8
#  374 PersonalField17_YL     uint8
#  375 PersonalField17_YM     uint8
#  376 PersonalField17_YN     uint8
#  377 PersonalField17_YQ     uint8
#  378 PersonalField17_YR     uint8
#  379 PersonalField17_YS     uint8
#  380 PersonalField17_YT     uint8
#  381 PersonalField17_YU     uint8
#  382 PersonalField17_YV     uint8
#  383 PersonalField17_YW     uint8
#  384 PersonalField17_YX     uint8
#  385 PersonalField17_YY     uint8
#  386 PersonalField17_YZ     uint8
#  387 PersonalField17_ZA     uint8
#  388 PersonalField17_ZB     uint8
#  389 PersonalField17_ZC     uint8
#  390 PersonalField17_ZD     uint8
#  391 PersonalField17_ZE     uint8
#  392 PersonalField17_ZF     uint8
#  393 PersonalField17_ZG     uint8
#  394 PersonalField17_ZH     uint8
#  395 PersonalField17_ZI     uint8
#  396 PersonalField17_ZK     uint8
#  397 PersonalField17_ZL     uint8
#  398 PersonalField17_ZM     uint8
#  399 PersonalField17_ZN     uint8
#  400 PersonalField17_ZO     uint8
#  401 PersonalField17_ZP     uint8
#  402 PersonalField17_ZQ     uint8
#  403 PersonalField17_ZS     uint8
#  404 PersonalField17_ZT     uint8
#  405 PersonalField17_ZU     uint8
#  406 PersonalField17_ZV     uint8
#  407 PersonalField17_ZW     uint8
#  408 PersonalField18_OTHER  uint8
#  409 PersonalField18_XC     uint8
#  410 PersonalField18_XD     uint8
#  411 PersonalField18_XE     uint8
#  412 PersonalField18_XF     uint8
#  413 PersonalField18_XG     uint8
#  414 PersonalField18_XI     uint8
#  415 PersonalField18_XJ     uint8
#  416 PersonalField18_XK     uint8
#  417 PersonalField18_XL     uint8
#  418 PersonalField18_XM     uint8
#  419 PersonalField18_XN     uint8
#  420 PersonalField18_XO     uint8
#  421 PersonalField18_XP     uint8
#  422 PersonalField18_XQ     uint8
#  423 PersonalField18_XR     uint8
#  424 PersonalField18_XS     uint8
#  425 PersonalField18_XT     uint8
#  426 PersonalField18_XU     uint8
#  427 PersonalField18_XW     uint8
#  428 PersonalField18_XX     uint8
#  429 PersonalField18_XY     uint8
#  430 PersonalField18_XZ     uint8
#  431 PersonalField18_YE     uint8
#  432 PersonalField18_YF     uint8
#  433 PersonalField18_YG     uint8
#  434 PersonalField18_YH     uint8
#  435 PersonalField18_YI     uint8
#  436 PersonalField18_YJ     uint8
#  437 PersonalField18_YK     uint8
#  438 PersonalField18_YL     uint8
#  439 PersonalField18_YM     uint8
#  440 PersonalField18_YN     uint8
#  441 PersonalField18_YO     uint8
#  442 PersonalField18_YP     uint8
#  443 PersonalField18_YQ     uint8
#  444 PersonalField18_YR     uint8
#  445 PersonalField18_ZA     uint8
#  446 PersonalField18_ZB     uint8
#  447 PersonalField18_ZC     uint8
#  448 PersonalField18_ZD     uint8
#  449 PersonalField18_ZE     uint8
#  450 PersonalField18_ZF     uint8
#  451 PersonalField18_ZH     uint8
#  452 PersonalField18_ZJ     uint8
#  453 PersonalField18_ZK     uint8
#  454 PersonalField18_ZL     uint8
#  455 PersonalField18_ZM     uint8
#  456 PersonalField18_ZN     uint8
#  457 PersonalField18_ZO     uint8
#  458 PersonalField18_ZP     uint8
#  459 PersonalField18_ZQ     uint8
#  460 PersonalField18_ZR     uint8
#  461 PersonalField18_ZS     uint8
#  462 PersonalField18_ZT     uint8
#  463 PersonalField18_ZU     uint8
#  464 PersonalField18_ZV     uint8
#  465 PersonalField18_ZW     uint8
#  466 PersonalField19_OTHER  uint8
#  467 PersonalField19_XB     uint8
#  468 PersonalField19_XC     uint8
#  469 PersonalField19_XD     uint8
#  470 PersonalField19_XE     uint8
#  471 PersonalField19_XF     uint8
#  472 PersonalField19_XG     uint8
#  473 PersonalField19_XH     uint8
#  474 PersonalField19_XI     uint8
#  475 PersonalField19_XJ     uint8
#  476 PersonalField19_XK     uint8
#  477 PersonalField19_XM     uint8
#  478 PersonalField19_XN     uint8
#  479 PersonalField19_XO     uint8
#  480 PersonalField19_XP     uint8
#  481 PersonalField19_XQ     uint8
#  482 PersonalField19_XR     uint8
#  483 PersonalField19_XS     uint8
#  484 PersonalField19_XT     uint8
#  485 PersonalField19_XU     uint8
#  486 PersonalField19_XV     uint8
#  487 PersonalField19_XW     uint8
#  488 PersonalField19_XX     uint8
#  489 PersonalField19_XY     uint8
#  490 PersonalField19_XZ     uint8
#  491 PersonalField19_YE     uint8
#  492 PersonalField19_YF     uint8
#  493 PersonalField19_YG     uint8
#  494 PersonalField19_YH     uint8
#  495 PersonalField19_YJ     uint8
#  496 PersonalField19_YK     uint8
#  497 PersonalField19_YL     uint8
#  498 PersonalField19_YM     uint8
#  499 PersonalField19_YN     uint8
#  500 PersonalField19_ZA     uint8
#  501 PersonalField19_ZB     uint8
#  502 PersonalField19_ZD     uint8
#  503 PersonalField19_ZE     uint8
#  504 PersonalField19_ZF     uint8
#  505 PersonalField19_ZG     uint8
#  506 PersonalField19_ZH     uint8
#  507 PersonalField19_ZI     uint8
#  508 PersonalField19_ZJ     uint8
#  509 PersonalField19_ZK     uint8
#  510 PersonalField19_ZL     uint8
#  511 PersonalField19_ZM     uint8
#  512 PersonalField19_ZN     uint8
#  513 PersonalField19_ZO     uint8
#  514 PersonalField19_ZP     uint8
#  515 PersonalField19_ZQ     uint8
#  516 PersonalField19_ZR     uint8
#  517 PersonalField19_ZT     uint8
#  518 PersonalField19_ZU     uint8
#  519 PersonalField19_ZV     uint8
#  520 PersonalField19_ZW     uint8
#  521 PropertyField3_N       uint8
#  522 PropertyField3_Y       uint8
#  523 PropertyField4_N       uint8
#  524 PropertyField4_Y       uint8
#  525 PropertyField5_N       uint8
#  526 PropertyField5_Y       uint8
#  527 PropertyField7_A       uint8
#  528 PropertyField7_C       uint8
#  529 PropertyField7_D       uint8
#  530 PropertyField7_E       uint8
#  531 PropertyField7_F       uint8
#  532 PropertyField7_G       uint8
#  533 PropertyField7_H       uint8
#  534 PropertyField7_I       uint8
#  535 PropertyField7_J       uint8
#  536 PropertyField7_K       uint8
#  537 PropertyField7_L       uint8
#  538 PropertyField7_M       uint8
#  539 PropertyField7_N       uint8
#  540 PropertyField7_O       uint8
#  541 PropertyField7_OTHER   uint8
#  542 PropertyField7_P       uint8
#  543 PropertyField7_Q       uint8
#  544 PropertyField7_R       uint8
#  545 PropertyField7_S       uint8
#  546 PropertyField14_A      uint8
#  547 PropertyField14_B      uint8
#  548 PropertyField14_C      uint8
#  549 PropertyField14_D      uint8
#  550 PropertyField28_A      uint8
#  551 PropertyField28_B      uint8
#  552 PropertyField28_C      uint8
#  553 PropertyField28_D      uint8
#  554 PropertyField30_N      uint8
#  555 PropertyField30_Y      uint8
#  556 PropertyField31_K      uint8
#  557 PropertyField31_M      uint8
#  558 PropertyField31_N      uint8
#  559 PropertyField31_O      uint8
#  560 PropertyField32_N      uint8
#  561 PropertyField32_Y      uint8
#  562 PropertyField33_E      uint8
#  563 PropertyField33_F      uint8
#  564 PropertyField33_G      uint8
#  565 PropertyField33_H      uint8
#  566 PropertyField34_N      uint8
#  567 PropertyField34_Y      uint8
#  568 PropertyField36_N      uint8
#  569 PropertyField36_Y      uint8
#  570 PropertyField37_N      uint8
#  571 PropertyField37_Y      uint8
#  572 PropertyField38_N      uint8
#  573 PropertyField38_Y      uint8
#  574 GeographicField63_N    uint8
#  575 GeographicField63_Y    uint8
#  576 GeographicField64_CA   uint8
#  577 GeographicField64_IL   uint8
#  578 GeographicField64_NJ   uint8
#  579 GeographicField64_TX   uint8
# dtypes: float64(5), int64(262), uint8(313)
# memory usage: 406.0 MB

# %%
columns_original = X_original.columns.tolist()
columns_kaggle = X_kaggle_data.columns.tolist()
print('Attributes in the training data frame but not in the Kaggle test data frame:')
set(columns_original).difference(set(columns_kaggle))
# Out:
# Attributes in the training data frame but not in the Kaggle test data frame:
# set()

# %%
print('Attributes in the Kaggle test data frame but not in the training data frame:')
set(columns_kaggle).difference(set(columns_original))
# Out:
# Attributes in the Kaggle test data frame but not in the training data frame:
# set()

# %%
# Convert the dataframe to numpy array before the final prediction step
X_test_kaggle = X_kaggle_data.to_numpy()
print("X_test_kaggle.shape: {}".format(X_test_kaggle.shape))
# Out:
# X_test_kaggle.shape: (173836, 580)

# %%
predictions_kaggle = final_model.predict_proba(X_test_kaggle)[:,1]
y_submission_kaggle['QuoteConversion_Flag'] = predictions_kaggle
print("y_submission_kaggle.shape: {}".format(y_submission_kaggle.shape))
# Out:
# y_submission_kaggle.shape: (173836, 2)

# %%
# Mount Google Drive locally for storing files
# from google.colab import drive
# drive.mount('/content/gdrive')
# gdrivePrefix = '/content/gdrive/My Drive/Colab_Downloads/'

# %%
submission_file = y_submission_kaggle.to_csv(header=True, index=False)
filename = 'submission_' + datetime.now().strftime('%Y%m%d-%H%M') + '.csv'
with open(filename, 'w') as f:
    f.write(submission_file)
    print('Completed writing output file: ' + filename)
# Out:
# Completed writing output file: submission_20200514-0034.csv

# %%
if notifyStatus: email_notify("Model Validation and Final Model Creation completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
print ('Total time for the script:',(datetime.now() - startTimeScript))
# Out:
# Total time for the script: 1 day, 7:25:22.406134
