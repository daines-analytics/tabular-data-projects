# %% [markdown]
# # Binary Classification Model for Springleaf Marketing Response Using Python Take 2
# ### David Lowe
# ### March 17, 2020
#
# Template Credit: Adapted from a template made available by Dr. Jason Brownlee of Machine Learning Mastery. [https://machinelearningmastery.com/]
#
# SUMMARY: The purpose of this project is to construct a predictive model using various machine learning algorithms and to document the end-to-end steps using a template. The Springleaf Marketing Response dataset is a binary classification situation where we are trying to predict one of the two possible outcomes.
#
# INTRODUCTION: Springleaf leverages the direct mail method for connecting with customers who may need a loan. To improve their targeting efforts, Springleaf must be sure they are focusing on the customers who are likely to respond and be good candidates for their services. Using a dataset with a broad set of anonymized features, Springleaf is looking to predict which customers will respond to a direct mail offer.
#
# In iteration Take1, we constructed several traditional machine learning models using the linear, non-linear, and ensemble techniques. We also observed the best ROC-AUC result that we could obtain with each of these models.
#
# In this Take2 iteration, we will construct and tune an XGBoost machine learning model for this dataset. We will observe the best ROC-AUC result that we can obtain with the XGBoost model.
#
# ANALYSIS: In iteration Take1, the baseline performance of the machine learning algorithms achieved an average ROC-AUC of 70.42%. The Random Forest and Gradient Boosting Machine algorithms made the top ROC-AUC metrics after the first round of modeling. After a series of tuning trials, GBM turned in an overall ROC-AUC result of 77.96%. When we apply the tuned GBM algorithm to the test dataset, we obtained a ROC-AUC score of only 62.58%, which was much lower than the score from model training.
#
# In this Take2 iteration, the XGBoost algorithm achieved a baseline ROC-AUC performance of 77.08%. After a series of tuning trials, XGBoost turned in an overall best ROC-AUC result of 78.23%. When we apply the tuned XGBoost algorithm to the test dataset, we obtained a ROC-AUC score of only 62.86%, which was much lower than the score from model training.
#
# CONCLUSION: For this iteration, the XGBoost algorithm achieved a ROC-AUC result with high variance using the training and test datasets. For this dataset, we should consider doing more modeling and tuning with the XGBoost and other algorithms.
#
# Dataset Used: Springleaf Marketing Response Data Set
#
# Dataset ML Model: Binary classification with numerical and categorical attributes
#
# Dataset Reference: https://www.kaggle.com/c/springleaf-marketing-response/data
#
# One potential source of performance benchmark: https://www.kaggle.com/c/springleaf-marketing-response/leaderboard
#
# The project aims to touch on the following areas:
#
# * Document a predictive modeling problem end-to-end.
# * Explore data cleaning and transformation options
# * Explore non-ensemble and ensemble algorithms for baseline model performance
# * Explore algorithm tuning techniques for improving model performance
#
# Any predictive modeling machine learning project genrally can be broken down into about six major tasks:
#
# 1. Prepare Environment
# 2. Summarize Data
# 3. Prepare Data
# 4. Model and Evaluate Algorithms
# 5. Improve Accuracy or Results
# 6. Finalize Model and Present Results

# %% [markdown]
# ## Section 1 - Prepare Environment

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Wed Mar 11 14:09:17 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.59       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('To enable a high-RAM runtime, select the Runtime → "Change runtime type"')
  print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
  print('re-execute this cell.')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.4 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %% [markdown]
# ### 1.a) Load libraries and modules

# %%
# Set the random seed number for reproducible results
seedNum = 888

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import os
import sys
import shutil
import urllib.request
import zipfile
import smtplib
import re
from datetime import datetime
from email.message import EmailMessage
from pandas.plotting import scatter_matrix
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import RFE
from imblearn.over_sampling import SMOTE
from imblearn.combine import SMOTEENN
from imblearn.combine import SMOTETomek

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
from imblearn.ensemble import RUSBoostClassifier
from imblearn.ensemble import BalancedBaggingClassifier
from xgboost import XGBClassifier
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.ensemble.bagging module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.ensemble.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.ensemble.forest module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ### 1.b) Set up the controlling parameters and functions

# %%
# Begin the timer for the script processing
startTimeScript = datetime.now()

# Set up the number of CPU cores available for multi-thread processing
n_jobs = 1

# Set up the flag to stop sending progress emails (setting to True will send status emails!)
notifyStatus = False

# Set the flag for splitting the dataset
splitDataset = True
splitPercentage = 0.15

# Set the number of folds for cross validation
n_folds = 5

# Set various default modeling parameters
# scoring = 'accuracy'
scoring = 'roc_auc'

# Set various Pandas options
pd.set_option('display.max_rows', 9999)

# %%
# Set up the email notification function
def email_notify(msg_text):
    sender = os.environ.get('MAIL_SENDER')
    receiver = os.environ.get('MAIL_RECEIVER')
    gateway = os.environ.get('SMTP_GATEWAY')
    smtpuser = os.environ.get('SMTP_USERNAME')
    password = os.environ.get('SMTP_PASSWORD')
    if sender==None or receiver==None or gateway==None or smtpuser==None or password==None:
        sys.exit("Incomplete email setup info. Script Processing Aborted!!!")
    msg = EmailMessage()
    msg.set_content(msg_text)
    msg['Subject'] = 'Notification from Python Binary Classification Script'
    msg['From'] = sender
    msg['To'] = receiver
    server = smtplib.SMTP(gateway, 587)
    server.starttls()
    server.login(smtpuser, password)
    server.send_message(msg)
    server.quit()

# %%
if (notifyStatus): email_notify("Library and Data Loading has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 1.c) Load dataset

# %%
dataset_path = 'https://dainesanalytics.com/datasets/kaggle-springleaf-marketing-response/train.csv'
Xy_original = pd.read_csv(dataset_path, sep=',', na_values=["NA"," [] ",""], true_values=["true"], false_values=["false"])

# Take a peek at the dataframe after import
Xy_original.head(10)
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (8,9,10,11,12,43,157,196,214,225,228,229,231,235,238) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    ID VAR_0001  VAR_0002  VAR_0003  ...  VAR_1932 VAR_1933  VAR_1934  target
# 0   2        H       224         0  ...      9998     9998      IAPS       0
# 1   4        H         7        53  ...      9998     9998      IAPS       0
# 2   5        H       116         3  ...      9998     9998      IAPS       0
# 3   7        H       240       300  ...      9998     9998       RCC       0
# 4   8        R        72       261  ...      9998     9998    BRANCH       1
# 5  14        R         4         4  ...      9998     9998      IAPS       0
# 6  16        H        60       132  ...      9996       76      IAPS       1
# 7  20        R        13        75  ...      9998     9998      IAPS       0
# 8  21        R        17        16  ...      9996       90    MOBILE       1
# 9  22        R        24        72  ...      9998     9998    BRANCH       0
#
# [10 rows x 1934 columns]

# %%
Xy_original.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145231 entries, 0 to 145230
# Data columns (total 1934 columns):
# ID          int64
# VAR_0001    object
# VAR_0002    int64
# VAR_0003    int64
# VAR_0004    int64
# VAR_0005    object
# VAR_0006    float64
# VAR_0007    float64
# VAR_0008    object
# VAR_0009    object
# VAR_0010    object
# VAR_0011    object
# VAR_0012    object
# VAR_0013    float64
# VAR_0014    float64
# VAR_0015    float64
# VAR_0016    float64
# VAR_0017    float64
# VAR_0018    float64
# VAR_0019    float64
# VAR_0020    float64
# VAR_0021    float64
# VAR_0022    float64
# VAR_0023    float64
# VAR_0024    float64
# VAR_0025    float64
# VAR_0026    float64
# VAR_0027    float64
# VAR_0028    float64
# VAR_0029    float64
# VAR_0030    float64
# VAR_0031    float64
# VAR_0032    float64
# VAR_0033    float64
# VAR_0034    float64
# VAR_0035    float64
# VAR_0036    float64
# VAR_0037    float64
# VAR_0038    float64
# VAR_0039    float64
# VAR_0040    float64
# VAR_0041    float64
# VAR_0042    float64
# VAR_0043    object
# VAR_0044    object
# VAR_0045    float64
# VAR_0046    float64
# VAR_0047    float64
# VAR_0048    float64
# VAR_0049    float64
# VAR_0050    float64
# VAR_0051    float64
# VAR_0052    float64
# VAR_0053    float64
# VAR_0054    float64
# VAR_0055    float64
# VAR_0056    float64
# VAR_0057    float64
# VAR_0058    float64
# VAR_0059    float64
# VAR_0060    float64
# VAR_0061    float64
# VAR_0062    float64
# VAR_0063    float64
# VAR_0064    float64
# VAR_0065    float64
# VAR_0066    float64
# VAR_0067    float64
# VAR_0068    float64
# VAR_0069    float64
# VAR_0070    float64
# VAR_0071    float64
# VAR_0072    float64
# VAR_0073    object
# VAR_0074    float64
# VAR_0075    object
# VAR_0076    float64
# VAR_0077    float64
# VAR_0078    float64
# VAR_0079    float64
# VAR_0080    float64
# VAR_0081    float64
# VAR_0082    float64
# VAR_0083    float64
# VAR_0084    float64
# VAR_0085    float64
# VAR_0086    float64
# VAR_0087    float64
# VAR_0088    float64
# VAR_0089    float64
# VAR_0090    float64
# VAR_0091    float64
# VAR_0092    float64
# VAR_0093    float64
# VAR_0094    float64
# VAR_0095    float64
# VAR_0096    float64
# VAR_0097    float64
# VAR_0098    float64
# VAR_0099    float64
# VAR_0100    float64
# VAR_0101    float64
# VAR_0102    float64
# VAR_0103    float64
# VAR_0104    float64
# VAR_0105    float64
# VAR_0106    float64
# VAR_0107    float64
# VAR_0108    float64
# VAR_0109    float64
# VAR_0110    float64
# VAR_0111    float64
# VAR_0112    float64
# VAR_0113    float64
# VAR_0114    float64
# VAR_0115    float64
# VAR_0116    float64
# VAR_0117    float64
# VAR_0118    float64
# VAR_0119    float64
# VAR_0120    float64
# VAR_0121    float64
# VAR_0122    float64
# VAR_0123    float64
# VAR_0124    float64
# VAR_0125    float64
# VAR_0126    float64
# VAR_0127    float64
# VAR_0128    float64
# VAR_0129    float64
# VAR_0130    float64
# VAR_0131    float64
# VAR_0132    float64
# VAR_0133    float64
# VAR_0134    float64
# VAR_0135    float64
# VAR_0136    float64
# VAR_0137    float64
# VAR_0138    float64
# VAR_0139    float64
# VAR_0140    float64
# VAR_0141    float64
# VAR_0142    float64
# VAR_0143    float64
# VAR_0144    float64
# VAR_0145    float64
# VAR_0146    float64
# VAR_0147    float64
# VAR_0148    float64
# VAR_0149    float64
# VAR_0150    float64
# VAR_0151    float64
# VAR_0152    float64
# VAR_0153    float64
# VAR_0154    float64
# VAR_0155    float64
# VAR_0156    object
# VAR_0157    object
# VAR_0158    object
# VAR_0159    object
# VAR_0160    float64
# VAR_0161    float64
# VAR_0162    float64
# VAR_0163    float64
# VAR_0164    float64
# VAR_0165    float64
# VAR_0166    object
# VAR_0167    object
# VAR_0168    object
# VAR_0169    object
# VAR_0170    float64
# VAR_0171    float64
# VAR_0172    float64
# VAR_0173    float64
# VAR_0174    float64
# VAR_0175    float64
# VAR_0176    object
# VAR_0177    object
# VAR_0178    object
# VAR_0179    object
# VAR_0180    float64
# VAR_0181    float64
# VAR_0182    float64
# VAR_0183    float64
# VAR_0184    float64
# VAR_0185    float64
# VAR_0186    float64
# VAR_0187    float64
# VAR_0188    float64
# VAR_0189    float64
# VAR_0190    float64
# VAR_0191    float64
# VAR_0192    float64
# VAR_0193    float64
# VAR_0194    float64
# VAR_0195    float64
# VAR_0196    object
# VAR_0197    float64
# VAR_0198    float64
# VAR_0199    float64
# VAR_0200    object
# VAR_0201    float64
# VAR_0202    object
# VAR_0203    float64
# VAR_0204    object
# VAR_0205    float64
# VAR_0206    float64
# VAR_0207    float64
# VAR_0208    float64
# VAR_0209    float64
# VAR_0210    float64
# VAR_0211    float64
# VAR_0212    float64
# VAR_0213    float64
# VAR_0214    object
# VAR_0215    float64
# VAR_0216    object
# VAR_0217    object
# VAR_0219    float64
# VAR_0220    float64
# VAR_0221    float64
# VAR_0222    object
# VAR_0223    float64
# VAR_0224    float64
# VAR_0225    float64
# VAR_0226    object
# VAR_0227    float64
# VAR_0228    float64
# VAR_0229    object
# VAR_0230    object
# VAR_0231    float64
# VAR_0232    object
# VAR_0233    float64
# VAR_0234    float64
# VAR_0235    float64
# VAR_0236    object
# VAR_0237    object
# VAR_0238    float64
# VAR_0239    object
# VAR_0241    float64
# VAR_0242    float64
# VAR_0243    float64
# VAR_0244    float64
# VAR_0245    float64
# VAR_0246    float64
# VAR_0247    float64
# VAR_0248    float64
# VAR_0249    float64
# VAR_0250    float64
# VAR_0251    float64
# VAR_0252    float64
# VAR_0253    float64
# VAR_0254    float64
# VAR_0255    float64
# VAR_0256    float64
# VAR_0257    float64
# VAR_0258    float64
# VAR_0259    float64
# VAR_0260    float64
# VAR_0261    float64
# VAR_0262    float64
# VAR_0263    float64
# VAR_0264    float64
# VAR_0265    float64
# VAR_0266    float64
# VAR_0267    float64
# VAR_0268    float64
# VAR_0269    float64
# VAR_0270    float64
# VAR_0271    float64
# VAR_0272    float64
# VAR_0273    float64
# VAR_0274    object
# VAR_0275    float64
# VAR_0276    float64
# VAR_0277    float64
# VAR_0278    float64
# VAR_0279    float64
# VAR_0280    float64
# VAR_0281    float64
# VAR_0282    float64
# VAR_0283    object
# VAR_0284    float64
# VAR_0285    float64
# VAR_0286    float64
# VAR_0287    float64
# VAR_0288    float64
# VAR_0289    float64
# VAR_0290    float64
# VAR_0291    float64
# VAR_0292    float64
# VAR_0293    float64
# VAR_0294    float64
# VAR_0295    float64
# VAR_0296    float64
# VAR_0297    float64
# VAR_0298    float64
# VAR_0299    float64
# VAR_0300    float64
# VAR_0301    float64
# VAR_0302    float64
# VAR_0303    float64
# VAR_0304    float64
# VAR_0305    object
# VAR_0306    float64
# VAR_0307    float64
# VAR_0308    float64
# VAR_0309    float64
# VAR_0310    float64
# VAR_0311    float64
# VAR_0312    float64
# VAR_0313    float64
# VAR_0314    float64
# VAR_0315    float64
# VAR_0316    float64
# VAR_0317    float64
# VAR_0318    float64
# VAR_0319    float64
# VAR_0320    float64
# VAR_0321    float64
# VAR_0322    float64
# VAR_0323    float64
# VAR_0324    float64
# VAR_0325    object
# VAR_0326    float64
# VAR_0327    float64
# VAR_0328    float64
# VAR_0329    float64
# VAR_0330    float64
# VAR_0331    float64
# VAR_0332    float64
# VAR_0333    float64
# VAR_0334    float64
# VAR_0335    float64
# VAR_0336    float64
# VAR_0337    float64
# VAR_0338    float64
# VAR_0339    float64
# VAR_0340    float64
# VAR_0341    float64
# VAR_0342    object
# VAR_0343    float64
# VAR_0344    float64
# VAR_0345    float64
# VAR_0346    float64
# VAR_0347    float64
# VAR_0348    float64
# VAR_0349    float64
# VAR_0350    float64
# VAR_0351    float64
# VAR_0352    object
# VAR_0353    object
# VAR_0354    object
# VAR_0355    float64
# VAR_0356    float64
# VAR_0357    float64
# VAR_0358    float64
# VAR_0359    float64
# VAR_0360    float64
# VAR_0361    float64
# VAR_0362    float64
# VAR_0363    float64
# VAR_0364    float64
# VAR_0365    float64
# VAR_0366    float64
# VAR_0367    float64
# VAR_0368    float64
# VAR_0369    float64
# VAR_0370    float64
# VAR_0371    float64
# VAR_0372    float64
# VAR_0373    float64
# VAR_0374    float64
# VAR_0375    float64
# VAR_0376    float64
# VAR_0377    float64
# VAR_0378    float64
# VAR_0379    float64
# VAR_0380    float64
# VAR_0381    float64
# VAR_0382    float64
# VAR_0383    float64
# VAR_0384    float64
# VAR_0385    float64
# VAR_0386    float64
# VAR_0387    float64
# VAR_0388    float64
# VAR_0389    float64
# VAR_0390    float64
# VAR_0391    float64
# VAR_0392    float64
# VAR_0393    float64
# VAR_0394    float64
# VAR_0395    float64
# VAR_0396    float64
# VAR_0397    float64
# VAR_0398    float64
# VAR_0399    float64
# VAR_0400    float64
# VAR_0401    float64
# VAR_0402    float64
# VAR_0403    float64
# VAR_0404    object
# VAR_0405    float64
# VAR_0406    float64
# VAR_0407    float64
# VAR_0408    float64
# VAR_0409    float64
# VAR_0410    float64
# VAR_0411    float64
# VAR_0412    float64
# VAR_0413    float64
# VAR_0414    float64
# VAR_0415    float64
# VAR_0416    float64
# VAR_0417    float64
# VAR_0418    float64
# VAR_0419    float64
# VAR_0420    float64
# VAR_0421    float64
# VAR_0422    float64
# VAR_0423    float64
# VAR_0424    float64
# VAR_0425    float64
# VAR_0426    float64
# VAR_0427    float64
# VAR_0428    float64
# VAR_0429    float64
# VAR_0430    float64
# VAR_0431    float64
# VAR_0432    float64
# VAR_0433    float64
# VAR_0434    float64
# VAR_0435    float64
# VAR_0436    float64
# VAR_0437    float64
# VAR_0438    float64
# VAR_0439    float64
# VAR_0440    float64
# VAR_0441    float64
# VAR_0442    float64
# VAR_0443    float64
# VAR_0444    float64
# VAR_0445    float64
# VAR_0446    float64
# VAR_0447    float64
# VAR_0448    float64
# VAR_0449    float64
# VAR_0450    float64
# VAR_0451    float64
# VAR_0452    float64
# VAR_0453    float64
# VAR_0454    float64
# VAR_0455    float64
# VAR_0456    float64
# VAR_0457    float64
# VAR_0458    float64
# VAR_0459    float64
# VAR_0460    float64
# VAR_0461    float64
# VAR_0462    float64
# VAR_0463    float64
# VAR_0464    float64
# VAR_0465    float64
# VAR_0466    object
# VAR_0467    object
# VAR_0468    float64
# VAR_0469    float64
# VAR_0470    float64
# VAR_0471    float64
# VAR_0472    float64
# VAR_0473    float64
# VAR_0474    float64
# VAR_0475    float64
# VAR_0476    float64
# VAR_0477    float64
# VAR_0478    float64
# VAR_0479    float64
# VAR_0480    float64
# VAR_0481    float64
# VAR_0482    float64
# VAR_0483    float64
# VAR_0484    float64
# VAR_0485    float64
# VAR_0486    float64
# VAR_0487    float64
# VAR_0488    float64
# VAR_0489    float64
# VAR_0490    float64
# VAR_0491    float64
# VAR_0492    float64
# VAR_0493    object
# VAR_0494    float64
# VAR_0495    float64
# VAR_0496    float64
# VAR_0497    float64
# VAR_0498    float64
# VAR_0499    float64
# VAR_0500    float64
# VAR_0501    float64
# VAR_0502    float64
# VAR_0503    float64
# VAR_0504    float64
# VAR_0505    float64
# VAR_0506    float64
# VAR_0507    float64
# VAR_0508    float64
# VAR_0509    float64
# VAR_0510    float64
# VAR_0511    float64
# VAR_0512    float64
# VAR_0513    float64
# VAR_0514    float64
# VAR_0515    float64
# VAR_0516    float64
# VAR_0517    float64
# VAR_0518    float64
# VAR_0519    float64
# VAR_0520    float64
# VAR_0521    float64
# VAR_0522    float64
# VAR_0523    float64
# VAR_0524    float64
# VAR_0525    float64
# VAR_0526    float64
# VAR_0527    float64
# VAR_0528    float64
# VAR_0529    float64
# VAR_0530    float64
# VAR_0531    float64
# VAR_0532    int64
# VAR_0533    int64
# VAR_0534    int64
# VAR_0535    int64
# VAR_0536    int64
# VAR_0537    int64
# VAR_0538    int64
# VAR_0539    int64
# VAR_0540    int64
# VAR_0541    int64
# VAR_0542    int64
# VAR_0543    int64
# VAR_0544    int64
# VAR_0545    int64
# VAR_0546    int64
# VAR_0547    int64
# VAR_0548    int64
# VAR_0549    int64
# VAR_0550    int64
# VAR_0551    int64
# VAR_0552    int64
# VAR_0553    int64
# VAR_0554    int64
# VAR_0555    int64
# VAR_0556    int64
# VAR_0557    int64
# VAR_0558    int64
# VAR_0559    int64
# VAR_0560    int64
# VAR_0561    int64
# VAR_0562    int64
# VAR_0563    int64
# VAR_0564    int64
# VAR_0565    int64
# VAR_0566    int64
# VAR_0567    int64
# VAR_0568    int64
# VAR_0569    int64
# VAR_0570    int64
# VAR_0571    int64
# VAR_0572    int64
# VAR_0573    int64
# VAR_0574    int64
# VAR_0575    int64
# VAR_0576    int64
# VAR_0577    int64
# VAR_0578    int64
# VAR_0579    int64
# VAR_0580    int64
# VAR_0581    int64
# VAR_0582    int64
# VAR_0583    int64
# VAR_0584    int64
# VAR_0585    int64
# VAR_0586    int64
# VAR_0587    int64
# VAR_0588    int64
# VAR_0589    int64
# VAR_0590    int64
# VAR_0591    int64
# VAR_0592    int64
# VAR_0593    int64
# VAR_0594    int64
# VAR_0595    int64
# VAR_0596    int64
# VAR_0597    int64
# VAR_0598    int64
# VAR_0599    int64
# VAR_0600    int64
# VAR_0601    int64
# VAR_0602    int64
# VAR_0603    int64
# VAR_0604    int64
# VAR_0605    int64
# VAR_0606    int64
# VAR_0607    int64
# VAR_0608    int64
# VAR_0609    int64
# VAR_0610    int64
# VAR_0611    int64
# VAR_0612    int64
# VAR_0613    int64
# VAR_0614    int64
# VAR_0615    int64
# VAR_0616    int64
# VAR_0617    int64
# VAR_0618    int64
# VAR_0619    int64
# VAR_0620    int64
# VAR_0621    int64
# VAR_0622    int64
# VAR_0623    int64
# VAR_0624    int64
# VAR_0625    int64
# VAR_0626    int64
# VAR_0627    int64
# VAR_0628    int64
# VAR_0629    int64
# VAR_0630    int64
# VAR_0631    int64
# VAR_0632    int64
# VAR_0633    int64
# VAR_0634    int64
# VAR_0635    int64
# VAR_0636    int64
# VAR_0637    int64
# VAR_0638    int64
# VAR_0639    int64
# VAR_0640    int64
# VAR_0641    int64
# VAR_0642    int64
# VAR_0643    int64
# VAR_0644    int64
# VAR_0645    int64
# VAR_0646    int64
# VAR_0647    int64
# VAR_0648    int64
# VAR_0649    int64
# VAR_0650    int64
# VAR_0651    int64
# VAR_0652    int64
# VAR_0653    int64
# VAR_0654    int64
# VAR_0655    int64
# VAR_0656    int64
# VAR_0657    int64
# VAR_0658    int64
# VAR_0659    int64
# VAR_0660    int64
# VAR_0661    int64
# VAR_0662    int64
# VAR_0663    int64
# VAR_0664    int64
# VAR_0665    int64
# VAR_0666    int64
# VAR_0667    int64
# VAR_0668    int64
# VAR_0669    int64
# VAR_0670    int64
# VAR_0671    int64
# VAR_0672    int64
# VAR_0673    int64
# VAR_0674    int64
# VAR_0675    int64
# VAR_0676    int64
# VAR_0677    int64
# VAR_0678    int64
# VAR_0679    int64
# VAR_0680    int64
# VAR_0681    int64
# VAR_0682    int64
# VAR_0683    int64
# VAR_0684    int64
# VAR_0685    int64
# VAR_0686    int64
# VAR_0687    int64
# VAR_0688    int64
# VAR_0689    int64
# VAR_0690    int64
# VAR_0691    int64
# VAR_0692    int64
# VAR_0693    int64
# VAR_0694    int64
# VAR_0695    int64
# VAR_0696    int64
# VAR_0697    int64
# VAR_0698    int64
# VAR_0699    int64
# VAR_0700    int64
# VAR_0701    int64
# VAR_0702    int64
# VAR_0703    int64
# VAR_0704    int64
# VAR_0705    int64
# VAR_0706    int64
# VAR_0707    int64
# VAR_0708    int64
# VAR_0709    int64
# VAR_0710    int64
# VAR_0711    int64
# VAR_0712    int64
# VAR_0713    int64
# VAR_0714    int64
# VAR_0715    int64
# VAR_0716    int64
# VAR_0717    int64
# VAR_0718    int64
# VAR_0719    int64
# VAR_0720    int64
# VAR_0721    int64
# VAR_0722    int64
# VAR_0723    int64
# VAR_0724    int64
# VAR_0725    int64
# VAR_0726    int64
# VAR_0727    int64
# VAR_0728    int64
# VAR_0729    int64
# VAR_0730    int64
# VAR_0731    int64
# VAR_0732    int64
# VAR_0733    int64
# VAR_0734    int64
# VAR_0735    int64
# VAR_0736    int64
# VAR_0737    int64
# VAR_0738    int64
# VAR_0739    int64
# VAR_0740    int64
# VAR_0741    int64
# VAR_0742    int64
# VAR_0743    int64
# VAR_0744    int64
# VAR_0745    int64
# VAR_0746    int64
# VAR_0747    int64
# VAR_0748    int64
# VAR_0749    int64
# VAR_0750    int64
# VAR_0751    int64
# VAR_0752    int64
# VAR_0753    int64
# VAR_0754    int64
# VAR_0755    int64
# VAR_0756    int64
# VAR_0757    int64
# VAR_0758    int64
# VAR_0759    int64
# VAR_0760    int64
# VAR_0761    int64
# VAR_0762    int64
# VAR_0763    int64
# VAR_0764    int64
# VAR_0765    int64
# VAR_0766    int64
# VAR_0767    int64
# VAR_0768    int64
# VAR_0769    int64
# VAR_0770    int64
# VAR_0771    int64
# VAR_0772    int64
# VAR_0773    int64
# VAR_0774    int64
# VAR_0775    int64
# VAR_0776    int64
# VAR_0777    int64
# VAR_0778    int64
# VAR_0779    int64
# VAR_0780    int64
# VAR_0781    int64
# VAR_0782    int64
# VAR_0783    int64
# VAR_0784    int64
# VAR_0785    int64
# VAR_0786    int64
# VAR_0787    int64
# VAR_0788    int64
# VAR_0789    int64
# VAR_0790    int64
# VAR_0791    int64
# VAR_0792    int64
# VAR_0793    int64
# VAR_0794    int64
# VAR_0795    int64
# VAR_0796    int64
# VAR_0797    int64
# VAR_0798    int64
# VAR_0799    int64
# VAR_0800    int64
# VAR_0801    int64
# VAR_0802    int64
# VAR_0803    int64
# VAR_0804    int64
# VAR_0805    int64
# VAR_0806    int64
# VAR_0807    int64
# VAR_0808    int64
# VAR_0809    int64
# VAR_0810    int64
# VAR_0811    int64
# VAR_0812    int64
# VAR_0813    int64
# VAR_0814    int64
# VAR_0815    int64
# VAR_0816    int64
# VAR_0817    int64
# VAR_0818    int64
# VAR_0819    int64
# VAR_0820    int64
# VAR_0821    int64
# VAR_0822    int64
# VAR_0823    int64
# VAR_0824    int64
# VAR_0825    int64
# VAR_0826    int64
# VAR_0827    int64
# VAR_0828    int64
# VAR_0829    int64
# VAR_0830    int64
# VAR_0831    int64
# VAR_0832    int64
# VAR_0833    int64
# VAR_0834    int64
# VAR_0835    int64
# VAR_0836    int64
# VAR_0837    int64
# VAR_0838    int64
# VAR_0839    int64
# VAR_0840    float64
# VAR_0841    int64
# VAR_0842    int64
# VAR_0843    int64
# VAR_0844    int64
# VAR_0845    int64
# VAR_0846    int64
# VAR_0847    int64
# VAR_0848    int64
# VAR_0849    int64
# VAR_0850    int64
# VAR_0851    int64
# VAR_0852    int64
# VAR_0853    int64
# VAR_0854    int64
# VAR_0855    int64
# VAR_0856    int64
# VAR_0857    int64
# VAR_0858    int64
# VAR_0859    int64
# VAR_0860    int64
# VAR_0861    int64
# VAR_0862    int64
# VAR_0863    int64
# VAR_0864    int64
# VAR_0865    int64
# VAR_0866    int64
# VAR_0867    int64
# VAR_0868    int64
# VAR_0869    int64
# VAR_0870    int64
# VAR_0871    int64
# VAR_0872    int64
# VAR_0873    int64
# VAR_0874    int64
# VAR_0875    int64
# VAR_0876    int64
# VAR_0877    int64
# VAR_0878    int64
# VAR_0879    int64
# VAR_0880    int64
# VAR_0881    int64
# VAR_0882    int64
# VAR_0883    int64
# VAR_0884    int64
# VAR_0885    int64
# VAR_0886    int64
# VAR_0887    int64
# VAR_0888    int64
# VAR_0889    int64
# VAR_0890    int64
# VAR_0891    int64
# VAR_0892    int64
# VAR_0893    int64
# VAR_0894    int64
# VAR_0895    int64
# VAR_0896    int64
# VAR_0897    int64
# VAR_0898    int64
# VAR_0899    int64
# VAR_0900    int64
# VAR_0901    int64
# VAR_0902    int64
# VAR_0903    int64
# VAR_0904    int64
# VAR_0905    int64
# VAR_0906    int64
# VAR_0907    int64
# VAR_0908    int64
# VAR_0909    int64
# VAR_0910    int64
# VAR_0911    int64
# VAR_0912    int64
# VAR_0913    int64
# VAR_0914    int64
# VAR_0915    int64
# VAR_0916    int64
# VAR_0917    int64
# VAR_0918    int64
# VAR_0919    int64
# VAR_0920    int64
# VAR_0921    int64
# VAR_0922    int64
# VAR_0923    int64
# VAR_0924    int64
# VAR_0925    int64
# VAR_0926    int64
# VAR_0927    int64
# VAR_0928    int64
# VAR_0929    int64
# VAR_0930    int64
# VAR_0931    int64
# VAR_0932    int64
# VAR_0933    int64
# VAR_0934    int64
# VAR_0935    int64
# VAR_0936    int64
# VAR_0937    int64
# VAR_0938    int64
# VAR_0939    int64
# VAR_0940    int64
# VAR_0941    int64
# VAR_0942    int64
# VAR_0943    int64
# VAR_0944    int64
# VAR_0945    int64
# VAR_0946    int64
# VAR_0947    int64
# VAR_0948    int64
# VAR_0949    int64
# VAR_0950    int64
# VAR_0951    int64
# VAR_0952    int64
# VAR_0953    int64
# VAR_0954    int64
# VAR_0955    int64
# VAR_0956    int64
# VAR_0957    int64
# VAR_0958    int64
# VAR_0959    int64
# VAR_0960    int64
# VAR_0961    int64
# VAR_0962    int64
# VAR_0963    int64
# VAR_0964    int64
# VAR_0965    int64
# VAR_0966    int64
# VAR_0967    int64
# VAR_0968    int64
# VAR_0969    int64
# VAR_0970    int64
# VAR_0971    int64
# VAR_0972    int64
# VAR_0973    int64
# VAR_0974    int64
# VAR_0975    int64
# VAR_0976    int64
# VAR_0977    int64
# VAR_0978    int64
# VAR_0979    int64
# VAR_0980    int64
# VAR_0981    int64
# VAR_0982    int64
# VAR_0983    int64
# VAR_0984    int64
# VAR_0985    int64
# VAR_0986    int64
# VAR_0987    int64
# VAR_0988    int64
# VAR_0989    int64
# VAR_0990    int64
# VAR_0991    int64
# VAR_0992    int64
# VAR_0993    int64
# VAR_0994    int64
# VAR_0995    int64
# VAR_0996    int64
# VAR_0997    int64
# VAR_0998    int64
# VAR_0999    int64
# VAR_1000    int64
# VAR_1001    int64
# VAR_1002    int64
# VAR_1003    int64
# VAR_1004    int64
# VAR_1005    int64
# VAR_1006    int64
# VAR_1007    int64
# VAR_1008    int64
# VAR_1009    int64
# VAR_1010    int64
# VAR_1011    int64
# VAR_1012    int64
# VAR_1013    int64
# VAR_1014    int64
# VAR_1015    int64
# VAR_1016    int64
# VAR_1017    int64
# VAR_1018    int64
# VAR_1019    int64
# VAR_1020    int64
# VAR_1021    int64
# VAR_1022    int64
# VAR_1023    int64
# VAR_1024    int64
# VAR_1025    int64
# VAR_1026    int64
# VAR_1027    int64
# VAR_1028    int64
# VAR_1029    int64
# VAR_1030    int64
# VAR_1031    int64
# VAR_1032    int64
# VAR_1033    int64
# VAR_1034    int64
# VAR_1035    int64
# VAR_1036    int64
# VAR_1037    int64
# VAR_1038    int64
# VAR_1039    int64
# VAR_1040    int64
# VAR_1041    int64
# VAR_1042    int64
# VAR_1043    int64
# VAR_1044    int64
# VAR_1045    int64
# VAR_1046    int64
# VAR_1047    int64
# VAR_1048    int64
# VAR_1049    int64
# VAR_1050    int64
# VAR_1051    int64
# VAR_1052    int64
# VAR_1053    int64
# VAR_1054    int64
# VAR_1055    int64
# VAR_1056    int64
# VAR_1057    int64
# VAR_1058    int64
# VAR_1059    int64
# VAR_1060    int64
# VAR_1061    int64
# VAR_1062    int64
# VAR_1063    int64
# VAR_1064    int64
# VAR_1065    int64
# VAR_1066    int64
# VAR_1067    int64
# VAR_1068    int64
# VAR_1069    int64
# VAR_1070    int64
# VAR_1071    int64
# VAR_1072    int64
# VAR_1073    int64
# VAR_1074    int64
# VAR_1075    int64
# VAR_1076    int64
# VAR_1077    int64
# VAR_1078    int64
# VAR_1079    int64
# VAR_1080    int64
# VAR_1081    int64
# VAR_1082    int64
# VAR_1083    int64
# VAR_1084    int64
# VAR_1085    int64
# VAR_1086    int64
# VAR_1087    int64
# VAR_1088    int64
# VAR_1089    int64
# VAR_1090    int64
# VAR_1091    int64
# VAR_1092    int64
# VAR_1093    int64
# VAR_1094    int64
# VAR_1095    int64
# VAR_1096    int64
# VAR_1097    int64
# VAR_1098    int64
# VAR_1099    int64
# VAR_1100    int64
# VAR_1101    int64
# VAR_1102    int64
# VAR_1103    int64
# VAR_1104    int64
# VAR_1105    int64
# VAR_1106    int64
# VAR_1107    int64
# VAR_1108    int64
# VAR_1109    int64
# VAR_1110    int64
# VAR_1111    int64
# VAR_1112    int64
# VAR_1113    int64
# VAR_1114    int64
# VAR_1115    int64
# VAR_1116    int64
# VAR_1117    int64
# VAR_1118    int64
# VAR_1119    int64
# VAR_1120    int64
# VAR_1121    int64
# VAR_1122    int64
# VAR_1123    int64
# VAR_1124    int64
# VAR_1125    int64
# VAR_1126    int64
# VAR_1127    int64
# VAR_1128    int64
# VAR_1129    int64
# VAR_1130    int64
# VAR_1131    int64
# VAR_1132    int64
# VAR_1133    int64
# VAR_1134    int64
# VAR_1135    int64
# VAR_1136    int64
# VAR_1137    int64
# VAR_1138    int64
# VAR_1139    int64
# VAR_1140    int64
# VAR_1141    int64
# VAR_1142    int64
# VAR_1143    int64
# VAR_1144    int64
# VAR_1145    int64
# VAR_1146    int64
# VAR_1147    int64
# VAR_1148    int64
# VAR_1149    int64
# VAR_1150    int64
# VAR_1151    int64
# VAR_1152    int64
# VAR_1153    int64
# VAR_1154    int64
# VAR_1155    int64
# VAR_1156    int64
# VAR_1157    int64
# VAR_1158    int64
# VAR_1159    int64
# VAR_1160    int64
# VAR_1161    int64
# VAR_1162    int64
# VAR_1163    int64
# VAR_1164    int64
# VAR_1165    int64
# VAR_1166    int64
# VAR_1167    int64
# VAR_1168    int64
# VAR_1169    int64
# VAR_1170    int64
# VAR_1171    int64
# VAR_1172    int64
# VAR_1173    int64
# VAR_1174    int64
# VAR_1175    int64
# VAR_1176    int64
# VAR_1177    int64
# VAR_1178    int64
# VAR_1179    int64
# VAR_1180    int64
# VAR_1181    int64
# VAR_1182    int64
# VAR_1183    int64
# VAR_1184    int64
# VAR_1185    int64
# VAR_1186    int64
# VAR_1187    int64
# VAR_1188    int64
# VAR_1189    int64
# VAR_1190    int64
# VAR_1191    int64
# VAR_1192    int64
# VAR_1193    int64
# VAR_1194    int64
# VAR_1195    int64
# VAR_1196    int64
# VAR_1197    int64
# VAR_1198    int64
# VAR_1199    int64
# VAR_1200    int64
# VAR_1201    int64
# VAR_1202    int64
# VAR_1203    int64
# VAR_1204    int64
# VAR_1205    int64
# VAR_1206    int64
# VAR_1207    int64
# VAR_1208    int64
# VAR_1209    int64
# VAR_1210    int64
# VAR_1211    int64
# VAR_1212    int64
# VAR_1213    int64
# VAR_1214    int64
# VAR_1215    int64
# VAR_1216    int64
# VAR_1217    int64
# VAR_1218    int64
# VAR_1219    int64
# VAR_1220    int64
# VAR_1221    int64
# VAR_1222    int64
# VAR_1223    int64
# VAR_1224    int64
# VAR_1225    int64
# VAR_1226    int64
# VAR_1227    int64
# VAR_1228    int64
# VAR_1229    int64
# VAR_1230    int64
# VAR_1231    int64
# VAR_1232    int64
# VAR_1233    int64
# VAR_1234    int64
# VAR_1235    int64
# VAR_1236    int64
# VAR_1237    int64
# VAR_1238    int64
# VAR_1239    int64
# VAR_1240    int64
# VAR_1241    int64
# VAR_1242    int64
# VAR_1243    int64
# VAR_1244    int64
# VAR_1245    int64
# VAR_1246    int64
# VAR_1247    int64
# VAR_1248    int64
# VAR_1249    int64
# VAR_1250    int64
# VAR_1251    int64
# VAR_1252    int64
# VAR_1253    int64
# VAR_1254    int64
# VAR_1255    int64
# VAR_1256    int64
# VAR_1257    int64
# VAR_1258    int64
# VAR_1259    int64
# VAR_1260    int64
# VAR_1261    int64
# VAR_1262    int64
# VAR_1263    int64
# VAR_1264    int64
# VAR_1265    int64
# VAR_1266    int64
# VAR_1267    int64
# VAR_1268    int64
# VAR_1269    int64
# VAR_1270    int64
# VAR_1271    int64
# VAR_1272    int64
# VAR_1273    int64
# VAR_1274    int64
# VAR_1275    int64
# VAR_1276    int64
# VAR_1277    int64
# VAR_1278    int64
# VAR_1279    int64
# VAR_1280    int64
# VAR_1281    int64
# VAR_1282    int64
# VAR_1283    int64
# VAR_1284    int64
# VAR_1285    int64
# VAR_1286    int64
# VAR_1287    int64
# VAR_1288    int64
# VAR_1289    int64
# VAR_1290    int64
# VAR_1291    int64
# VAR_1292    int64
# VAR_1293    int64
# VAR_1294    int64
# VAR_1295    int64
# VAR_1296    int64
# VAR_1297    int64
# VAR_1298    int64
# VAR_1299    int64
# VAR_1300    int64
# VAR_1301    int64
# VAR_1302    int64
# VAR_1303    int64
# VAR_1304    int64
# VAR_1305    int64
# VAR_1306    int64
# VAR_1307    int64
# VAR_1308    int64
# VAR_1309    int64
# VAR_1310    int64
# VAR_1311    int64
# VAR_1312    int64
# VAR_1313    int64
# VAR_1314    int64
# VAR_1315    int64
# VAR_1316    int64
# VAR_1317    int64
# VAR_1318    int64
# VAR_1319    int64
# VAR_1320    int64
# VAR_1321    int64
# VAR_1322    int64
# VAR_1323    int64
# VAR_1324    int64
# VAR_1325    int64
# VAR_1326    int64
# VAR_1327    int64
# VAR_1328    int64
# VAR_1329    int64
# VAR_1330    int64
# VAR_1331    int64
# VAR_1332    int64
# VAR_1333    int64
# VAR_1334    int64
# VAR_1335    int64
# VAR_1336    int64
# VAR_1337    int64
# VAR_1338    int64
# VAR_1339    int64
# VAR_1340    int64
# VAR_1341    int64
# VAR_1342    int64
# VAR_1343    int64
# VAR_1344    int64
# VAR_1345    int64
# VAR_1346    int64
# VAR_1347    int64
# VAR_1348    int64
# VAR_1349    int64
# VAR_1350    int64
# VAR_1351    int64
# VAR_1352    int64
# VAR_1353    int64
# VAR_1354    int64
# VAR_1355    int64
# VAR_1356    int64
# VAR_1357    int64
# VAR_1358    int64
# VAR_1359    int64
# VAR_1360    int64
# VAR_1361    int64
# VAR_1362    int64
# VAR_1363    int64
# VAR_1364    int64
# VAR_1365    int64
# VAR_1366    int64
# VAR_1367    int64
# VAR_1368    int64
# VAR_1369    int64
# VAR_1370    int64
# VAR_1371    int64
# VAR_1372    int64
# VAR_1373    int64
# VAR_1374    int64
# VAR_1375    int64
# VAR_1376    int64
# VAR_1377    int64
# VAR_1378    int64
# VAR_1379    int64
# VAR_1380    int64
# VAR_1381    int64
# VAR_1382    int64
# VAR_1383    int64
# VAR_1384    int64
# VAR_1385    int64
# VAR_1386    int64
# VAR_1387    int64
# VAR_1388    int64
# VAR_1389    int64
# VAR_1390    int64
# VAR_1391    int64
# VAR_1392    int64
# VAR_1393    int64
# VAR_1394    int64
# VAR_1395    int64
# VAR_1396    int64
# VAR_1397    int64
# VAR_1398    int64
# VAR_1399    int64
# VAR_1400    int64
# VAR_1401    int64
# VAR_1402    int64
# VAR_1403    int64
# VAR_1404    int64
# VAR_1405    int64
# VAR_1406    int64
# VAR_1407    int64
# VAR_1408    int64
# VAR_1409    int64
# VAR_1410    int64
# VAR_1411    int64
# VAR_1412    int64
# VAR_1413    int64
# VAR_1414    int64
# VAR_1415    int64
# VAR_1416    int64
# VAR_1417    int64
# VAR_1418    int64
# VAR_1419    int64
# VAR_1420    int64
# VAR_1421    int64
# VAR_1422    int64
# VAR_1423    int64
# VAR_1424    int64
# VAR_1425    int64
# VAR_1426    int64
# VAR_1427    int64
# VAR_1428    int64
# VAR_1429    int64
# VAR_1430    int64
# VAR_1431    int64
# VAR_1432    int64
# VAR_1433    int64
# VAR_1434    int64
# VAR_1435    int64
# VAR_1436    int64
# VAR_1437    int64
# VAR_1438    int64
# VAR_1439    int64
# VAR_1440    int64
# VAR_1441    int64
# VAR_1442    int64
# VAR_1443    int64
# VAR_1444    int64
# VAR_1445    int64
# VAR_1446    int64
# VAR_1447    int64
# VAR_1448    int64
# VAR_1449    int64
# VAR_1450    int64
# VAR_1451    int64
# VAR_1452    int64
# VAR_1453    int64
# VAR_1454    int64
# VAR_1455    int64
# VAR_1456    int64
# VAR_1457    int64
# VAR_1458    int64
# VAR_1459    int64
# VAR_1460    int64
# VAR_1461    int64
# VAR_1462    int64
# VAR_1463    int64
# VAR_1464    int64
# VAR_1465    int64
# VAR_1466    int64
# VAR_1467    int64
# VAR_1468    int64
# VAR_1469    int64
# VAR_1470    int64
# VAR_1471    int64
# VAR_1472    int64
# VAR_1473    int64
# VAR_1474    int64
# VAR_1475    int64
# VAR_1476    int64
# VAR_1477    int64
# VAR_1478    int64
# VAR_1479    int64
# VAR_1480    int64
# VAR_1481    int64
# VAR_1482    int64
# VAR_1483    int64
# VAR_1484    int64
# VAR_1485    int64
# VAR_1486    int64
# VAR_1487    int64
# VAR_1488    int64
# VAR_1489    int64
# VAR_1490    int64
# VAR_1491    int64
# VAR_1492    int64
# VAR_1493    int64
# VAR_1494    int64
# VAR_1495    int64
# VAR_1496    int64
# VAR_1497    int64
# VAR_1498    int64
# VAR_1499    int64
# VAR_1500    int64
# VAR_1501    int64
# VAR_1502    int64
# VAR_1503    int64
# VAR_1504    int64
# VAR_1505    int64
# VAR_1506    int64
# VAR_1507    int64
# VAR_1508    int64
# VAR_1509    int64
# VAR_1510    int64
# VAR_1511    int64
# VAR_1512    int64
# VAR_1513    int64
# VAR_1514    int64
# VAR_1515    int64
# VAR_1516    int64
# VAR_1517    int64
# VAR_1518    int64
# VAR_1519    int64
# VAR_1520    int64
# VAR_1521    int64
# VAR_1522    int64
# VAR_1523    int64
# VAR_1524    int64
# VAR_1525    int64
# VAR_1526    int64
# VAR_1527    int64
# VAR_1528    int64
# VAR_1529    int64
# VAR_1530    int64
# VAR_1531    int64
# VAR_1532    int64
# VAR_1533    int64
# VAR_1534    int64
# VAR_1535    int64
# VAR_1536    int64
# VAR_1537    int64
# VAR_1538    int64
# VAR_1539    int64
# VAR_1540    int64
# VAR_1541    int64
# VAR_1542    int64
# VAR_1543    int64
# VAR_1544    int64
# VAR_1545    int64
# VAR_1546    int64
# VAR_1547    int64
# VAR_1548    int64
# VAR_1549    int64
# VAR_1550    int64
# VAR_1551    int64
# VAR_1552    int64
# VAR_1553    int64
# VAR_1554    int64
# VAR_1555    int64
# VAR_1556    int64
# VAR_1557    int64
# VAR_1558    int64
# VAR_1559    int64
# VAR_1560    int64
# VAR_1561    int64
# VAR_1562    int64
# VAR_1563    int64
# VAR_1564    int64
# VAR_1565    int64
# VAR_1566    int64
# VAR_1567    int64
# VAR_1568    int64
# VAR_1569    int64
# VAR_1570    int64
# VAR_1571    int64
# VAR_1572    int64
# VAR_1573    int64
# VAR_1574    int64
# VAR_1575    int64
# VAR_1576    int64
# VAR_1577    int64
# VAR_1578    int64
# VAR_1579    int64
# VAR_1580    int64
# VAR_1581    int64
# VAR_1582    int64
# VAR_1583    int64
# VAR_1584    int64
# VAR_1585    int64
# VAR_1586    int64
# VAR_1587    int64
# VAR_1588    int64
# VAR_1589    int64
# VAR_1590    int64
# VAR_1591    int64
# VAR_1592    int64
# VAR_1593    int64
# VAR_1594    int64
# VAR_1595    int64
# VAR_1596    int64
# VAR_1597    int64
# VAR_1598    int64
# VAR_1599    int64
# VAR_1600    int64
# VAR_1601    int64
# VAR_1602    int64
# VAR_1603    int64
# VAR_1604    int64
# VAR_1605    int64
# VAR_1606    int64
# VAR_1607    int64
# VAR_1608    int64
# VAR_1609    int64
# VAR_1610    int64
# VAR_1611    int64
# VAR_1612    int64
# VAR_1613    int64
# VAR_1614    int64
# VAR_1615    int64
# VAR_1616    int64
# VAR_1617    int64
# VAR_1618    int64
# VAR_1619    int64
# VAR_1620    int64
# VAR_1621    int64
# VAR_1622    int64
# VAR_1623    int64
# VAR_1624    int64
# VAR_1625    int64
# VAR_1626    int64
# VAR_1627    int64
# VAR_1628    int64
# VAR_1629    int64
# VAR_1630    int64
# VAR_1631    int64
# VAR_1632    int64
# VAR_1633    int64
# VAR_1634    int64
# VAR_1635    int64
# VAR_1636    int64
# VAR_1637    int64
# VAR_1638    int64
# VAR_1639    int64
# VAR_1640    int64
# VAR_1641    int64
# VAR_1642    int64
# VAR_1643    int64
# VAR_1644    int64
# VAR_1645    int64
# VAR_1646    int64
# VAR_1647    int64
# VAR_1648    int64
# VAR_1649    int64
# VAR_1650    int64
# VAR_1651    int64
# VAR_1652    int64
# VAR_1653    int64
# VAR_1654    int64
# VAR_1655    int64
# VAR_1656    int64
# VAR_1657    int64
# VAR_1658    int64
# VAR_1659    int64
# VAR_1660    int64
# VAR_1661    int64
# VAR_1662    int64
# VAR_1663    int64
# VAR_1664    int64
# VAR_1665    int64
# VAR_1666    int64
# VAR_1667    int64
# VAR_1668    int64
# VAR_1669    int64
# VAR_1670    int64
# VAR_1671    int64
# VAR_1672    int64
# VAR_1673    int64
# VAR_1674    int64
# VAR_1675    int64
# VAR_1676    int64
# VAR_1677    int64
# VAR_1678    int64
# VAR_1679    int64
# VAR_1680    int64
# VAR_1681    int64
# VAR_1682    int64
# VAR_1683    int64
# VAR_1684    int64
# VAR_1685    int64
# VAR_1686    int64
# VAR_1687    int64
# VAR_1688    int64
# VAR_1689    int64
# VAR_1690    int64
# VAR_1691    int64
# VAR_1692    int64
# VAR_1693    int64
# VAR_1694    int64
# VAR_1695    int64
# VAR_1696    int64
# VAR_1697    int64
# VAR_1698    int64
# VAR_1699    int64
# VAR_1700    int64
# VAR_1701    int64
# VAR_1702    int64
# VAR_1703    int64
# VAR_1704    int64
# VAR_1705    int64
# VAR_1706    int64
# VAR_1707    int64
# VAR_1708    int64
# VAR_1709    int64
# VAR_1710    int64
# VAR_1711    int64
# VAR_1712    int64
# VAR_1713    int64
# VAR_1714    int64
# VAR_1715    int64
# VAR_1716    int64
# VAR_1717    int64
# VAR_1718    int64
# VAR_1719    int64
# VAR_1720    int64
# VAR_1721    int64
# VAR_1722    int64
# VAR_1723    int64
# VAR_1724    int64
# VAR_1725    int64
# VAR_1726    int64
# VAR_1727    int64
# VAR_1728    int64
# VAR_1729    int64
# VAR_1730    int64
# VAR_1731    int64
# VAR_1732    int64
# VAR_1733    int64
# VAR_1734    int64
# VAR_1735    int64
# VAR_1736    int64
# VAR_1737    int64
# VAR_1738    int64
# VAR_1739    int64
# VAR_1740    int64
# VAR_1741    int64
# VAR_1742    int64
# VAR_1743    int64
# VAR_1744    int64
# VAR_1745    int64
# VAR_1746    int64
# VAR_1747    int64
# VAR_1748    int64
# VAR_1749    int64
# VAR_1750    int64
# VAR_1751    int64
# VAR_1752    int64
# VAR_1753    int64
# VAR_1754    int64
# VAR_1755    int64
# VAR_1756    int64
# VAR_1757    int64
# VAR_1758    int64
# VAR_1759    int64
# VAR_1760    int64
# VAR_1761    int64
# VAR_1762    int64
# VAR_1763    int64
# VAR_1764    int64
# VAR_1765    int64
# VAR_1766    int64
# VAR_1767    int64
# VAR_1768    int64
# VAR_1769    int64
# VAR_1770    int64
# VAR_1771    int64
# VAR_1772    int64
# VAR_1773    int64
# VAR_1774    int64
# VAR_1775    int64
# VAR_1776    int64
# VAR_1777    int64
# VAR_1778    int64
# VAR_1779    int64
# VAR_1780    int64
# VAR_1781    int64
# VAR_1782    int64
# VAR_1783    int64
# VAR_1784    int64
# VAR_1785    int64
# VAR_1786    int64
# VAR_1787    int64
# VAR_1788    int64
# VAR_1789    int64
# VAR_1790    int64
# VAR_1791    int64
# VAR_1792    int64
# VAR_1793    int64
# VAR_1794    int64
# VAR_1795    int64
# VAR_1796    int64
# VAR_1797    int64
# VAR_1798    int64
# VAR_1799    int64
# VAR_1800    int64
# VAR_1801    int64
# VAR_1802    int64
# VAR_1803    int64
# VAR_1804    int64
# VAR_1805    int64
# VAR_1806    int64
# VAR_1807    int64
# VAR_1808    int64
# VAR_1809    int64
# VAR_1810    int64
# VAR_1811    int64
# VAR_1812    int64
# VAR_1813    int64
# VAR_1814    int64
# VAR_1815    int64
# VAR_1816    int64
# VAR_1817    int64
# VAR_1818    int64
# VAR_1819    int64
# VAR_1820    int64
# VAR_1821    int64
# VAR_1822    int64
# VAR_1823    int64
# VAR_1824    int64
# VAR_1825    int64
# VAR_1826    int64
# VAR_1827    int64
# VAR_1828    int64
# VAR_1829    int64
# VAR_1830    int64
# VAR_1831    int64
# VAR_1832    int64
# VAR_1833    int64
# VAR_1834    int64
# VAR_1835    int64
# VAR_1836    int64
# VAR_1837    int64
# VAR_1838    int64
# VAR_1839    int64
# VAR_1840    int64
# VAR_1841    int64
# VAR_1842    int64
# VAR_1843    int64
# VAR_1844    int64
# VAR_1845    int64
# VAR_1846    int64
# VAR_1847    int64
# VAR_1848    int64
# VAR_1849    int64
# VAR_1850    int64
# VAR_1851    int64
# VAR_1852    int64
# VAR_1853    int64
# VAR_1854    int64
# VAR_1855    int64
# VAR_1856    int64
# VAR_1857    int64
# VAR_1858    int64
# VAR_1859    int64
# VAR_1860    int64
# VAR_1861    int64
# VAR_1862    int64
# VAR_1863    int64
# VAR_1864    int64
# VAR_1865    int64
# VAR_1866    int64
# VAR_1867    int64
# VAR_1868    int64
# VAR_1869    int64
# VAR_1870    int64
# VAR_1871    int64
# VAR_1872    int64
# VAR_1873    int64
# VAR_1874    int64
# VAR_1875    int64
# VAR_1876    int64
# VAR_1877    int64
# VAR_1878    int64
# VAR_1879    int64
# VAR_1880    int64
# VAR_1881    int64
# VAR_1882    int64
# VAR_1883    int64
# VAR_1884    int64
# VAR_1885    int64
# VAR_1886    int64
# VAR_1887    int64
# VAR_1888    int64
# VAR_1889    int64
# VAR_1890    int64
# VAR_1891    int64
# VAR_1892    int64
# VAR_1893    int64
# VAR_1894    int64
# VAR_1895    int64
# VAR_1896    int64
# VAR_1897    int64
# VAR_1898    int64
# VAR_1899    int64
# VAR_1900    int64
# VAR_1901    int64
# VAR_1902    int64
# VAR_1903    int64
# VAR_1904    int64
# VAR_1905    int64
# VAR_1906    int64
# VAR_1907    int64
# VAR_1908    int64
# VAR_1909    int64
# VAR_1910    int64
# VAR_1911    int64
# VAR_1912    int64
# VAR_1913    int64
# VAR_1914    int64
# VAR_1915    int64
# VAR_1916    int64
# VAR_1917    int64
# VAR_1918    int64
# VAR_1919    int64
# VAR_1920    int64
# VAR_1921    int64
# VAR_1922    int64
# VAR_1923    int64
# VAR_1924    int64
# VAR_1925    int64
# VAR_1926    int64
# VAR_1927    int64
# VAR_1928    int64
# VAR_1929    int64
# VAR_1930    int64
# VAR_1931    int64
# VAR_1932    int64
# VAR_1933    int64
# VAR_1934    object
# target      int64
# dtypes: float64(477), int64(1406), object(51)
# memory usage: 2.1+ GB

# %%
null_counts = Xy_original.isnull().sum()
null_counts[null_counts > 0]
# Out:
# VAR_0006        56
# VAR_0007        56
# VAR_0008        56
# VAR_0009        56
# VAR_0010        56
# VAR_0011        56
# VAR_0012        56
# VAR_0013        56
# VAR_0014        56
# VAR_0015        56
# VAR_0016        56
# VAR_0017        56
# VAR_0018        56
# VAR_0019        56
# VAR_0020        56
# VAR_0021        56
# VAR_0022        56
# VAR_0023        56
# VAR_0024        56
# VAR_0025        56
# VAR_0026        56
# VAR_0027        56
# VAR_0028        56
# VAR_0029        56
# VAR_0030        56
# VAR_0031        56
# VAR_0032        56
# VAR_0033        56
# VAR_0034        56
# VAR_0035        56
# VAR_0036        56
# VAR_0037        56
# VAR_0038        56
# VAR_0039        56
# VAR_0040        56
# VAR_0041        56
# VAR_0042        56
# VAR_0043        56
# VAR_0044        56
# VAR_0045        56
# VAR_0046        56
# VAR_0047        56
# VAR_0048        56
# VAR_0049        56
# VAR_0050        56
# VAR_0051        56
# VAR_0052        56
# VAR_0053        56
# VAR_0054        56
# VAR_0055        56
# VAR_0056        56
# VAR_0057        56
# VAR_0058        56
# VAR_0059        56
# VAR_0060        56
# VAR_0061        56
# VAR_0062        56
# VAR_0063        56
# VAR_0064        56
# VAR_0065        56
# VAR_0066        56
# VAR_0067        56
# VAR_0068        56
# VAR_0069        56
# VAR_0070        56
# VAR_0071        56
# VAR_0072        56
# VAR_0073    101127
# VAR_0074    101127
# VAR_0075        56
# VAR_0076        56
# VAR_0077        56
# VAR_0078        56
# VAR_0079        56
# VAR_0080        56
# VAR_0081        56
# VAR_0082        56
# VAR_0083        56
# VAR_0084        56
# VAR_0085        56
# VAR_0086        56
# VAR_0087        56
# VAR_0088        56
# VAR_0089        56
# VAR_0090        91
# VAR_0091        91
# VAR_0092        91
# VAR_0093        91
# VAR_0094        91
# VAR_0095        91
# VAR_0096        91
# VAR_0097        91
# VAR_0098        91
# VAR_0099        91
# VAR_0100        91
# VAR_0101        91
# VAR_0102        91
# VAR_0103        91
# VAR_0104        91
# VAR_0105        91
# VAR_0106        91
# VAR_0107        91
# VAR_0108        91
# VAR_0109        91
# VAR_0110        91
# VAR_0111        91
# VAR_0112        91
# VAR_0113        91
# VAR_0114        91
# VAR_0115        91
# VAR_0116        91
# VAR_0117        91
# VAR_0118        91
# VAR_0119        91
# VAR_0120        91
# VAR_0121        91
# VAR_0122        91
# VAR_0123        91
# VAR_0124        91
# VAR_0125        91
# VAR_0126        91
# VAR_0127        91
# VAR_0128        91
# VAR_0129        91
# VAR_0130        91
# VAR_0131        91
# VAR_0132        91
# VAR_0133        91
# VAR_0134        91
# VAR_0135        91
# VAR_0136        91
# VAR_0137        91
# VAR_0138        91
# VAR_0139        91
# VAR_0140        91
# VAR_0141        91
# VAR_0142        91
# VAR_0143        91
# VAR_0144        91
# VAR_0145        91
# VAR_0146        89
# VAR_0147        89
# VAR_0148        89
# VAR_0149        89
# VAR_0150        89
# VAR_0151        89
# VAR_0152        89
# VAR_0153        89
# VAR_0154        89
# VAR_0155        89
# VAR_0156    139361
# VAR_0157    144311
# VAR_0158    143142
# VAR_0159    139361
# VAR_0160        89
# VAR_0161        89
# VAR_0162        89
# VAR_0163        89
# VAR_0164        89
# VAR_0165        89
# VAR_0166    131001
# VAR_0167    142664
# VAR_0168    134506
# VAR_0169    131001
# VAR_0170        89
# VAR_0171        89
# VAR_0172        89
# VAR_0173        89
# VAR_0174        89
# VAR_0175        89
# VAR_0176    127699
# VAR_0177    141873
# VAR_0178    133158
# VAR_0179    127699
# VAR_0180        89
# VAR_0181        89
# VAR_0182        89
# VAR_0183        89
# VAR_0184        89
# VAR_0185        89
# VAR_0186        89
# VAR_0187        89
# VAR_0188        89
# VAR_0189        89
# VAR_0190        89
# VAR_0191        89
# VAR_0192        89
# VAR_0193        89
# VAR_0194        89
# VAR_0195        89
# VAR_0196        56
# VAR_0197        56
# VAR_0198        56
# VAR_0199        56
# VAR_0200        60
# VAR_0201        56
# VAR_0202        56
# VAR_0203        56
# VAR_0204        56
# VAR_0205    142974
# VAR_0206    142903
# VAR_0207    145231
# VAR_0208    125775
# VAR_0209    135844
# VAR_0210    125775
# VAR_0211    125775
# VAR_0212     12550
# VAR_0213    145231
# VAR_0214    145219
# VAR_0215        56
# VAR_0216        56
# VAR_0217        56
# VAR_0219        56
# VAR_0220        56
# VAR_0221        56
# VAR_0222        56
# VAR_0223        56
# VAR_0224        56
# VAR_0225        56
# VAR_0226        56
# VAR_0227        56
# VAR_0228        56
# VAR_0229        56
# VAR_0230        56
# VAR_0231        56
# VAR_0232        56
# VAR_0233        56
# VAR_0234        56
# VAR_0235        56
# VAR_0236        56
# VAR_0237        56
# VAR_0238        56
# VAR_0239        56
# VAR_0241        56
# VAR_0242       918
# VAR_0243       918
# VAR_0244       918
# VAR_0245       918
# VAR_0246       918
# VAR_0247       918
# VAR_0248       918
# VAR_0249       918
# VAR_0250       918
# VAR_0251       918
# VAR_0252       918
# VAR_0253       918
# VAR_0254       918
# VAR_0255       918
# VAR_0256       918
# VAR_0257       918
# VAR_0258       918
# VAR_0259       918
# VAR_0260       918
# VAR_0261       918
# VAR_0262       918
# VAR_0263       918
# VAR_0264       918
# VAR_0265       918
# VAR_0266       918
# VAR_0267       918
# VAR_0268       918
# VAR_0269       918
# VAR_0270       918
# VAR_0271       918
# VAR_0272       918
# VAR_0273       918
# VAR_0274       918
# VAR_0275       918
# VAR_0276       918
# VAR_0277       918
# VAR_0278       918
# VAR_0279       918
# VAR_0280       918
# VAR_0281       918
# VAR_0282       918
# VAR_0283       918
# VAR_0284       918
# VAR_0285       918
# VAR_0286       918
# VAR_0287       918
# VAR_0288       918
# VAR_0289       918
# VAR_0290       918
# VAR_0291       918
# VAR_0292       918
# VAR_0293       918
# VAR_0294       918
# VAR_0295       918
# VAR_0296       918
# VAR_0297       918
# VAR_0298       918
# VAR_0299       918
# VAR_0300       918
# VAR_0301       918
# VAR_0302       918
# VAR_0303       918
# VAR_0304       918
# VAR_0305       918
# VAR_0306       918
# VAR_0307       918
# VAR_0308       918
# VAR_0309       918
# VAR_0310       918
# VAR_0311       918
# VAR_0312       918
# VAR_0313       918
# VAR_0314       918
# VAR_0315       918
# VAR_0316       918
# VAR_0317       918
# VAR_0318       918
# VAR_0319       918
# VAR_0320       918
# VAR_0321       918
# VAR_0322       918
# VAR_0323       918
# VAR_0324       918
# VAR_0325       918
# VAR_0326       918
# VAR_0327       918
# VAR_0328       918
# VAR_0329       918
# VAR_0330       918
# VAR_0331       918
# VAR_0332       918
# VAR_0333       918
# VAR_0334       918
# VAR_0335       918
# VAR_0336       918
# VAR_0337       918
# VAR_0338       918
# VAR_0339       918
# VAR_0340       918
# VAR_0341       918
# VAR_0342       918
# VAR_0343       918
# VAR_0344       918
# VAR_0345       918
# VAR_0346       918
# VAR_0347       918
# VAR_0348       918
# VAR_0349       918
# VAR_0350       927
# VAR_0351       918
# VAR_0352       918
# VAR_0353       918
# VAR_0354       918
# VAR_0355       918
# VAR_0356       918
# VAR_0357       918
# VAR_0358       918
# VAR_0359       918
# VAR_0360       918
# VAR_0361       918
# VAR_0362       918
# VAR_0363       918
# VAR_0364       918
# VAR_0365       918
# VAR_0366       918
# VAR_0367       918
# VAR_0368       918
# VAR_0369       918
# VAR_0370       918
# VAR_0371       918
# VAR_0372       918
# VAR_0373       918
# VAR_0374       918
# VAR_0375       918
# VAR_0376       918
# VAR_0377       918
# VAR_0378       918
# VAR_0379       918
# VAR_0380       918
# VAR_0381       918
# VAR_0382       918
# VAR_0383       918
# VAR_0384       918
# VAR_0385       918
# VAR_0386       918
# VAR_0387       918
# VAR_0388       918
# VAR_0389       918
# VAR_0390       918
# VAR_0391       918
# VAR_0392       918
# VAR_0393       918
# VAR_0394       918
# VAR_0395       918
# VAR_0396       918
# VAR_0397       918
# VAR_0398       918
# VAR_0399       918
# VAR_0400       918
# VAR_0401       918
# VAR_0402       918
# VAR_0403       918
# VAR_0404       918
# VAR_0405       918
# VAR_0406       918
# VAR_0407       918
# VAR_0408       918
# VAR_0409       918
# VAR_0410       918
# VAR_0411       918
# VAR_0412       918
# VAR_0413       918
# VAR_0414       918
# VAR_0415       918
# VAR_0416       918
# VAR_0417       918
# VAR_0418       918
# VAR_0419       918
# VAR_0420       918
# VAR_0421       918
# VAR_0422       918
# VAR_0423       918
# VAR_0424       918
# VAR_0425       918
# VAR_0426       918
# VAR_0427       918
# VAR_0428       918
# VAR_0429       918
# VAR_0430       918
# VAR_0431       918
# VAR_0432       918
# VAR_0433       918
# VAR_0434       918
# VAR_0435       918
# VAR_0436       918
# VAR_0437       918
# VAR_0438       918
# VAR_0439       918
# VAR_0440       918
# VAR_0441       918
# VAR_0442       918
# VAR_0443       918
# VAR_0444       918
# VAR_0445       918
# VAR_0446       918
# VAR_0447       918
# VAR_0448       918
# VAR_0449       918
# VAR_0450       918
# VAR_0451       918
# VAR_0452       918
# VAR_0453       918
# VAR_0454       918
# VAR_0455       918
# VAR_0456       918
# VAR_0457       918
# VAR_0458       918
# VAR_0459       918
# VAR_0460       918
# VAR_0461       918
# VAR_0462       918
# VAR_0463       918
# VAR_0464       918
# VAR_0465       918
# VAR_0466       918
# VAR_0467       918
# VAR_0468       918
# VAR_0469       918
# VAR_0470       918
# VAR_0471       918
# VAR_0472       918
# VAR_0473       918
# VAR_0474       918
# VAR_0475       918
# VAR_0476       918
# VAR_0477       918
# VAR_0478       918
# VAR_0479       918
# VAR_0480       918
# VAR_0481       918
# VAR_0482       918
# VAR_0483       918
# VAR_0484       918
# VAR_0485       918
# VAR_0486       918
# VAR_0487       918
# VAR_0488       918
# VAR_0489       918
# VAR_0490       918
# VAR_0491       918
# VAR_0492       918
# VAR_0493       918
# VAR_0494       918
# VAR_0495       918
# VAR_0496       918
# VAR_0497       918
# VAR_0498       918
# VAR_0499       918
# VAR_0500       918
# VAR_0501       918
# VAR_0502       918
# VAR_0503       918
# VAR_0504       918
# VAR_0505       918
# VAR_0506       918
# VAR_0507       918
# VAR_0508       918
# VAR_0509       918
# VAR_0510       918
# VAR_0511       918
# VAR_0512       918
# VAR_0513       918
# VAR_0514       918
# VAR_0515       918
# VAR_0516       918
# VAR_0517       918
# VAR_0518       918
# VAR_0519       918
# VAR_0520       918
# VAR_0521       918
# VAR_0522       918
# VAR_0523       918
# VAR_0524       918
# VAR_0525       918
# VAR_0526       917
# VAR_0527       918
# VAR_0528       918
# VAR_0529       917
# VAR_0530       918
# VAR_0531       917
# VAR_0840    145231
# dtype: int64

# %%
print('Total number of NaN in the dataframe: ', Xy_original.isnull().sum().sum())
# Out:
# Total number of NaN in the dataframe:  3511742

# %% [markdown]
# ### 1.d) Data Cleaning

# %%
# Standardize the class column to the name of targetVar if required
Xy_original = Xy_original.rename(columns={'target': 'targetVar'})

# %%
# Impute missing values
Xy_original.dropna(subset=['VAR_0008', 'VAR_0090', 'VAR_0242', 'VAR_0200', 'VAR_0350'], inplace=True)

# %%
# Dropping features due to too many missing values in the columns
Xy_original.drop(columns=['VAR_0073', 'VAR_0074'], inplace=True)
Xy_original.drop(columns=['VAR_0156', 'VAR_0157', 'VAR_0158', 'VAR_0159'], inplace=True)
Xy_original.drop(columns=['VAR_0166', 'VAR_0167', 'VAR_0168', 'VAR_0169'], inplace=True)
Xy_original.drop(columns=['VAR_0176', 'VAR_0177', 'VAR_0178', 'VAR_0179'], inplace=True)
Xy_original.drop(columns=['VAR_0205', 'VAR_0206', 'VAR_0207', 'VAR_0208', 'VAR_0209'], inplace=True)
Xy_original.drop(columns=['VAR_0210', 'VAR_0211', 'VAR_0212', 'VAR_0213', 'VAR_0214'], inplace=True)
Xy_original.drop(columns=['VAR_0840'], inplace=True)

# %%
# Dropping features due to non-predictive nature of the columns
Xy_original.drop(columns=['ID'], inplace=True)
Xy_original.drop(columns=['VAR_0008', 'VAR_0009', 'VAR_0010', 'VAR_0011', 'VAR_0012'], inplace=True)
Xy_original.drop(columns=['VAR_0018', 'VAR_0019', 'VAR_0020', 'VAR_0021', 'VAR_0022'], inplace=True)
Xy_original.drop(columns=['VAR_0023', 'VAR_0024', 'VAR_0025', 'VAR_0026', 'VAR_0027'], inplace=True)
Xy_original.drop(columns=['VAR_0028', 'VAR_0029', 'VAR_0030', 'VAR_0031', 'VAR_0032'], inplace=True)
Xy_original.drop(columns=['VAR_0038', 'VAR_0039', 'VAR_0040', 'VAR_0041', 'VAR_0042'], inplace=True)
Xy_original.drop(columns=['VAR_0043', 'VAR_0044', 'VAR_0075'], inplace=True)
Xy_original.drop(columns=['VAR_0188', 'VAR_0189', 'VAR_0190'], inplace=True)
Xy_original.drop(columns=['VAR_0196', 'VAR_0197', 'VAR_0199'], inplace=True)
Xy_original.drop(columns=['VAR_0200', 'VAR_0202', 'VAR_0203', 'VAR_0204'], inplace=True)
Xy_original.drop(columns=['VAR_0215', 'VAR_0216', 'VAR_0217'], inplace=True)
Xy_original.drop(columns=['VAR_0221', 'VAR_0222', 'VAR_0223'], inplace=True)
Xy_original.drop(columns=['VAR_0229', 'VAR_0239', 'VAR_0246'], inplace=True)
Xy_original.drop(columns=['VAR_0394', 'VAR_0404', 'VAR_0438'], inplace=True)
Xy_original.drop(columns=['VAR_0493'], inplace=True)
Xy_original.drop(columns=['VAR_0527', 'VAR_0528', 'VAR_0530'], inplace=True)
Xy_original.drop(columns=['VAR_0847'], inplace=True)
Xy_original.drop(columns=['VAR_1428'], inplace=True)

# %%
# Convert columns from one data type to another
Xy_original['VAR_0001'] = Xy_original['VAR_0001'].astype('category')
Xy_original['VAR_0005'] = Xy_original['VAR_0005'].astype('category')
Xy_original['VAR_0226'] = Xy_original['VAR_0226'].astype('bool')
Xy_original['VAR_0230'] = Xy_original['VAR_0230'].astype('bool')
Xy_original['VAR_0232'] = Xy_original['VAR_0232'].astype('bool')
Xy_original['VAR_0236'] = Xy_original['VAR_0236'].astype('bool')
Xy_original['VAR_0237'] = Xy_original['VAR_0237'].astype('category')
Xy_original['VAR_0274'] = Xy_original['VAR_0274'].astype('category')
Xy_original['VAR_0283'] = Xy_original['VAR_0283'].astype('category')
Xy_original['VAR_0305'] = Xy_original['VAR_0305'].astype('category')
Xy_original['VAR_0325'] = Xy_original['VAR_0325'].astype('category')
Xy_original['VAR_0342'] = Xy_original['VAR_0342'].astype('category')
Xy_original['VAR_0352'] = Xy_original['VAR_0352'].astype('category')
Xy_original['VAR_0353'] = Xy_original['VAR_0353'].astype('category')
Xy_original['VAR_0354'] = Xy_original['VAR_0354'].astype('category')
Xy_original['VAR_0466'] = Xy_original['VAR_0466'].astype('category')
Xy_original['VAR_0467'] = Xy_original['VAR_0467'].astype('category')
Xy_original['VAR_1934'] = Xy_original['VAR_0467'].astype('category')

# %%
# Take a peek at the dataframe after cleaning
Xy_original.head(10)
# Out:
#   VAR_0001  VAR_0002  VAR_0003  ...  VAR_1933    VAR_1934  targetVar
# 0        H       224         0  ...      9998          -1          0
# 1        H         7        53  ...      9998  Discharged          0
# 2        H       116         3  ...      9998          -1          0
# 3        H       240       300  ...      9998          -1          0
# 4        R        72       261  ...      9998          -1          1
# 5        R         4         4  ...      9998          -1          0
# 6        H        60       132  ...        76          -1          1
# 7        R        13        75  ...      9998          -1          0
# 8        R        17        16  ...        90          -1          1
# 9        R        24        72  ...      9998          -1          0
#
# [10 rows x 1852 columns]

# %%
Xy_original.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 144262 entries, 0 to 145230
# Data columns (total 1852 columns):
# VAR_0001     category
# VAR_0002     int64
# VAR_0003     int64
# VAR_0004     int64
# VAR_0005     category
# VAR_0006     float64
# VAR_0007     float64
# VAR_0013     float64
# VAR_0014     float64
# VAR_0015     float64
# VAR_0016     float64
# VAR_0017     float64
# VAR_0033     float64
# VAR_0034     float64
# VAR_0035     float64
# VAR_0036     float64
# VAR_0037     float64
# VAR_0045     float64
# VAR_0046     float64
# VAR_0047     float64
# VAR_0048     float64
# VAR_0049     float64
# VAR_0050     float64
# VAR_0051     float64
# VAR_0052     float64
# VAR_0053     float64
# VAR_0054     float64
# VAR_0055     float64
# VAR_0056     float64
# VAR_0057     float64
# VAR_0058     float64
# VAR_0059     float64
# VAR_0060     float64
# VAR_0061     float64
# VAR_0062     float64
# VAR_0063     float64
# VAR_0064     float64
# VAR_0065     float64
# VAR_0066     float64
# VAR_0067     float64
# VAR_0068     float64
# VAR_0069     float64
# VAR_0070     float64
# VAR_0071     float64
# VAR_0072     float64
# VAR_0076     float64
# VAR_0077     float64
# VAR_0078     float64
# VAR_0079     float64
# VAR_0080     float64
# VAR_0081     float64
# VAR_0082     float64
# VAR_0083     float64
# VAR_0084     float64
# VAR_0085     float64
# VAR_0086     float64
# VAR_0087     float64
# VAR_0088     float64
# VAR_0089     float64
# VAR_0090     float64
# VAR_0091     float64
# VAR_0092     float64
# VAR_0093     float64
# VAR_0094     float64
# VAR_0095     float64
# VAR_0096     float64
# VAR_0097     float64
# VAR_0098     float64
# VAR_0099     float64
# VAR_0100     float64
# VAR_0101     float64
# VAR_0102     float64
# VAR_0103     float64
# VAR_0104     float64
# VAR_0105     float64
# VAR_0106     float64
# VAR_0107     float64
# VAR_0108     float64
# VAR_0109     float64
# VAR_0110     float64
# VAR_0111     float64
# VAR_0112     float64
# VAR_0113     float64
# VAR_0114     float64
# VAR_0115     float64
# VAR_0116     float64
# VAR_0117     float64
# VAR_0118     float64
# VAR_0119     float64
# VAR_0120     float64
# VAR_0121     float64
# VAR_0122     float64
# VAR_0123     float64
# VAR_0124     float64
# VAR_0125     float64
# VAR_0126     float64
# VAR_0127     float64
# VAR_0128     float64
# VAR_0129     float64
# VAR_0130     float64
# VAR_0131     float64
# VAR_0132     float64
# VAR_0133     float64
# VAR_0134     float64
# VAR_0135     float64
# VAR_0136     float64
# VAR_0137     float64
# VAR_0138     float64
# VAR_0139     float64
# VAR_0140     float64
# VAR_0141     float64
# VAR_0142     float64
# VAR_0143     float64
# VAR_0144     float64
# VAR_0145     float64
# VAR_0146     float64
# VAR_0147     float64
# VAR_0148     float64
# VAR_0149     float64
# VAR_0150     float64
# VAR_0151     float64
# VAR_0152     float64
# VAR_0153     float64
# VAR_0154     float64
# VAR_0155     float64
# VAR_0160     float64
# VAR_0161     float64
# VAR_0162     float64
# VAR_0163     float64
# VAR_0164     float64
# VAR_0165     float64
# VAR_0170     float64
# VAR_0171     float64
# VAR_0172     float64
# VAR_0173     float64
# VAR_0174     float64
# VAR_0175     float64
# VAR_0180     float64
# VAR_0181     float64
# VAR_0182     float64
# VAR_0183     float64
# VAR_0184     float64
# VAR_0185     float64
# VAR_0186     float64
# VAR_0187     float64
# VAR_0191     float64
# VAR_0192     float64
# VAR_0193     float64
# VAR_0194     float64
# VAR_0195     float64
# VAR_0198     float64
# VAR_0201     float64
# VAR_0219     float64
# VAR_0220     float64
# VAR_0224     float64
# VAR_0225     float64
# VAR_0226     bool
# VAR_0227     float64
# VAR_0228     float64
# VAR_0230     bool
# VAR_0231     float64
# VAR_0232     bool
# VAR_0233     float64
# VAR_0234     float64
# VAR_0235     float64
# VAR_0236     bool
# VAR_0237     category
# VAR_0238     float64
# VAR_0241     float64
# VAR_0242     float64
# VAR_0243     float64
# VAR_0244     float64
# VAR_0245     float64
# VAR_0247     float64
# VAR_0248     float64
# VAR_0249     float64
# VAR_0250     float64
# VAR_0251     float64
# VAR_0252     float64
# VAR_0253     float64
# VAR_0254     float64
# VAR_0255     float64
# VAR_0256     float64
# VAR_0257     float64
# VAR_0258     float64
# VAR_0259     float64
# VAR_0260     float64
# VAR_0261     float64
# VAR_0262     float64
# VAR_0263     float64
# VAR_0264     float64
# VAR_0265     float64
# VAR_0266     float64
# VAR_0267     float64
# VAR_0268     float64
# VAR_0269     float64
# VAR_0270     float64
# VAR_0271     float64
# VAR_0272     float64
# VAR_0273     float64
# VAR_0274     category
# VAR_0275     float64
# VAR_0276     float64
# VAR_0277     float64
# VAR_0278     float64
# VAR_0279     float64
# VAR_0280     float64
# VAR_0281     float64
# VAR_0282     float64
# VAR_0283     category
# VAR_0284     float64
# VAR_0285     float64
# VAR_0286     float64
# VAR_0287     float64
# VAR_0288     float64
# VAR_0289     float64
# VAR_0290     float64
# VAR_0291     float64
# VAR_0292     float64
# VAR_0293     float64
# VAR_0294     float64
# VAR_0295     float64
# VAR_0296     float64
# VAR_0297     float64
# VAR_0298     float64
# VAR_0299     float64
# VAR_0300     float64
# VAR_0301     float64
# VAR_0302     float64
# VAR_0303     float64
# VAR_0304     float64
# VAR_0305     category
# VAR_0306     float64
# VAR_0307     float64
# VAR_0308     float64
# VAR_0309     float64
# VAR_0310     float64
# VAR_0311     float64
# VAR_0312     float64
# VAR_0313     float64
# VAR_0314     float64
# VAR_0315     float64
# VAR_0316     float64
# VAR_0317     float64
# VAR_0318     float64
# VAR_0319     float64
# VAR_0320     float64
# VAR_0321     float64
# VAR_0322     float64
# VAR_0323     float64
# VAR_0324     float64
# VAR_0325     category
# VAR_0326     float64
# VAR_0327     float64
# VAR_0328     float64
# VAR_0329     float64
# VAR_0330     float64
# VAR_0331     float64
# VAR_0332     float64
# VAR_0333     float64
# VAR_0334     float64
# VAR_0335     float64
# VAR_0336     float64
# VAR_0337     float64
# VAR_0338     float64
# VAR_0339     float64
# VAR_0340     float64
# VAR_0341     float64
# VAR_0342     category
# VAR_0343     float64
# VAR_0344     float64
# VAR_0345     float64
# VAR_0346     float64
# VAR_0347     float64
# VAR_0348     float64
# VAR_0349     float64
# VAR_0350     float64
# VAR_0351     float64
# VAR_0352     category
# VAR_0353     category
# VAR_0354     category
# VAR_0355     float64
# VAR_0356     float64
# VAR_0357     float64
# VAR_0358     float64
# VAR_0359     float64
# VAR_0360     float64
# VAR_0361     float64
# VAR_0362     float64
# VAR_0363     float64
# VAR_0364     float64
# VAR_0365     float64
# VAR_0366     float64
# VAR_0367     float64
# VAR_0368     float64
# VAR_0369     float64
# VAR_0370     float64
# VAR_0371     float64
# VAR_0372     float64
# VAR_0373     float64
# VAR_0374     float64
# VAR_0375     float64
# VAR_0376     float64
# VAR_0377     float64
# VAR_0378     float64
# VAR_0379     float64
# VAR_0380     float64
# VAR_0381     float64
# VAR_0382     float64
# VAR_0383     float64
# VAR_0384     float64
# VAR_0385     float64
# VAR_0386     float64
# VAR_0387     float64
# VAR_0388     float64
# VAR_0389     float64
# VAR_0390     float64
# VAR_0391     float64
# VAR_0392     float64
# VAR_0393     float64
# VAR_0395     float64
# VAR_0396     float64
# VAR_0397     float64
# VAR_0398     float64
# VAR_0399     float64
# VAR_0400     float64
# VAR_0401     float64
# VAR_0402     float64
# VAR_0403     float64
# VAR_0405     float64
# VAR_0406     float64
# VAR_0407     float64
# VAR_0408     float64
# VAR_0409     float64
# VAR_0410     float64
# VAR_0411     float64
# VAR_0412     float64
# VAR_0413     float64
# VAR_0414     float64
# VAR_0415     float64
# VAR_0416     float64
# VAR_0417     float64
# VAR_0418     float64
# VAR_0419     float64
# VAR_0420     float64
# VAR_0421     float64
# VAR_0422     float64
# VAR_0423     float64
# VAR_0424     float64
# VAR_0425     float64
# VAR_0426     float64
# VAR_0427     float64
# VAR_0428     float64
# VAR_0429     float64
# VAR_0430     float64
# VAR_0431     float64
# VAR_0432     float64
# VAR_0433     float64
# VAR_0434     float64
# VAR_0435     float64
# VAR_0436     float64
# VAR_0437     float64
# VAR_0439     float64
# VAR_0440     float64
# VAR_0441     float64
# VAR_0442     float64
# VAR_0443     float64
# VAR_0444     float64
# VAR_0445     float64
# VAR_0446     float64
# VAR_0447     float64
# VAR_0448     float64
# VAR_0449     float64
# VAR_0450     float64
# VAR_0451     float64
# VAR_0452     float64
# VAR_0453     float64
# VAR_0454     float64
# VAR_0455     float64
# VAR_0456     float64
# VAR_0457     float64
# VAR_0458     float64
# VAR_0459     float64
# VAR_0460     float64
# VAR_0461     float64
# VAR_0462     float64
# VAR_0463     float64
# VAR_0464     float64
# VAR_0465     float64
# VAR_0466     category
# VAR_0467     category
# VAR_0468     float64
# VAR_0469     float64
# VAR_0470     float64
# VAR_0471     float64
# VAR_0472     float64
# VAR_0473     float64
# VAR_0474     float64
# VAR_0475     float64
# VAR_0476     float64
# VAR_0477     float64
# VAR_0478     float64
# VAR_0479     float64
# VAR_0480     float64
# VAR_0481     float64
# VAR_0482     float64
# VAR_0483     float64
# VAR_0484     float64
# VAR_0485     float64
# VAR_0486     float64
# VAR_0487     float64
# VAR_0488     float64
# VAR_0489     float64
# VAR_0490     float64
# VAR_0491     float64
# VAR_0492     float64
# VAR_0494     float64
# VAR_0495     float64
# VAR_0496     float64
# VAR_0497     float64
# VAR_0498     float64
# VAR_0499     float64
# VAR_0500     float64
# VAR_0501     float64
# VAR_0502     float64
# VAR_0503     float64
# VAR_0504     float64
# VAR_0505     float64
# VAR_0506     float64
# VAR_0507     float64
# VAR_0508     float64
# VAR_0509     float64
# VAR_0510     float64
# VAR_0511     float64
# VAR_0512     float64
# VAR_0513     float64
# VAR_0514     float64
# VAR_0515     float64
# VAR_0516     float64
# VAR_0517     float64
# VAR_0518     float64
# VAR_0519     float64
# VAR_0520     float64
# VAR_0521     float64
# VAR_0522     float64
# VAR_0523     float64
# VAR_0524     float64
# VAR_0525     float64
# VAR_0526     float64
# VAR_0529     float64
# VAR_0531     float64
# VAR_0532     int64
# VAR_0533     int64
# VAR_0534     int64
# VAR_0535     int64
# VAR_0536     int64
# VAR_0537     int64
# VAR_0538     int64
# VAR_0539     int64
# VAR_0540     int64
# VAR_0541     int64
# VAR_0542     int64
# VAR_0543     int64
# VAR_0544     int64
# VAR_0545     int64
# VAR_0546     int64
# VAR_0547     int64
# VAR_0548     int64
# VAR_0549     int64
# VAR_0550     int64
# VAR_0551     int64
# VAR_0552     int64
# VAR_0553     int64
# VAR_0554     int64
# VAR_0555     int64
# VAR_0556     int64
# VAR_0557     int64
# VAR_0558     int64
# VAR_0559     int64
# VAR_0560     int64
# VAR_0561     int64
# VAR_0562     int64
# VAR_0563     int64
# VAR_0564     int64
# VAR_0565     int64
# VAR_0566     int64
# VAR_0567     int64
# VAR_0568     int64
# VAR_0569     int64
# VAR_0570     int64
# VAR_0571     int64
# VAR_0572     int64
# VAR_0573     int64
# VAR_0574     int64
# VAR_0575     int64
# VAR_0576     int64
# VAR_0577     int64
# VAR_0578     int64
# VAR_0579     int64
# VAR_0580     int64
# VAR_0581     int64
# VAR_0582     int64
# VAR_0583     int64
# VAR_0584     int64
# VAR_0585     int64
# VAR_0586     int64
# VAR_0587     int64
# VAR_0588     int64
# VAR_0589     int64
# VAR_0590     int64
# VAR_0591     int64
# VAR_0592     int64
# VAR_0593     int64
# VAR_0594     int64
# VAR_0595     int64
# VAR_0596     int64
# VAR_0597     int64
# VAR_0598     int64
# VAR_0599     int64
# VAR_0600     int64
# VAR_0601     int64
# VAR_0602     int64
# VAR_0603     int64
# VAR_0604     int64
# VAR_0605     int64
# VAR_0606     int64
# VAR_0607     int64
# VAR_0608     int64
# VAR_0609     int64
# VAR_0610     int64
# VAR_0611     int64
# VAR_0612     int64
# VAR_0613     int64
# VAR_0614     int64
# VAR_0615     int64
# VAR_0616     int64
# VAR_0617     int64
# VAR_0618     int64
# VAR_0619     int64
# VAR_0620     int64
# VAR_0621     int64
# VAR_0622     int64
# VAR_0623     int64
# VAR_0624     int64
# VAR_0625     int64
# VAR_0626     int64
# VAR_0627     int64
# VAR_0628     int64
# VAR_0629     int64
# VAR_0630     int64
# VAR_0631     int64
# VAR_0632     int64
# VAR_0633     int64
# VAR_0634     int64
# VAR_0635     int64
# VAR_0636     int64
# VAR_0637     int64
# VAR_0638     int64
# VAR_0639     int64
# VAR_0640     int64
# VAR_0641     int64
# VAR_0642     int64
# VAR_0643     int64
# VAR_0644     int64
# VAR_0645     int64
# VAR_0646     int64
# VAR_0647     int64
# VAR_0648     int64
# VAR_0649     int64
# VAR_0650     int64
# VAR_0651     int64
# VAR_0652     int64
# VAR_0653     int64
# VAR_0654     int64
# VAR_0655     int64
# VAR_0656     int64
# VAR_0657     int64
# VAR_0658     int64
# VAR_0659     int64
# VAR_0660     int64
# VAR_0661     int64
# VAR_0662     int64
# VAR_0663     int64
# VAR_0664     int64
# VAR_0665     int64
# VAR_0666     int64
# VAR_0667     int64
# VAR_0668     int64
# VAR_0669     int64
# VAR_0670     int64
# VAR_0671     int64
# VAR_0672     int64
# VAR_0673     int64
# VAR_0674     int64
# VAR_0675     int64
# VAR_0676     int64
# VAR_0677     int64
# VAR_0678     int64
# VAR_0679     int64
# VAR_0680     int64
# VAR_0681     int64
# VAR_0682     int64
# VAR_0683     int64
# VAR_0684     int64
# VAR_0685     int64
# VAR_0686     int64
# VAR_0687     int64
# VAR_0688     int64
# VAR_0689     int64
# VAR_0690     int64
# VAR_0691     int64
# VAR_0692     int64
# VAR_0693     int64
# VAR_0694     int64
# VAR_0695     int64
# VAR_0696     int64
# VAR_0697     int64
# VAR_0698     int64
# VAR_0699     int64
# VAR_0700     int64
# VAR_0701     int64
# VAR_0702     int64
# VAR_0703     int64
# VAR_0704     int64
# VAR_0705     int64
# VAR_0706     int64
# VAR_0707     int64
# VAR_0708     int64
# VAR_0709     int64
# VAR_0710     int64
# VAR_0711     int64
# VAR_0712     int64
# VAR_0713     int64
# VAR_0714     int64
# VAR_0715     int64
# VAR_0716     int64
# VAR_0717     int64
# VAR_0718     int64
# VAR_0719     int64
# VAR_0720     int64
# VAR_0721     int64
# VAR_0722     int64
# VAR_0723     int64
# VAR_0724     int64
# VAR_0725     int64
# VAR_0726     int64
# VAR_0727     int64
# VAR_0728     int64
# VAR_0729     int64
# VAR_0730     int64
# VAR_0731     int64
# VAR_0732     int64
# VAR_0733     int64
# VAR_0734     int64
# VAR_0735     int64
# VAR_0736     int64
# VAR_0737     int64
# VAR_0738     int64
# VAR_0739     int64
# VAR_0740     int64
# VAR_0741     int64
# VAR_0742     int64
# VAR_0743     int64
# VAR_0744     int64
# VAR_0745     int64
# VAR_0746     int64
# VAR_0747     int64
# VAR_0748     int64
# VAR_0749     int64
# VAR_0750     int64
# VAR_0751     int64
# VAR_0752     int64
# VAR_0753     int64
# VAR_0754     int64
# VAR_0755     int64
# VAR_0756     int64
# VAR_0757     int64
# VAR_0758     int64
# VAR_0759     int64
# VAR_0760     int64
# VAR_0761     int64
# VAR_0762     int64
# VAR_0763     int64
# VAR_0764     int64
# VAR_0765     int64
# VAR_0766     int64
# VAR_0767     int64
# VAR_0768     int64
# VAR_0769     int64
# VAR_0770     int64
# VAR_0771     int64
# VAR_0772     int64
# VAR_0773     int64
# VAR_0774     int64
# VAR_0775     int64
# VAR_0776     int64
# VAR_0777     int64
# VAR_0778     int64
# VAR_0779     int64
# VAR_0780     int64
# VAR_0781     int64
# VAR_0782     int64
# VAR_0783     int64
# VAR_0784     int64
# VAR_0785     int64
# VAR_0786     int64
# VAR_0787     int64
# VAR_0788     int64
# VAR_0789     int64
# VAR_0790     int64
# VAR_0791     int64
# VAR_0792     int64
# VAR_0793     int64
# VAR_0794     int64
# VAR_0795     int64
# VAR_0796     int64
# VAR_0797     int64
# VAR_0798     int64
# VAR_0799     int64
# VAR_0800     int64
# VAR_0801     int64
# VAR_0802     int64
# VAR_0803     int64
# VAR_0804     int64
# VAR_0805     int64
# VAR_0806     int64
# VAR_0807     int64
# VAR_0808     int64
# VAR_0809     int64
# VAR_0810     int64
# VAR_0811     int64
# VAR_0812     int64
# VAR_0813     int64
# VAR_0814     int64
# VAR_0815     int64
# VAR_0816     int64
# VAR_0817     int64
# VAR_0818     int64
# VAR_0819     int64
# VAR_0820     int64
# VAR_0821     int64
# VAR_0822     int64
# VAR_0823     int64
# VAR_0824     int64
# VAR_0825     int64
# VAR_0826     int64
# VAR_0827     int64
# VAR_0828     int64
# VAR_0829     int64
# VAR_0830     int64
# VAR_0831     int64
# VAR_0832     int64
# VAR_0833     int64
# VAR_0834     int64
# VAR_0835     int64
# VAR_0836     int64
# VAR_0837     int64
# VAR_0838     int64
# VAR_0839     int64
# VAR_0841     int64
# VAR_0842     int64
# VAR_0843     int64
# VAR_0844     int64
# VAR_0845     int64
# VAR_0846     int64
# VAR_0848     int64
# VAR_0849     int64
# VAR_0850     int64
# VAR_0851     int64
# VAR_0852     int64
# VAR_0853     int64
# VAR_0854     int64
# VAR_0855     int64
# VAR_0856     int64
# VAR_0857     int64
# VAR_0858     int64
# VAR_0859     int64
# VAR_0860     int64
# VAR_0861     int64
# VAR_0862     int64
# VAR_0863     int64
# VAR_0864     int64
# VAR_0865     int64
# VAR_0866     int64
# VAR_0867     int64
# VAR_0868     int64
# VAR_0869     int64
# VAR_0870     int64
# VAR_0871     int64
# VAR_0872     int64
# VAR_0873     int64
# VAR_0874     int64
# VAR_0875     int64
# VAR_0876     int64
# VAR_0877     int64
# VAR_0878     int64
# VAR_0879     int64
# VAR_0880     int64
# VAR_0881     int64
# VAR_0882     int64
# VAR_0883     int64
# VAR_0884     int64
# VAR_0885     int64
# VAR_0886     int64
# VAR_0887     int64
# VAR_0888     int64
# VAR_0889     int64
# VAR_0890     int64
# VAR_0891     int64
# VAR_0892     int64
# VAR_0893     int64
# VAR_0894     int64
# VAR_0895     int64
# VAR_0896     int64
# VAR_0897     int64
# VAR_0898     int64
# VAR_0899     int64
# VAR_0900     int64
# VAR_0901     int64
# VAR_0902     int64
# VAR_0903     int64
# VAR_0904     int64
# VAR_0905     int64
# VAR_0906     int64
# VAR_0907     int64
# VAR_0908     int64
# VAR_0909     int64
# VAR_0910     int64
# VAR_0911     int64
# VAR_0912     int64
# VAR_0913     int64
# VAR_0914     int64
# VAR_0915     int64
# VAR_0916     int64
# VAR_0917     int64
# VAR_0918     int64
# VAR_0919     int64
# VAR_0920     int64
# VAR_0921     int64
# VAR_0922     int64
# VAR_0923     int64
# VAR_0924     int64
# VAR_0925     int64
# VAR_0926     int64
# VAR_0927     int64
# VAR_0928     int64
# VAR_0929     int64
# VAR_0930     int64
# VAR_0931     int64
# VAR_0932     int64
# VAR_0933     int64
# VAR_0934     int64
# VAR_0935     int64
# VAR_0936     int64
# VAR_0937     int64
# VAR_0938     int64
# VAR_0939     int64
# VAR_0940     int64
# VAR_0941     int64
# VAR_0942     int64
# VAR_0943     int64
# VAR_0944     int64
# VAR_0945     int64
# VAR_0946     int64
# VAR_0947     int64
# VAR_0948     int64
# VAR_0949     int64
# VAR_0950     int64
# VAR_0951     int64
# VAR_0952     int64
# VAR_0953     int64
# VAR_0954     int64
# VAR_0955     int64
# VAR_0956     int64
# VAR_0957     int64
# VAR_0958     int64
# VAR_0959     int64
# VAR_0960     int64
# VAR_0961     int64
# VAR_0962     int64
# VAR_0963     int64
# VAR_0964     int64
# VAR_0965     int64
# VAR_0966     int64
# VAR_0967     int64
# VAR_0968     int64
# VAR_0969     int64
# VAR_0970     int64
# VAR_0971     int64
# VAR_0972     int64
# VAR_0973     int64
# VAR_0974     int64
# VAR_0975     int64
# VAR_0976     int64
# VAR_0977     int64
# VAR_0978     int64
# VAR_0979     int64
# VAR_0980     int64
# VAR_0981     int64
# VAR_0982     int64
# VAR_0983     int64
# VAR_0984     int64
# VAR_0985     int64
# VAR_0986     int64
# VAR_0987     int64
# VAR_0988     int64
# VAR_0989     int64
# VAR_0990     int64
# VAR_0991     int64
# VAR_0992     int64
# VAR_0993     int64
# VAR_0994     int64
# VAR_0995     int64
# VAR_0996     int64
# VAR_0997     int64
# VAR_0998     int64
# VAR_0999     int64
# VAR_1000     int64
# VAR_1001     int64
# VAR_1002     int64
# VAR_1003     int64
# VAR_1004     int64
# VAR_1005     int64
# VAR_1006     int64
# VAR_1007     int64
# VAR_1008     int64
# VAR_1009     int64
# VAR_1010     int64
# VAR_1011     int64
# VAR_1012     int64
# VAR_1013     int64
# VAR_1014     int64
# VAR_1015     int64
# VAR_1016     int64
# VAR_1017     int64
# VAR_1018     int64
# VAR_1019     int64
# VAR_1020     int64
# VAR_1021     int64
# VAR_1022     int64
# VAR_1023     int64
# VAR_1024     int64
# VAR_1025     int64
# VAR_1026     int64
# VAR_1027     int64
# VAR_1028     int64
# VAR_1029     int64
# VAR_1030     int64
# VAR_1031     int64
# VAR_1032     int64
# VAR_1033     int64
# VAR_1034     int64
# VAR_1035     int64
# VAR_1036     int64
# VAR_1037     int64
# VAR_1038     int64
# VAR_1039     int64
# VAR_1040     int64
# VAR_1041     int64
# VAR_1042     int64
# VAR_1043     int64
# VAR_1044     int64
# VAR_1045     int64
# VAR_1046     int64
# VAR_1047     int64
# VAR_1048     int64
# VAR_1049     int64
# VAR_1050     int64
# VAR_1051     int64
# VAR_1052     int64
# VAR_1053     int64
# VAR_1054     int64
# VAR_1055     int64
# VAR_1056     int64
# VAR_1057     int64
# VAR_1058     int64
# VAR_1059     int64
# VAR_1060     int64
# VAR_1061     int64
# VAR_1062     int64
# VAR_1063     int64
# VAR_1064     int64
# VAR_1065     int64
# VAR_1066     int64
# VAR_1067     int64
# VAR_1068     int64
# VAR_1069     int64
# VAR_1070     int64
# VAR_1071     int64
# VAR_1072     int64
# VAR_1073     int64
# VAR_1074     int64
# VAR_1075     int64
# VAR_1076     int64
# VAR_1077     int64
# VAR_1078     int64
# VAR_1079     int64
# VAR_1080     int64
# VAR_1081     int64
# VAR_1082     int64
# VAR_1083     int64
# VAR_1084     int64
# VAR_1085     int64
# VAR_1086     int64
# VAR_1087     int64
# VAR_1088     int64
# VAR_1089     int64
# VAR_1090     int64
# VAR_1091     int64
# VAR_1092     int64
# VAR_1093     int64
# VAR_1094     int64
# VAR_1095     int64
# VAR_1096     int64
# VAR_1097     int64
# VAR_1098     int64
# VAR_1099     int64
# VAR_1100     int64
# VAR_1101     int64
# VAR_1102     int64
# VAR_1103     int64
# VAR_1104     int64
# VAR_1105     int64
# VAR_1106     int64
# VAR_1107     int64
# VAR_1108     int64
# VAR_1109     int64
# VAR_1110     int64
# VAR_1111     int64
# VAR_1112     int64
# VAR_1113     int64
# VAR_1114     int64
# VAR_1115     int64
# VAR_1116     int64
# VAR_1117     int64
# VAR_1118     int64
# VAR_1119     int64
# VAR_1120     int64
# VAR_1121     int64
# VAR_1122     int64
# VAR_1123     int64
# VAR_1124     int64
# VAR_1125     int64
# VAR_1126     int64
# VAR_1127     int64
# VAR_1128     int64
# VAR_1129     int64
# VAR_1130     int64
# VAR_1131     int64
# VAR_1132     int64
# VAR_1133     int64
# VAR_1134     int64
# VAR_1135     int64
# VAR_1136     int64
# VAR_1137     int64
# VAR_1138     int64
# VAR_1139     int64
# VAR_1140     int64
# VAR_1141     int64
# VAR_1142     int64
# VAR_1143     int64
# VAR_1144     int64
# VAR_1145     int64
# VAR_1146     int64
# VAR_1147     int64
# VAR_1148     int64
# VAR_1149     int64
# VAR_1150     int64
# VAR_1151     int64
# VAR_1152     int64
# VAR_1153     int64
# VAR_1154     int64
# VAR_1155     int64
# VAR_1156     int64
# VAR_1157     int64
# VAR_1158     int64
# VAR_1159     int64
# VAR_1160     int64
# VAR_1161     int64
# VAR_1162     int64
# VAR_1163     int64
# VAR_1164     int64
# VAR_1165     int64
# VAR_1166     int64
# VAR_1167     int64
# VAR_1168     int64
# VAR_1169     int64
# VAR_1170     int64
# VAR_1171     int64
# VAR_1172     int64
# VAR_1173     int64
# VAR_1174     int64
# VAR_1175     int64
# VAR_1176     int64
# VAR_1177     int64
# VAR_1178     int64
# VAR_1179     int64
# VAR_1180     int64
# VAR_1181     int64
# VAR_1182     int64
# VAR_1183     int64
# VAR_1184     int64
# VAR_1185     int64
# VAR_1186     int64
# VAR_1187     int64
# VAR_1188     int64
# VAR_1189     int64
# VAR_1190     int64
# VAR_1191     int64
# VAR_1192     int64
# VAR_1193     int64
# VAR_1194     int64
# VAR_1195     int64
# VAR_1196     int64
# VAR_1197     int64
# VAR_1198     int64
# VAR_1199     int64
# VAR_1200     int64
# VAR_1201     int64
# VAR_1202     int64
# VAR_1203     int64
# VAR_1204     int64
# VAR_1205     int64
# VAR_1206     int64
# VAR_1207     int64
# VAR_1208     int64
# VAR_1209     int64
# VAR_1210     int64
# VAR_1211     int64
# VAR_1212     int64
# VAR_1213     int64
# VAR_1214     int64
# VAR_1215     int64
# VAR_1216     int64
# VAR_1217     int64
# VAR_1218     int64
# VAR_1219     int64
# VAR_1220     int64
# VAR_1221     int64
# VAR_1222     int64
# VAR_1223     int64
# VAR_1224     int64
# VAR_1225     int64
# VAR_1226     int64
# VAR_1227     int64
# VAR_1228     int64
# VAR_1229     int64
# VAR_1230     int64
# VAR_1231     int64
# VAR_1232     int64
# VAR_1233     int64
# VAR_1234     int64
# VAR_1235     int64
# VAR_1236     int64
# VAR_1237     int64
# VAR_1238     int64
# VAR_1239     int64
# VAR_1240     int64
# VAR_1241     int64
# VAR_1242     int64
# VAR_1243     int64
# VAR_1244     int64
# VAR_1245     int64
# VAR_1246     int64
# VAR_1247     int64
# VAR_1248     int64
# VAR_1249     int64
# VAR_1250     int64
# VAR_1251     int64
# VAR_1252     int64
# VAR_1253     int64
# VAR_1254     int64
# VAR_1255     int64
# VAR_1256     int64
# VAR_1257     int64
# VAR_1258     int64
# VAR_1259     int64
# VAR_1260     int64
# VAR_1261     int64
# VAR_1262     int64
# VAR_1263     int64
# VAR_1264     int64
# VAR_1265     int64
# VAR_1266     int64
# VAR_1267     int64
# VAR_1268     int64
# VAR_1269     int64
# VAR_1270     int64
# VAR_1271     int64
# VAR_1272     int64
# VAR_1273     int64
# VAR_1274     int64
# VAR_1275     int64
# VAR_1276     int64
# VAR_1277     int64
# VAR_1278     int64
# VAR_1279     int64
# VAR_1280     int64
# VAR_1281     int64
# VAR_1282     int64
# VAR_1283     int64
# VAR_1284     int64
# VAR_1285     int64
# VAR_1286     int64
# VAR_1287     int64
# VAR_1288     int64
# VAR_1289     int64
# VAR_1290     int64
# VAR_1291     int64
# VAR_1292     int64
# VAR_1293     int64
# VAR_1294     int64
# VAR_1295     int64
# VAR_1296     int64
# VAR_1297     int64
# VAR_1298     int64
# VAR_1299     int64
# VAR_1300     int64
# VAR_1301     int64
# VAR_1302     int64
# VAR_1303     int64
# VAR_1304     int64
# VAR_1305     int64
# VAR_1306     int64
# VAR_1307     int64
# VAR_1308     int64
# VAR_1309     int64
# VAR_1310     int64
# VAR_1311     int64
# VAR_1312     int64
# VAR_1313     int64
# VAR_1314     int64
# VAR_1315     int64
# VAR_1316     int64
# VAR_1317     int64
# VAR_1318     int64
# VAR_1319     int64
# VAR_1320     int64
# VAR_1321     int64
# VAR_1322     int64
# VAR_1323     int64
# VAR_1324     int64
# VAR_1325     int64
# VAR_1326     int64
# VAR_1327     int64
# VAR_1328     int64
# VAR_1329     int64
# VAR_1330     int64
# VAR_1331     int64
# VAR_1332     int64
# VAR_1333     int64
# VAR_1334     int64
# VAR_1335     int64
# VAR_1336     int64
# VAR_1337     int64
# VAR_1338     int64
# VAR_1339     int64
# VAR_1340     int64
# VAR_1341     int64
# VAR_1342     int64
# VAR_1343     int64
# VAR_1344     int64
# VAR_1345     int64
# VAR_1346     int64
# VAR_1347     int64
# VAR_1348     int64
# VAR_1349     int64
# VAR_1350     int64
# VAR_1351     int64
# VAR_1352     int64
# VAR_1353     int64
# VAR_1354     int64
# VAR_1355     int64
# VAR_1356     int64
# VAR_1357     int64
# VAR_1358     int64
# VAR_1359     int64
# VAR_1360     int64
# VAR_1361     int64
# VAR_1362     int64
# VAR_1363     int64
# VAR_1364     int64
# VAR_1365     int64
# VAR_1366     int64
# VAR_1367     int64
# VAR_1368     int64
# VAR_1369     int64
# VAR_1370     int64
# VAR_1371     int64
# VAR_1372     int64
# VAR_1373     int64
# VAR_1374     int64
# VAR_1375     int64
# VAR_1376     int64
# VAR_1377     int64
# VAR_1378     int64
# VAR_1379     int64
# VAR_1380     int64
# VAR_1381     int64
# VAR_1382     int64
# VAR_1383     int64
# VAR_1384     int64
# VAR_1385     int64
# VAR_1386     int64
# VAR_1387     int64
# VAR_1388     int64
# VAR_1389     int64
# VAR_1390     int64
# VAR_1391     int64
# VAR_1392     int64
# VAR_1393     int64
# VAR_1394     int64
# VAR_1395     int64
# VAR_1396     int64
# VAR_1397     int64
# VAR_1398     int64
# VAR_1399     int64
# VAR_1400     int64
# VAR_1401     int64
# VAR_1402     int64
# VAR_1403     int64
# VAR_1404     int64
# VAR_1405     int64
# VAR_1406     int64
# VAR_1407     int64
# VAR_1408     int64
# VAR_1409     int64
# VAR_1410     int64
# VAR_1411     int64
# VAR_1412     int64
# VAR_1413     int64
# VAR_1414     int64
# VAR_1415     int64
# VAR_1416     int64
# VAR_1417     int64
# VAR_1418     int64
# VAR_1419     int64
# VAR_1420     int64
# VAR_1421     int64
# VAR_1422     int64
# VAR_1423     int64
# VAR_1424     int64
# VAR_1425     int64
# VAR_1426     int64
# VAR_1427     int64
# VAR_1429     int64
# VAR_1430     int64
# VAR_1431     int64
# VAR_1432     int64
# VAR_1433     int64
# VAR_1434     int64
# VAR_1435     int64
# VAR_1436     int64
# VAR_1437     int64
# VAR_1438     int64
# VAR_1439     int64
# VAR_1440     int64
# VAR_1441     int64
# VAR_1442     int64
# VAR_1443     int64
# VAR_1444     int64
# VAR_1445     int64
# VAR_1446     int64
# VAR_1447     int64
# VAR_1448     int64
# VAR_1449     int64
# VAR_1450     int64
# VAR_1451     int64
# VAR_1452     int64
# VAR_1453     int64
# VAR_1454     int64
# VAR_1455     int64
# VAR_1456     int64
# VAR_1457     int64
# VAR_1458     int64
# VAR_1459     int64
# VAR_1460     int64
# VAR_1461     int64
# VAR_1462     int64
# VAR_1463     int64
# VAR_1464     int64
# VAR_1465     int64
# VAR_1466     int64
# VAR_1467     int64
# VAR_1468     int64
# VAR_1469     int64
# VAR_1470     int64
# VAR_1471     int64
# VAR_1472     int64
# VAR_1473     int64
# VAR_1474     int64
# VAR_1475     int64
# VAR_1476     int64
# VAR_1477     int64
# VAR_1478     int64
# VAR_1479     int64
# VAR_1480     int64
# VAR_1481     int64
# VAR_1482     int64
# VAR_1483     int64
# VAR_1484     int64
# VAR_1485     int64
# VAR_1486     int64
# VAR_1487     int64
# VAR_1488     int64
# VAR_1489     int64
# VAR_1490     int64
# VAR_1491     int64
# VAR_1492     int64
# VAR_1493     int64
# VAR_1494     int64
# VAR_1495     int64
# VAR_1496     int64
# VAR_1497     int64
# VAR_1498     int64
# VAR_1499     int64
# VAR_1500     int64
# VAR_1501     int64
# VAR_1502     int64
# VAR_1503     int64
# VAR_1504     int64
# VAR_1505     int64
# VAR_1506     int64
# VAR_1507     int64
# VAR_1508     int64
# VAR_1509     int64
# VAR_1510     int64
# VAR_1511     int64
# VAR_1512     int64
# VAR_1513     int64
# VAR_1514     int64
# VAR_1515     int64
# VAR_1516     int64
# VAR_1517     int64
# VAR_1518     int64
# VAR_1519     int64
# VAR_1520     int64
# VAR_1521     int64
# VAR_1522     int64
# VAR_1523     int64
# VAR_1524     int64
# VAR_1525     int64
# VAR_1526     int64
# VAR_1527     int64
# VAR_1528     int64
# VAR_1529     int64
# VAR_1530     int64
# VAR_1531     int64
# VAR_1532     int64
# VAR_1533     int64
# VAR_1534     int64
# VAR_1535     int64
# VAR_1536     int64
# VAR_1537     int64
# VAR_1538     int64
# VAR_1539     int64
# VAR_1540     int64
# VAR_1541     int64
# VAR_1542     int64
# VAR_1543     int64
# VAR_1544     int64
# VAR_1545     int64
# VAR_1546     int64
# VAR_1547     int64
# VAR_1548     int64
# VAR_1549     int64
# VAR_1550     int64
# VAR_1551     int64
# VAR_1552     int64
# VAR_1553     int64
# VAR_1554     int64
# VAR_1555     int64
# VAR_1556     int64
# VAR_1557     int64
# VAR_1558     int64
# VAR_1559     int64
# VAR_1560     int64
# VAR_1561     int64
# VAR_1562     int64
# VAR_1563     int64
# VAR_1564     int64
# VAR_1565     int64
# VAR_1566     int64
# VAR_1567     int64
# VAR_1568     int64
# VAR_1569     int64
# VAR_1570     int64
# VAR_1571     int64
# VAR_1572     int64
# VAR_1573     int64
# VAR_1574     int64
# VAR_1575     int64
# VAR_1576     int64
# VAR_1577     int64
# VAR_1578     int64
# VAR_1579     int64
# VAR_1580     int64
# VAR_1581     int64
# VAR_1582     int64
# VAR_1583     int64
# VAR_1584     int64
# VAR_1585     int64
# VAR_1586     int64
# VAR_1587     int64
# VAR_1588     int64
# VAR_1589     int64
# VAR_1590     int64
# VAR_1591     int64
# VAR_1592     int64
# VAR_1593     int64
# VAR_1594     int64
# VAR_1595     int64
# VAR_1596     int64
# VAR_1597     int64
# VAR_1598     int64
# VAR_1599     int64
# VAR_1600     int64
# VAR_1601     int64
# VAR_1602     int64
# VAR_1603     int64
# VAR_1604     int64
# VAR_1605     int64
# VAR_1606     int64
# VAR_1607     int64
# VAR_1608     int64
# VAR_1609     int64
# VAR_1610     int64
# VAR_1611     int64
# VAR_1612     int64
# VAR_1613     int64
# VAR_1614     int64
# VAR_1615     int64
# VAR_1616     int64
# VAR_1617     int64
# VAR_1618     int64
# VAR_1619     int64
# VAR_1620     int64
# VAR_1621     int64
# VAR_1622     int64
# VAR_1623     int64
# VAR_1624     int64
# VAR_1625     int64
# VAR_1626     int64
# VAR_1627     int64
# VAR_1628     int64
# VAR_1629     int64
# VAR_1630     int64
# VAR_1631     int64
# VAR_1632     int64
# VAR_1633     int64
# VAR_1634     int64
# VAR_1635     int64
# VAR_1636     int64
# VAR_1637     int64
# VAR_1638     int64
# VAR_1639     int64
# VAR_1640     int64
# VAR_1641     int64
# VAR_1642     int64
# VAR_1643     int64
# VAR_1644     int64
# VAR_1645     int64
# VAR_1646     int64
# VAR_1647     int64
# VAR_1648     int64
# VAR_1649     int64
# VAR_1650     int64
# VAR_1651     int64
# VAR_1652     int64
# VAR_1653     int64
# VAR_1654     int64
# VAR_1655     int64
# VAR_1656     int64
# VAR_1657     int64
# VAR_1658     int64
# VAR_1659     int64
# VAR_1660     int64
# VAR_1661     int64
# VAR_1662     int64
# VAR_1663     int64
# VAR_1664     int64
# VAR_1665     int64
# VAR_1666     int64
# VAR_1667     int64
# VAR_1668     int64
# VAR_1669     int64
# VAR_1670     int64
# VAR_1671     int64
# VAR_1672     int64
# VAR_1673     int64
# VAR_1674     int64
# VAR_1675     int64
# VAR_1676     int64
# VAR_1677     int64
# VAR_1678     int64
# VAR_1679     int64
# VAR_1680     int64
# VAR_1681     int64
# VAR_1682     int64
# VAR_1683     int64
# VAR_1684     int64
# VAR_1685     int64
# VAR_1686     int64
# VAR_1687     int64
# VAR_1688     int64
# VAR_1689     int64
# VAR_1690     int64
# VAR_1691     int64
# VAR_1692     int64
# VAR_1693     int64
# VAR_1694     int64
# VAR_1695     int64
# VAR_1696     int64
# VAR_1697     int64
# VAR_1698     int64
# VAR_1699     int64
# VAR_1700     int64
# VAR_1701     int64
# VAR_1702     int64
# VAR_1703     int64
# VAR_1704     int64
# VAR_1705     int64
# VAR_1706     int64
# VAR_1707     int64
# VAR_1708     int64
# VAR_1709     int64
# VAR_1710     int64
# VAR_1711     int64
# VAR_1712     int64
# VAR_1713     int64
# VAR_1714     int64
# VAR_1715     int64
# VAR_1716     int64
# VAR_1717     int64
# VAR_1718     int64
# VAR_1719     int64
# VAR_1720     int64
# VAR_1721     int64
# VAR_1722     int64
# VAR_1723     int64
# VAR_1724     int64
# VAR_1725     int64
# VAR_1726     int64
# VAR_1727     int64
# VAR_1728     int64
# VAR_1729     int64
# VAR_1730     int64
# VAR_1731     int64
# VAR_1732     int64
# VAR_1733     int64
# VAR_1734     int64
# VAR_1735     int64
# VAR_1736     int64
# VAR_1737     int64
# VAR_1738     int64
# VAR_1739     int64
# VAR_1740     int64
# VAR_1741     int64
# VAR_1742     int64
# VAR_1743     int64
# VAR_1744     int64
# VAR_1745     int64
# VAR_1746     int64
# VAR_1747     int64
# VAR_1748     int64
# VAR_1749     int64
# VAR_1750     int64
# VAR_1751     int64
# VAR_1752     int64
# VAR_1753     int64
# VAR_1754     int64
# VAR_1755     int64
# VAR_1756     int64
# VAR_1757     int64
# VAR_1758     int64
# VAR_1759     int64
# VAR_1760     int64
# VAR_1761     int64
# VAR_1762     int64
# VAR_1763     int64
# VAR_1764     int64
# VAR_1765     int64
# VAR_1766     int64
# VAR_1767     int64
# VAR_1768     int64
# VAR_1769     int64
# VAR_1770     int64
# VAR_1771     int64
# VAR_1772     int64
# VAR_1773     int64
# VAR_1774     int64
# VAR_1775     int64
# VAR_1776     int64
# VAR_1777     int64
# VAR_1778     int64
# VAR_1779     int64
# VAR_1780     int64
# VAR_1781     int64
# VAR_1782     int64
# VAR_1783     int64
# VAR_1784     int64
# VAR_1785     int64
# VAR_1786     int64
# VAR_1787     int64
# VAR_1788     int64
# VAR_1789     int64
# VAR_1790     int64
# VAR_1791     int64
# VAR_1792     int64
# VAR_1793     int64
# VAR_1794     int64
# VAR_1795     int64
# VAR_1796     int64
# VAR_1797     int64
# VAR_1798     int64
# VAR_1799     int64
# VAR_1800     int64
# VAR_1801     int64
# VAR_1802     int64
# VAR_1803     int64
# VAR_1804     int64
# VAR_1805     int64
# VAR_1806     int64
# VAR_1807     int64
# VAR_1808     int64
# VAR_1809     int64
# VAR_1810     int64
# VAR_1811     int64
# VAR_1812     int64
# VAR_1813     int64
# VAR_1814     int64
# VAR_1815     int64
# VAR_1816     int64
# VAR_1817     int64
# VAR_1818     int64
# VAR_1819     int64
# VAR_1820     int64
# VAR_1821     int64
# VAR_1822     int64
# VAR_1823     int64
# VAR_1824     int64
# VAR_1825     int64
# VAR_1826     int64
# VAR_1827     int64
# VAR_1828     int64
# VAR_1829     int64
# VAR_1830     int64
# VAR_1831     int64
# VAR_1832     int64
# VAR_1833     int64
# VAR_1834     int64
# VAR_1835     int64
# VAR_1836     int64
# VAR_1837     int64
# VAR_1838     int64
# VAR_1839     int64
# VAR_1840     int64
# VAR_1841     int64
# VAR_1842     int64
# VAR_1843     int64
# VAR_1844     int64
# VAR_1845     int64
# VAR_1846     int64
# VAR_1847     int64
# VAR_1848     int64
# VAR_1849     int64
# VAR_1850     int64
# VAR_1851     int64
# VAR_1852     int64
# VAR_1853     int64
# VAR_1854     int64
# VAR_1855     int64
# VAR_1856     int64
# VAR_1857     int64
# VAR_1858     int64
# VAR_1859     int64
# VAR_1860     int64
# VAR_1861     int64
# VAR_1862     int64
# VAR_1863     int64
# VAR_1864     int64
# VAR_1865     int64
# VAR_1866     int64
# VAR_1867     int64
# VAR_1868     int64
# VAR_1869     int64
# VAR_1870     int64
# VAR_1871     int64
# VAR_1872     int64
# VAR_1873     int64
# VAR_1874     int64
# VAR_1875     int64
# VAR_1876     int64
# VAR_1877     int64
# VAR_1878     int64
# VAR_1879     int64
# VAR_1880     int64
# VAR_1881     int64
# VAR_1882     int64
# VAR_1883     int64
# VAR_1884     int64
# VAR_1885     int64
# VAR_1886     int64
# VAR_1887     int64
# VAR_1888     int64
# VAR_1889     int64
# VAR_1890     int64
# VAR_1891     int64
# VAR_1892     int64
# VAR_1893     int64
# VAR_1894     int64
# VAR_1895     int64
# VAR_1896     int64
# VAR_1897     int64
# VAR_1898     int64
# VAR_1899     int64
# VAR_1900     int64
# VAR_1901     int64
# VAR_1902     int64
# VAR_1903     int64
# VAR_1904     int64
# VAR_1905     int64
# VAR_1906     int64
# VAR_1907     int64
# VAR_1908     int64
# VAR_1909     int64
# VAR_1910     int64
# VAR_1911     int64
# VAR_1912     int64
# VAR_1913     int64
# VAR_1914     int64
# VAR_1915     int64
# VAR_1916     int64
# VAR_1917     int64
# VAR_1918     int64
# VAR_1919     int64
# VAR_1920     int64
# VAR_1921     int64
# VAR_1922     int64
# VAR_1923     int64
# VAR_1924     int64
# VAR_1925     int64
# VAR_1926     int64
# VAR_1927     int64
# VAR_1928     int64
# VAR_1929     int64
# VAR_1930     int64
# VAR_1931     int64
# VAR_1932     int64
# VAR_1933     int64
# VAR_1934     category
# targetVar    int64
# dtypes: bool(4), category(14), float64(431), int64(1403)
# memory usage: 2.0 GB

# %%
null_counts = Xy_original.isnull().sum()
null_counts[null_counts > 0]
# Out:
# Series([], dtype: int64)

# %%
print('Total number of NaN in the dataframe: ', Xy_original.isnull().sum().sum())
# Out:
# Total number of NaN in the dataframe:  0

# %% [markdown]
# ### 1.e) Splitting Data into Attribute-only and Target-only Sets

# %%
# Use variable totCol to hold the number of columns in the dataframe
totCol = len(Xy_original.columns)

# Set up variable totAttr for the total number of attribute columns
totAttr = totCol-1

# targetCol variable indicates the column location of the target/class variable
# If the first column, set targetCol to 1. If the last column, set targetCol to totCol
# If (targetCol <> 1) and (targetCol <> totCol), be aware when slicing up the dataframes for visualization
targetCol = totCol

# %%
# We create attribute-only and target-only datasets (X_original and y_original)
# for various visualization and cleaning/transformation operations

if targetCol == totCol:
    X_original = Xy_original.iloc[:,0:totAttr]
    y_original = Xy_original.iloc[:,totAttr]
else:
    X_original = Xy_original.iloc[:,1:totCol]
    y_original = Xy_original.iloc[:,0]

print("Xy_original.shape: {} X_original.shape: {} y_original.shape: {}".format(Xy_original.shape, X_original.shape, y_original.shape))
# Out:
# Xy_original.shape: (144262, 1852) X_original.shape: (144262, 1851) y_original.shape: (144262,)

# %% [markdown]
# ### 1.f) Set up the parameters for data visualization

# %%
# Set up the number of row and columns for visualization display. dispRow * dispCol should be >= totAttr
dispCol = 4
if totAttr % dispCol == 0 :
    dispRow = totAttr // dispCol
else :
    dispRow = (totAttr // dispCol) + 1
    
# Set figure width to display the data visualization plots
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = dispCol*4
fig_size[1] = dispRow*4
plt.rcParams["figure.figsize"] = fig_size

# %%
if (notifyStatus): email_notify("Library and Data Loading completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 2 - Summarize Data
# To gain a better understanding of the data that we have on-hand, we will leverage a number of descriptive statistics and data visualization techniques. The plan is to use the results to consider new questions, review assumptions, and validate hypotheses that we can investigate later with specialized models.

# %%
if (notifyStatus): email_notify("Data Summarization and Visualization has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 2.a) Descriptive Statistics

# %% [markdown]
# #### 2.a.i) Peek at the attribute columns

# %%
# X_original.head(10)

# %% [markdown]
# #### 2.a.ii) Dimensions and attribute types

# %%
# X_original.info(verbose=True)

# %% [markdown]
# #### 2.a.iii) Statistical summary of the attributes

# %%
# X_original.describe()

# %% [markdown]
# #### 2.a.iv) Summarize the levels of the class attribute

# %%
Xy_original.groupby('targetVar').size()
# Out:
# targetVar
# 0    110718
# 1     33544
# dtype: int64

# %% [markdown]
# ### 2.b) Data Visualization

# %%
# Histograms for each attribute
# X_original.hist(layout=(dispRow,dispCol))
# plt.show()

# %%
# Box and Whisker plot for each attribute
# X_original.plot(kind='box', subplots=True, layout=(dispRow,dispCol))
# plt.show()

# %%
# Density plot for each attribute
# X_original.plot(kind='density', subplots=True, layout=(dispRow,dispCol))
# plt.show()

# %%
# Correlation matrix
# fig = plt.figure(figsize=(16,12))
# ax = fig.add_subplot(111)
# correlations = X_original.corr(method='pearson')
# cax = ax.matshow(correlations, vmin=-1, vmax=1)
# fig.colorbar(cax)
# plt.show()

# %%
if (notifyStatus): email_notify("Data Summarization and Visualization completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 3 - Prepare Data
# Some dataset may require additional preparation activities that will best exposes the structure of the problem and the relationships between the input attributes and the output variable. Some data-prep tasks might include:
#
# * Cleaning data by removing duplicates, marking missing values and even imputing missing values.
# * Feature selection where redundant features may be removed.
# * Data transforms where attributes are scaled or redistributed in order to best expose the structure of the problem later to learning algorithms.

# %%
if (notifyStatus): email_notify("Data Cleaning and Transformation has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 3.a) Splitting Data into Training and Test Sets

# %%
# Perform one-hot-encoding on the categorical attributes
X_original = pd.get_dummies(X_original)
X_original.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 144262 entries, 0 to 145230
# Data columns (total 2042 columns):
# VAR_0002                 int64
# VAR_0003                 int64
# VAR_0004                 int64
# VAR_0006                 float64
# VAR_0007                 float64
# VAR_0013                 float64
# VAR_0014                 float64
# VAR_0015                 float64
# VAR_0016                 float64
# VAR_0017                 float64
# VAR_0033                 float64
# VAR_0034                 float64
# VAR_0035                 float64
# VAR_0036                 float64
# VAR_0037                 float64
# VAR_0045                 float64
# VAR_0046                 float64
# VAR_0047                 float64
# VAR_0048                 float64
# VAR_0049                 float64
# VAR_0050                 float64
# VAR_0051                 float64
# VAR_0052                 float64
# VAR_0053                 float64
# VAR_0054                 float64
# VAR_0055                 float64
# VAR_0056                 float64
# VAR_0057                 float64
# VAR_0058                 float64
# VAR_0059                 float64
# VAR_0060                 float64
# VAR_0061                 float64
# VAR_0062                 float64
# VAR_0063                 float64
# VAR_0064                 float64
# VAR_0065                 float64
# VAR_0066                 float64
# VAR_0067                 float64
# VAR_0068                 float64
# VAR_0069                 float64
# VAR_0070                 float64
# VAR_0071                 float64
# VAR_0072                 float64
# VAR_0076                 float64
# VAR_0077                 float64
# VAR_0078                 float64
# VAR_0079                 float64
# VAR_0080                 float64
# VAR_0081                 float64
# VAR_0082                 float64
# VAR_0083                 float64
# VAR_0084                 float64
# VAR_0085                 float64
# VAR_0086                 float64
# VAR_0087                 float64
# VAR_0088                 float64
# VAR_0089                 float64
# VAR_0090                 float64
# VAR_0091                 float64
# VAR_0092                 float64
# VAR_0093                 float64
# VAR_0094                 float64
# VAR_0095                 float64
# VAR_0096                 float64
# VAR_0097                 float64
# VAR_0098                 float64
# VAR_0099                 float64
# VAR_0100                 float64
# VAR_0101                 float64
# VAR_0102                 float64
# VAR_0103                 float64
# VAR_0104                 float64
# VAR_0105                 float64
# VAR_0106                 float64
# VAR_0107                 float64
# VAR_0108                 float64
# VAR_0109                 float64
# VAR_0110                 float64
# VAR_0111                 float64
# VAR_0112                 float64
# VAR_0113                 float64
# VAR_0114                 float64
# VAR_0115                 float64
# VAR_0116                 float64
# VAR_0117                 float64
# VAR_0118                 float64
# VAR_0119                 float64
# VAR_0120                 float64
# VAR_0121                 float64
# VAR_0122                 float64
# VAR_0123                 float64
# VAR_0124                 float64
# VAR_0125                 float64
# VAR_0126                 float64
# VAR_0127                 float64
# VAR_0128                 float64
# VAR_0129                 float64
# VAR_0130                 float64
# VAR_0131                 float64
# VAR_0132                 float64
# VAR_0133                 float64
# VAR_0134                 float64
# VAR_0135                 float64
# VAR_0136                 float64
# VAR_0137                 float64
# VAR_0138                 float64
# VAR_0139                 float64
# VAR_0140                 float64
# VAR_0141                 float64
# VAR_0142                 float64
# VAR_0143                 float64
# VAR_0144                 float64
# VAR_0145                 float64
# VAR_0146                 float64
# VAR_0147                 float64
# VAR_0148                 float64
# VAR_0149                 float64
# VAR_0150                 float64
# VAR_0151                 float64
# VAR_0152                 float64
# VAR_0153                 float64
# VAR_0154                 float64
# VAR_0155                 float64
# VAR_0160                 float64
# VAR_0161                 float64
# VAR_0162                 float64
# VAR_0163                 float64
# VAR_0164                 float64
# VAR_0165                 float64
# VAR_0170                 float64
# VAR_0171                 float64
# VAR_0172                 float64
# VAR_0173                 float64
# VAR_0174                 float64
# VAR_0175                 float64
# VAR_0180                 float64
# VAR_0181                 float64
# VAR_0182                 float64
# VAR_0183                 float64
# VAR_0184                 float64
# VAR_0185                 float64
# VAR_0186                 float64
# VAR_0187                 float64
# VAR_0191                 float64
# VAR_0192                 float64
# VAR_0193                 float64
# VAR_0194                 float64
# VAR_0195                 float64
# VAR_0198                 float64
# VAR_0201                 float64
# VAR_0219                 float64
# VAR_0220                 float64
# VAR_0224                 float64
# VAR_0225                 float64
# VAR_0226                 bool
# VAR_0227                 float64
# VAR_0228                 float64
# VAR_0230                 bool
# VAR_0231                 float64
# VAR_0232                 bool
# VAR_0233                 float64
# VAR_0234                 float64
# VAR_0235                 float64
# VAR_0236                 bool
# VAR_0238                 float64
# VAR_0241                 float64
# VAR_0242                 float64
# VAR_0243                 float64
# VAR_0244                 float64
# VAR_0245                 float64
# VAR_0247                 float64
# VAR_0248                 float64
# VAR_0249                 float64
# VAR_0250                 float64
# VAR_0251                 float64
# VAR_0252                 float64
# VAR_0253                 float64
# VAR_0254                 float64
# VAR_0255                 float64
# VAR_0256                 float64
# VAR_0257                 float64
# VAR_0258                 float64
# VAR_0259                 float64
# VAR_0260                 float64
# VAR_0261                 float64
# VAR_0262                 float64
# VAR_0263                 float64
# VAR_0264                 float64
# VAR_0265                 float64
# VAR_0266                 float64
# VAR_0267                 float64
# VAR_0268                 float64
# VAR_0269                 float64
# VAR_0270                 float64
# VAR_0271                 float64
# VAR_0272                 float64
# VAR_0273                 float64
# VAR_0275                 float64
# VAR_0276                 float64
# VAR_0277                 float64
# VAR_0278                 float64
# VAR_0279                 float64
# VAR_0280                 float64
# VAR_0281                 float64
# VAR_0282                 float64
# VAR_0284                 float64
# VAR_0285                 float64
# VAR_0286                 float64
# VAR_0287                 float64
# VAR_0288                 float64
# VAR_0289                 float64
# VAR_0290                 float64
# VAR_0291                 float64
# VAR_0292                 float64
# VAR_0293                 float64
# VAR_0294                 float64
# VAR_0295                 float64
# VAR_0296                 float64
# VAR_0297                 float64
# VAR_0298                 float64
# VAR_0299                 float64
# VAR_0300                 float64
# VAR_0301                 float64
# VAR_0302                 float64
# VAR_0303                 float64
# VAR_0304                 float64
# VAR_0306                 float64
# VAR_0307                 float64
# VAR_0308                 float64
# VAR_0309                 float64
# VAR_0310                 float64
# VAR_0311                 float64
# VAR_0312                 float64
# VAR_0313                 float64
# VAR_0314                 float64
# VAR_0315                 float64
# VAR_0316                 float64
# VAR_0317                 float64
# VAR_0318                 float64
# VAR_0319                 float64
# VAR_0320                 float64
# VAR_0321                 float64
# VAR_0322                 float64
# VAR_0323                 float64
# VAR_0324                 float64
# VAR_0326                 float64
# VAR_0327                 float64
# VAR_0328                 float64
# VAR_0329                 float64
# VAR_0330                 float64
# VAR_0331                 float64
# VAR_0332                 float64
# VAR_0333                 float64
# VAR_0334                 float64
# VAR_0335                 float64
# VAR_0336                 float64
# VAR_0337                 float64
# VAR_0338                 float64
# VAR_0339                 float64
# VAR_0340                 float64
# VAR_0341                 float64
# VAR_0343                 float64
# VAR_0344                 float64
# VAR_0345                 float64
# VAR_0346                 float64
# VAR_0347                 float64
# VAR_0348                 float64
# VAR_0349                 float64
# VAR_0350                 float64
# VAR_0351                 float64
# VAR_0355                 float64
# VAR_0356                 float64
# VAR_0357                 float64
# VAR_0358                 float64
# VAR_0359                 float64
# VAR_0360                 float64
# VAR_0361                 float64
# VAR_0362                 float64
# VAR_0363                 float64
# VAR_0364                 float64
# VAR_0365                 float64
# VAR_0366                 float64
# VAR_0367                 float64
# VAR_0368                 float64
# VAR_0369                 float64
# VAR_0370                 float64
# VAR_0371                 float64
# VAR_0372                 float64
# VAR_0373                 float64
# VAR_0374                 float64
# VAR_0375                 float64
# VAR_0376                 float64
# VAR_0377                 float64
# VAR_0378                 float64
# VAR_0379                 float64
# VAR_0380                 float64
# VAR_0381                 float64
# VAR_0382                 float64
# VAR_0383                 float64
# VAR_0384                 float64
# VAR_0385                 float64
# VAR_0386                 float64
# VAR_0387                 float64
# VAR_0388                 float64
# VAR_0389                 float64
# VAR_0390                 float64
# VAR_0391                 float64
# VAR_0392                 float64
# VAR_0393                 float64
# VAR_0395                 float64
# VAR_0396                 float64
# VAR_0397                 float64
# VAR_0398                 float64
# VAR_0399                 float64
# VAR_0400                 float64
# VAR_0401                 float64
# VAR_0402                 float64
# VAR_0403                 float64
# VAR_0405                 float64
# VAR_0406                 float64
# VAR_0407                 float64
# VAR_0408                 float64
# VAR_0409                 float64
# VAR_0410                 float64
# VAR_0411                 float64
# VAR_0412                 float64
# VAR_0413                 float64
# VAR_0414                 float64
# VAR_0415                 float64
# VAR_0416                 float64
# VAR_0417                 float64
# VAR_0418                 float64
# VAR_0419                 float64
# VAR_0420                 float64
# VAR_0421                 float64
# VAR_0422                 float64
# VAR_0423                 float64
# VAR_0424                 float64
# VAR_0425                 float64
# VAR_0426                 float64
# VAR_0427                 float64
# VAR_0428                 float64
# VAR_0429                 float64
# VAR_0430                 float64
# VAR_0431                 float64
# VAR_0432                 float64
# VAR_0433                 float64
# VAR_0434                 float64
# VAR_0435                 float64
# VAR_0436                 float64
# VAR_0437                 float64
# VAR_0439                 float64
# VAR_0440                 float64
# VAR_0441                 float64
# VAR_0442                 float64
# VAR_0443                 float64
# VAR_0444                 float64
# VAR_0445                 float64
# VAR_0446                 float64
# VAR_0447                 float64
# VAR_0448                 float64
# VAR_0449                 float64
# VAR_0450                 float64
# VAR_0451                 float64
# VAR_0452                 float64
# VAR_0453                 float64
# VAR_0454                 float64
# VAR_0455                 float64
# VAR_0456                 float64
# VAR_0457                 float64
# VAR_0458                 float64
# VAR_0459                 float64
# VAR_0460                 float64
# VAR_0461                 float64
# VAR_0462                 float64
# VAR_0463                 float64
# VAR_0464                 float64
# VAR_0465                 float64
# VAR_0468                 float64
# VAR_0469                 float64
# VAR_0470                 float64
# VAR_0471                 float64
# VAR_0472                 float64
# VAR_0473                 float64
# VAR_0474                 float64
# VAR_0475                 float64
# VAR_0476                 float64
# VAR_0477                 float64
# VAR_0478                 float64
# VAR_0479                 float64
# VAR_0480                 float64
# VAR_0481                 float64
# VAR_0482                 float64
# VAR_0483                 float64
# VAR_0484                 float64
# VAR_0485                 float64
# VAR_0486                 float64
# VAR_0487                 float64
# VAR_0488                 float64
# VAR_0489                 float64
# VAR_0490                 float64
# VAR_0491                 float64
# VAR_0492                 float64
# VAR_0494                 float64
# VAR_0495                 float64
# VAR_0496                 float64
# VAR_0497                 float64
# VAR_0498                 float64
# VAR_0499                 float64
# VAR_0500                 float64
# VAR_0501                 float64
# VAR_0502                 float64
# VAR_0503                 float64
# VAR_0504                 float64
# VAR_0505                 float64
# VAR_0506                 float64
# VAR_0507                 float64
# VAR_0508                 float64
# VAR_0509                 float64
# VAR_0510                 float64
# VAR_0511                 float64
# VAR_0512                 float64
# VAR_0513                 float64
# VAR_0514                 float64
# VAR_0515                 float64
# VAR_0516                 float64
# VAR_0517                 float64
# VAR_0518                 float64
# VAR_0519                 float64
# VAR_0520                 float64
# VAR_0521                 float64
# VAR_0522                 float64
# VAR_0523                 float64
# VAR_0524                 float64
# VAR_0525                 float64
# VAR_0526                 float64
# VAR_0529                 float64
# VAR_0531                 float64
# VAR_0532                 int64
# VAR_0533                 int64
# VAR_0534                 int64
# VAR_0535                 int64
# VAR_0536                 int64
# VAR_0537                 int64
# VAR_0538                 int64
# VAR_0539                 int64
# VAR_0540                 int64
# VAR_0541                 int64
# VAR_0542                 int64
# VAR_0543                 int64
# VAR_0544                 int64
# VAR_0545                 int64
# VAR_0546                 int64
# VAR_0547                 int64
# VAR_0548                 int64
# VAR_0549                 int64
# VAR_0550                 int64
# VAR_0551                 int64
# VAR_0552                 int64
# VAR_0553                 int64
# VAR_0554                 int64
# VAR_0555                 int64
# VAR_0556                 int64
# VAR_0557                 int64
# VAR_0558                 int64
# VAR_0559                 int64
# VAR_0560                 int64
# VAR_0561                 int64
# VAR_0562                 int64
# VAR_0563                 int64
# VAR_0564                 int64
# VAR_0565                 int64
# VAR_0566                 int64
# VAR_0567                 int64
# VAR_0568                 int64
# VAR_0569                 int64
# VAR_0570                 int64
# VAR_0571                 int64
# VAR_0572                 int64
# VAR_0573                 int64
# VAR_0574                 int64
# VAR_0575                 int64
# VAR_0576                 int64
# VAR_0577                 int64
# VAR_0578                 int64
# VAR_0579                 int64
# VAR_0580                 int64
# VAR_0581                 int64
# VAR_0582                 int64
# VAR_0583                 int64
# VAR_0584                 int64
# VAR_0585                 int64
# VAR_0586                 int64
# VAR_0587                 int64
# VAR_0588                 int64
# VAR_0589                 int64
# VAR_0590                 int64
# VAR_0591                 int64
# VAR_0592                 int64
# VAR_0593                 int64
# VAR_0594                 int64
# VAR_0595                 int64
# VAR_0596                 int64
# VAR_0597                 int64
# VAR_0598                 int64
# VAR_0599                 int64
# VAR_0600                 int64
# VAR_0601                 int64
# VAR_0602                 int64
# VAR_0603                 int64
# VAR_0604                 int64
# VAR_0605                 int64
# VAR_0606                 int64
# VAR_0607                 int64
# VAR_0608                 int64
# VAR_0609                 int64
# VAR_0610                 int64
# VAR_0611                 int64
# VAR_0612                 int64
# VAR_0613                 int64
# VAR_0614                 int64
# VAR_0615                 int64
# VAR_0616                 int64
# VAR_0617                 int64
# VAR_0618                 int64
# VAR_0619                 int64
# VAR_0620                 int64
# VAR_0621                 int64
# VAR_0622                 int64
# VAR_0623                 int64
# VAR_0624                 int64
# VAR_0625                 int64
# VAR_0626                 int64
# VAR_0627                 int64
# VAR_0628                 int64
# VAR_0629                 int64
# VAR_0630                 int64
# VAR_0631                 int64
# VAR_0632                 int64
# VAR_0633                 int64
# VAR_0634                 int64
# VAR_0635                 int64
# VAR_0636                 int64
# VAR_0637                 int64
# VAR_0638                 int64
# VAR_0639                 int64
# VAR_0640                 int64
# VAR_0641                 int64
# VAR_0642                 int64
# VAR_0643                 int64
# VAR_0644                 int64
# VAR_0645                 int64
# VAR_0646                 int64
# VAR_0647                 int64
# VAR_0648                 int64
# VAR_0649                 int64
# VAR_0650                 int64
# VAR_0651                 int64
# VAR_0652                 int64
# VAR_0653                 int64
# VAR_0654                 int64
# VAR_0655                 int64
# VAR_0656                 int64
# VAR_0657                 int64
# VAR_0658                 int64
# VAR_0659                 int64
# VAR_0660                 int64
# VAR_0661                 int64
# VAR_0662                 int64
# VAR_0663                 int64
# VAR_0664                 int64
# VAR_0665                 int64
# VAR_0666                 int64
# VAR_0667                 int64
# VAR_0668                 int64
# VAR_0669                 int64
# VAR_0670                 int64
# VAR_0671                 int64
# VAR_0672                 int64
# VAR_0673                 int64
# VAR_0674                 int64
# VAR_0675                 int64
# VAR_0676                 int64
# VAR_0677                 int64
# VAR_0678                 int64
# VAR_0679                 int64
# VAR_0680                 int64
# VAR_0681                 int64
# VAR_0682                 int64
# VAR_0683                 int64
# VAR_0684                 int64
# VAR_0685                 int64
# VAR_0686                 int64
# VAR_0687                 int64
# VAR_0688                 int64
# VAR_0689                 int64
# VAR_0690                 int64
# VAR_0691                 int64
# VAR_0692                 int64
# VAR_0693                 int64
# VAR_0694                 int64
# VAR_0695                 int64
# VAR_0696                 int64
# VAR_0697                 int64
# VAR_0698                 int64
# VAR_0699                 int64
# VAR_0700                 int64
# VAR_0701                 int64
# VAR_0702                 int64
# VAR_0703                 int64
# VAR_0704                 int64
# VAR_0705                 int64
# VAR_0706                 int64
# VAR_0707                 int64
# VAR_0708                 int64
# VAR_0709                 int64
# VAR_0710                 int64
# VAR_0711                 int64
# VAR_0712                 int64
# VAR_0713                 int64
# VAR_0714                 int64
# VAR_0715                 int64
# VAR_0716                 int64
# VAR_0717                 int64
# VAR_0718                 int64
# VAR_0719                 int64
# VAR_0720                 int64
# VAR_0721                 int64
# VAR_0722                 int64
# VAR_0723                 int64
# VAR_0724                 int64
# VAR_0725                 int64
# VAR_0726                 int64
# VAR_0727                 int64
# VAR_0728                 int64
# VAR_0729                 int64
# VAR_0730                 int64
# VAR_0731                 int64
# VAR_0732                 int64
# VAR_0733                 int64
# VAR_0734                 int64
# VAR_0735                 int64
# VAR_0736                 int64
# VAR_0737                 int64
# VAR_0738                 int64
# VAR_0739                 int64
# VAR_0740                 int64
# VAR_0741                 int64
# VAR_0742                 int64
# VAR_0743                 int64
# VAR_0744                 int64
# VAR_0745                 int64
# VAR_0746                 int64
# VAR_0747                 int64
# VAR_0748                 int64
# VAR_0749                 int64
# VAR_0750                 int64
# VAR_0751                 int64
# VAR_0752                 int64
# VAR_0753                 int64
# VAR_0754                 int64
# VAR_0755                 int64
# VAR_0756                 int64
# VAR_0757                 int64
# VAR_0758                 int64
# VAR_0759                 int64
# VAR_0760                 int64
# VAR_0761                 int64
# VAR_0762                 int64
# VAR_0763                 int64
# VAR_0764                 int64
# VAR_0765                 int64
# VAR_0766                 int64
# VAR_0767                 int64
# VAR_0768                 int64
# VAR_0769                 int64
# VAR_0770                 int64
# VAR_0771                 int64
# VAR_0772                 int64
# VAR_0773                 int64
# VAR_0774                 int64
# VAR_0775                 int64
# VAR_0776                 int64
# VAR_0777                 int64
# VAR_0778                 int64
# VAR_0779                 int64
# VAR_0780                 int64
# VAR_0781                 int64
# VAR_0782                 int64
# VAR_0783                 int64
# VAR_0784                 int64
# VAR_0785                 int64
# VAR_0786                 int64
# VAR_0787                 int64
# VAR_0788                 int64
# VAR_0789                 int64
# VAR_0790                 int64
# VAR_0791                 int64
# VAR_0792                 int64
# VAR_0793                 int64
# VAR_0794                 int64
# VAR_0795                 int64
# VAR_0796                 int64
# VAR_0797                 int64
# VAR_0798                 int64
# VAR_0799                 int64
# VAR_0800                 int64
# VAR_0801                 int64
# VAR_0802                 int64
# VAR_0803                 int64
# VAR_0804                 int64
# VAR_0805                 int64
# VAR_0806                 int64
# VAR_0807                 int64
# VAR_0808                 int64
# VAR_0809                 int64
# VAR_0810                 int64
# VAR_0811                 int64
# VAR_0812                 int64
# VAR_0813                 int64
# VAR_0814                 int64
# VAR_0815                 int64
# VAR_0816                 int64
# VAR_0817                 int64
# VAR_0818                 int64
# VAR_0819                 int64
# VAR_0820                 int64
# VAR_0821                 int64
# VAR_0822                 int64
# VAR_0823                 int64
# VAR_0824                 int64
# VAR_0825                 int64
# VAR_0826                 int64
# VAR_0827                 int64
# VAR_0828                 int64
# VAR_0829                 int64
# VAR_0830                 int64
# VAR_0831                 int64
# VAR_0832                 int64
# VAR_0833                 int64
# VAR_0834                 int64
# VAR_0835                 int64
# VAR_0836                 int64
# VAR_0837                 int64
# VAR_0838                 int64
# VAR_0839                 int64
# VAR_0841                 int64
# VAR_0842                 int64
# VAR_0843                 int64
# VAR_0844                 int64
# VAR_0845                 int64
# VAR_0846                 int64
# VAR_0848                 int64
# VAR_0849                 int64
# VAR_0850                 int64
# VAR_0851                 int64
# VAR_0852                 int64
# VAR_0853                 int64
# VAR_0854                 int64
# VAR_0855                 int64
# VAR_0856                 int64
# VAR_0857                 int64
# VAR_0858                 int64
# VAR_0859                 int64
# VAR_0860                 int64
# VAR_0861                 int64
# VAR_0862                 int64
# VAR_0863                 int64
# VAR_0864                 int64
# VAR_0865                 int64
# VAR_0866                 int64
# VAR_0867                 int64
# VAR_0868                 int64
# VAR_0869                 int64
# VAR_0870                 int64
# VAR_0871                 int64
# VAR_0872                 int64
# VAR_0873                 int64
# VAR_0874                 int64
# VAR_0875                 int64
# VAR_0876                 int64
# VAR_0877                 int64
# VAR_0878                 int64
# VAR_0879                 int64
# VAR_0880                 int64
# VAR_0881                 int64
# VAR_0882                 int64
# VAR_0883                 int64
# VAR_0884                 int64
# VAR_0885                 int64
# VAR_0886                 int64
# VAR_0887                 int64
# VAR_0888                 int64
# VAR_0889                 int64
# VAR_0890                 int64
# VAR_0891                 int64
# VAR_0892                 int64
# VAR_0893                 int64
# VAR_0894                 int64
# VAR_0895                 int64
# VAR_0896                 int64
# VAR_0897                 int64
# VAR_0898                 int64
# VAR_0899                 int64
# VAR_0900                 int64
# VAR_0901                 int64
# VAR_0902                 int64
# VAR_0903                 int64
# VAR_0904                 int64
# VAR_0905                 int64
# VAR_0906                 int64
# VAR_0907                 int64
# VAR_0908                 int64
# VAR_0909                 int64
# VAR_0910                 int64
# VAR_0911                 int64
# VAR_0912                 int64
# VAR_0913                 int64
# VAR_0914                 int64
# VAR_0915                 int64
# VAR_0916                 int64
# VAR_0917                 int64
# VAR_0918                 int64
# VAR_0919                 int64
# VAR_0920                 int64
# VAR_0921                 int64
# VAR_0922                 int64
# VAR_0923                 int64
# VAR_0924                 int64
# VAR_0925                 int64
# VAR_0926                 int64
# VAR_0927                 int64
# VAR_0928                 int64
# VAR_0929                 int64
# VAR_0930                 int64
# VAR_0931                 int64
# VAR_0932                 int64
# VAR_0933                 int64
# VAR_0934                 int64
# VAR_0935                 int64
# VAR_0936                 int64
# VAR_0937                 int64
# VAR_0938                 int64
# VAR_0939                 int64
# VAR_0940                 int64
# VAR_0941                 int64
# VAR_0942                 int64
# VAR_0943                 int64
# VAR_0944                 int64
# VAR_0945                 int64
# VAR_0946                 int64
# VAR_0947                 int64
# VAR_0948                 int64
# VAR_0949                 int64
# VAR_0950                 int64
# VAR_0951                 int64
# VAR_0952                 int64
# VAR_0953                 int64
# VAR_0954                 int64
# VAR_0955                 int64
# VAR_0956                 int64
# VAR_0957                 int64
# VAR_0958                 int64
# VAR_0959                 int64
# VAR_0960                 int64
# VAR_0961                 int64
# VAR_0962                 int64
# VAR_0963                 int64
# VAR_0964                 int64
# VAR_0965                 int64
# VAR_0966                 int64
# VAR_0967                 int64
# VAR_0968                 int64
# VAR_0969                 int64
# VAR_0970                 int64
# VAR_0971                 int64
# VAR_0972                 int64
# VAR_0973                 int64
# VAR_0974                 int64
# VAR_0975                 int64
# VAR_0976                 int64
# VAR_0977                 int64
# VAR_0978                 int64
# VAR_0979                 int64
# VAR_0980                 int64
# VAR_0981                 int64
# VAR_0982                 int64
# VAR_0983                 int64
# VAR_0984                 int64
# VAR_0985                 int64
# VAR_0986                 int64
# VAR_0987                 int64
# VAR_0988                 int64
# VAR_0989                 int64
# VAR_0990                 int64
# VAR_0991                 int64
# VAR_0992                 int64
# VAR_0993                 int64
# VAR_0994                 int64
# VAR_0995                 int64
# VAR_0996                 int64
# VAR_0997                 int64
# VAR_0998                 int64
# VAR_0999                 int64
# VAR_1000                 int64
# VAR_1001                 int64
# VAR_1002                 int64
# VAR_1003                 int64
# VAR_1004                 int64
# VAR_1005                 int64
# VAR_1006                 int64
# VAR_1007                 int64
# VAR_1008                 int64
# VAR_1009                 int64
# VAR_1010                 int64
# VAR_1011                 int64
# VAR_1012                 int64
# VAR_1013                 int64
# VAR_1014                 int64
# VAR_1015                 int64
# VAR_1016                 int64
# VAR_1017                 int64
# VAR_1018                 int64
# VAR_1019                 int64
# VAR_1020                 int64
# VAR_1021                 int64
# VAR_1022                 int64
# VAR_1023                 int64
# VAR_1024                 int64
# VAR_1025                 int64
# VAR_1026                 int64
# VAR_1027                 int64
# VAR_1028                 int64
# VAR_1029                 int64
# VAR_1030                 int64
# VAR_1031                 int64
# VAR_1032                 int64
# VAR_1033                 int64
# VAR_1034                 int64
# VAR_1035                 int64
# VAR_1036                 int64
# VAR_1037                 int64
# VAR_1038                 int64
# VAR_1039                 int64
# VAR_1040                 int64
# VAR_1041                 int64
# VAR_1042                 int64
# VAR_1043                 int64
# VAR_1044                 int64
# VAR_1045                 int64
# VAR_1046                 int64
# VAR_1047                 int64
# VAR_1048                 int64
# VAR_1049                 int64
# VAR_1050                 int64
# VAR_1051                 int64
# VAR_1052                 int64
# VAR_1053                 int64
# VAR_1054                 int64
# VAR_1055                 int64
# VAR_1056                 int64
# VAR_1057                 int64
# VAR_1058                 int64
# VAR_1059                 int64
# VAR_1060                 int64
# VAR_1061                 int64
# VAR_1062                 int64
# VAR_1063                 int64
# VAR_1064                 int64
# VAR_1065                 int64
# VAR_1066                 int64
# VAR_1067                 int64
# VAR_1068                 int64
# VAR_1069                 int64
# VAR_1070                 int64
# VAR_1071                 int64
# VAR_1072                 int64
# VAR_1073                 int64
# VAR_1074                 int64
# VAR_1075                 int64
# VAR_1076                 int64
# VAR_1077                 int64
# VAR_1078                 int64
# VAR_1079                 int64
# VAR_1080                 int64
# VAR_1081                 int64
# VAR_1082                 int64
# VAR_1083                 int64
# VAR_1084                 int64
# VAR_1085                 int64
# VAR_1086                 int64
# VAR_1087                 int64
# VAR_1088                 int64
# VAR_1089                 int64
# VAR_1090                 int64
# VAR_1091                 int64
# VAR_1092                 int64
# VAR_1093                 int64
# VAR_1094                 int64
# VAR_1095                 int64
# VAR_1096                 int64
# VAR_1097                 int64
# VAR_1098                 int64
# VAR_1099                 int64
# VAR_1100                 int64
# VAR_1101                 int64
# VAR_1102                 int64
# VAR_1103                 int64
# VAR_1104                 int64
# VAR_1105                 int64
# VAR_1106                 int64
# VAR_1107                 int64
# VAR_1108                 int64
# VAR_1109                 int64
# VAR_1110                 int64
# VAR_1111                 int64
# VAR_1112                 int64
# VAR_1113                 int64
# VAR_1114                 int64
# VAR_1115                 int64
# VAR_1116                 int64
# VAR_1117                 int64
# VAR_1118                 int64
# VAR_1119                 int64
# VAR_1120                 int64
# VAR_1121                 int64
# VAR_1122                 int64
# VAR_1123                 int64
# VAR_1124                 int64
# VAR_1125                 int64
# VAR_1126                 int64
# VAR_1127                 int64
# VAR_1128                 int64
# VAR_1129                 int64
# VAR_1130                 int64
# VAR_1131                 int64
# VAR_1132                 int64
# VAR_1133                 int64
# VAR_1134                 int64
# VAR_1135                 int64
# VAR_1136                 int64
# VAR_1137                 int64
# VAR_1138                 int64
# VAR_1139                 int64
# VAR_1140                 int64
# VAR_1141                 int64
# VAR_1142                 int64
# VAR_1143                 int64
# VAR_1144                 int64
# VAR_1145                 int64
# VAR_1146                 int64
# VAR_1147                 int64
# VAR_1148                 int64
# VAR_1149                 int64
# VAR_1150                 int64
# VAR_1151                 int64
# VAR_1152                 int64
# VAR_1153                 int64
# VAR_1154                 int64
# VAR_1155                 int64
# VAR_1156                 int64
# VAR_1157                 int64
# VAR_1158                 int64
# VAR_1159                 int64
# VAR_1160                 int64
# VAR_1161                 int64
# VAR_1162                 int64
# VAR_1163                 int64
# VAR_1164                 int64
# VAR_1165                 int64
# VAR_1166                 int64
# VAR_1167                 int64
# VAR_1168                 int64
# VAR_1169                 int64
# VAR_1170                 int64
# VAR_1171                 int64
# VAR_1172                 int64
# VAR_1173                 int64
# VAR_1174                 int64
# VAR_1175                 int64
# VAR_1176                 int64
# VAR_1177                 int64
# VAR_1178                 int64
# VAR_1179                 int64
# VAR_1180                 int64
# VAR_1181                 int64
# VAR_1182                 int64
# VAR_1183                 int64
# VAR_1184                 int64
# VAR_1185                 int64
# VAR_1186                 int64
# VAR_1187                 int64
# VAR_1188                 int64
# VAR_1189                 int64
# VAR_1190                 int64
# VAR_1191                 int64
# VAR_1192                 int64
# VAR_1193                 int64
# VAR_1194                 int64
# VAR_1195                 int64
# VAR_1196                 int64
# VAR_1197                 int64
# VAR_1198                 int64
# VAR_1199                 int64
# VAR_1200                 int64
# VAR_1201                 int64
# VAR_1202                 int64
# VAR_1203                 int64
# VAR_1204                 int64
# VAR_1205                 int64
# VAR_1206                 int64
# VAR_1207                 int64
# VAR_1208                 int64
# VAR_1209                 int64
# VAR_1210                 int64
# VAR_1211                 int64
# VAR_1212                 int64
# VAR_1213                 int64
# VAR_1214                 int64
# VAR_1215                 int64
# VAR_1216                 int64
# VAR_1217                 int64
# VAR_1218                 int64
# VAR_1219                 int64
# VAR_1220                 int64
# VAR_1221                 int64
# VAR_1222                 int64
# VAR_1223                 int64
# VAR_1224                 int64
# VAR_1225                 int64
# VAR_1226                 int64
# VAR_1227                 int64
# VAR_1228                 int64
# VAR_1229                 int64
# VAR_1230                 int64
# VAR_1231                 int64
# VAR_1232                 int64
# VAR_1233                 int64
# VAR_1234                 int64
# VAR_1235                 int64
# VAR_1236                 int64
# VAR_1237                 int64
# VAR_1238                 int64
# VAR_1239                 int64
# VAR_1240                 int64
# VAR_1241                 int64
# VAR_1242                 int64
# VAR_1243                 int64
# VAR_1244                 int64
# VAR_1245                 int64
# VAR_1246                 int64
# VAR_1247                 int64
# VAR_1248                 int64
# VAR_1249                 int64
# VAR_1250                 int64
# VAR_1251                 int64
# VAR_1252                 int64
# VAR_1253                 int64
# VAR_1254                 int64
# VAR_1255                 int64
# VAR_1256                 int64
# VAR_1257                 int64
# VAR_1258                 int64
# VAR_1259                 int64
# VAR_1260                 int64
# VAR_1261                 int64
# VAR_1262                 int64
# VAR_1263                 int64
# VAR_1264                 int64
# VAR_1265                 int64
# VAR_1266                 int64
# VAR_1267                 int64
# VAR_1268                 int64
# VAR_1269                 int64
# VAR_1270                 int64
# VAR_1271                 int64
# VAR_1272                 int64
# VAR_1273                 int64
# VAR_1274                 int64
# VAR_1275                 int64
# VAR_1276                 int64
# VAR_1277                 int64
# VAR_1278                 int64
# VAR_1279                 int64
# VAR_1280                 int64
# VAR_1281                 int64
# VAR_1282                 int64
# VAR_1283                 int64
# VAR_1284                 int64
# VAR_1285                 int64
# VAR_1286                 int64
# VAR_1287                 int64
# VAR_1288                 int64
# VAR_1289                 int64
# VAR_1290                 int64
# VAR_1291                 int64
# VAR_1292                 int64
# VAR_1293                 int64
# VAR_1294                 int64
# VAR_1295                 int64
# VAR_1296                 int64
# VAR_1297                 int64
# VAR_1298                 int64
# VAR_1299                 int64
# VAR_1300                 int64
# VAR_1301                 int64
# VAR_1302                 int64
# VAR_1303                 int64
# VAR_1304                 int64
# VAR_1305                 int64
# VAR_1306                 int64
# VAR_1307                 int64
# VAR_1308                 int64
# VAR_1309                 int64
# VAR_1310                 int64
# VAR_1311                 int64
# VAR_1312                 int64
# VAR_1313                 int64
# VAR_1314                 int64
# VAR_1315                 int64
# VAR_1316                 int64
# VAR_1317                 int64
# VAR_1318                 int64
# VAR_1319                 int64
# VAR_1320                 int64
# VAR_1321                 int64
# VAR_1322                 int64
# VAR_1323                 int64
# VAR_1324                 int64
# VAR_1325                 int64
# VAR_1326                 int64
# VAR_1327                 int64
# VAR_1328                 int64
# VAR_1329                 int64
# VAR_1330                 int64
# VAR_1331                 int64
# VAR_1332                 int64
# VAR_1333                 int64
# VAR_1334                 int64
# VAR_1335                 int64
# VAR_1336                 int64
# VAR_1337                 int64
# VAR_1338                 int64
# VAR_1339                 int64
# VAR_1340                 int64
# VAR_1341                 int64
# VAR_1342                 int64
# VAR_1343                 int64
# VAR_1344                 int64
# VAR_1345                 int64
# VAR_1346                 int64
# VAR_1347                 int64
# VAR_1348                 int64
# VAR_1349                 int64
# VAR_1350                 int64
# VAR_1351                 int64
# VAR_1352                 int64
# VAR_1353                 int64
# VAR_1354                 int64
# VAR_1355                 int64
# VAR_1356                 int64
# VAR_1357                 int64
# VAR_1358                 int64
# VAR_1359                 int64
# VAR_1360                 int64
# VAR_1361                 int64
# VAR_1362                 int64
# VAR_1363                 int64
# VAR_1364                 int64
# VAR_1365                 int64
# VAR_1366                 int64
# VAR_1367                 int64
# VAR_1368                 int64
# VAR_1369                 int64
# VAR_1370                 int64
# VAR_1371                 int64
# VAR_1372                 int64
# VAR_1373                 int64
# VAR_1374                 int64
# VAR_1375                 int64
# VAR_1376                 int64
# VAR_1377                 int64
# VAR_1378                 int64
# VAR_1379                 int64
# VAR_1380                 int64
# VAR_1381                 int64
# VAR_1382                 int64
# VAR_1383                 int64
# VAR_1384                 int64
# VAR_1385                 int64
# VAR_1386                 int64
# VAR_1387                 int64
# VAR_1388                 int64
# VAR_1389                 int64
# VAR_1390                 int64
# VAR_1391                 int64
# VAR_1392                 int64
# VAR_1393                 int64
# VAR_1394                 int64
# VAR_1395                 int64
# VAR_1396                 int64
# VAR_1397                 int64
# VAR_1398                 int64
# VAR_1399                 int64
# VAR_1400                 int64
# VAR_1401                 int64
# VAR_1402                 int64
# VAR_1403                 int64
# VAR_1404                 int64
# VAR_1405                 int64
# VAR_1406                 int64
# VAR_1407                 int64
# VAR_1408                 int64
# VAR_1409                 int64
# VAR_1410                 int64
# VAR_1411                 int64
# VAR_1412                 int64
# VAR_1413                 int64
# VAR_1414                 int64
# VAR_1415                 int64
# VAR_1416                 int64
# VAR_1417                 int64
# VAR_1418                 int64
# VAR_1419                 int64
# VAR_1420                 int64
# VAR_1421                 int64
# VAR_1422                 int64
# VAR_1423                 int64
# VAR_1424                 int64
# VAR_1425                 int64
# VAR_1426                 int64
# VAR_1427                 int64
# VAR_1429                 int64
# VAR_1430                 int64
# VAR_1431                 int64
# VAR_1432                 int64
# VAR_1433                 int64
# VAR_1434                 int64
# VAR_1435                 int64
# VAR_1436                 int64
# VAR_1437                 int64
# VAR_1438                 int64
# VAR_1439                 int64
# VAR_1440                 int64
# VAR_1441                 int64
# VAR_1442                 int64
# VAR_1443                 int64
# VAR_1444                 int64
# VAR_1445                 int64
# VAR_1446                 int64
# VAR_1447                 int64
# VAR_1448                 int64
# VAR_1449                 int64
# VAR_1450                 int64
# VAR_1451                 int64
# VAR_1452                 int64
# VAR_1453                 int64
# VAR_1454                 int64
# VAR_1455                 int64
# VAR_1456                 int64
# VAR_1457                 int64
# VAR_1458                 int64
# VAR_1459                 int64
# VAR_1460                 int64
# VAR_1461                 int64
# VAR_1462                 int64
# VAR_1463                 int64
# VAR_1464                 int64
# VAR_1465                 int64
# VAR_1466                 int64
# VAR_1467                 int64
# VAR_1468                 int64
# VAR_1469                 int64
# VAR_1470                 int64
# VAR_1471                 int64
# VAR_1472                 int64
# VAR_1473                 int64
# VAR_1474                 int64
# VAR_1475                 int64
# VAR_1476                 int64
# VAR_1477                 int64
# VAR_1478                 int64
# VAR_1479                 int64
# VAR_1480                 int64
# VAR_1481                 int64
# VAR_1482                 int64
# VAR_1483                 int64
# VAR_1484                 int64
# VAR_1485                 int64
# VAR_1486                 int64
# VAR_1487                 int64
# VAR_1488                 int64
# VAR_1489                 int64
# VAR_1490                 int64
# VAR_1491                 int64
# VAR_1492                 int64
# VAR_1493                 int64
# VAR_1494                 int64
# VAR_1495                 int64
# VAR_1496                 int64
# VAR_1497                 int64
# VAR_1498                 int64
# VAR_1499                 int64
# VAR_1500                 int64
# VAR_1501                 int64
# VAR_1502                 int64
# VAR_1503                 int64
# VAR_1504                 int64
# VAR_1505                 int64
# VAR_1506                 int64
# VAR_1507                 int64
# VAR_1508                 int64
# VAR_1509                 int64
# VAR_1510                 int64
# VAR_1511                 int64
# VAR_1512                 int64
# VAR_1513                 int64
# VAR_1514                 int64
# VAR_1515                 int64
# VAR_1516                 int64
# VAR_1517                 int64
# VAR_1518                 int64
# VAR_1519                 int64
# VAR_1520                 int64
# VAR_1521                 int64
# VAR_1522                 int64
# VAR_1523                 int64
# VAR_1524                 int64
# VAR_1525                 int64
# VAR_1526                 int64
# VAR_1527                 int64
# VAR_1528                 int64
# VAR_1529                 int64
# VAR_1530                 int64
# VAR_1531                 int64
# VAR_1532                 int64
# VAR_1533                 int64
# VAR_1534                 int64
# VAR_1535                 int64
# VAR_1536                 int64
# VAR_1537                 int64
# VAR_1538                 int64
# VAR_1539                 int64
# VAR_1540                 int64
# VAR_1541                 int64
# VAR_1542                 int64
# VAR_1543                 int64
# VAR_1544                 int64
# VAR_1545                 int64
# VAR_1546                 int64
# VAR_1547                 int64
# VAR_1548                 int64
# VAR_1549                 int64
# VAR_1550                 int64
# VAR_1551                 int64
# VAR_1552                 int64
# VAR_1553                 int64
# VAR_1554                 int64
# VAR_1555                 int64
# VAR_1556                 int64
# VAR_1557                 int64
# VAR_1558                 int64
# VAR_1559                 int64
# VAR_1560                 int64
# VAR_1561                 int64
# VAR_1562                 int64
# VAR_1563                 int64
# VAR_1564                 int64
# VAR_1565                 int64
# VAR_1566                 int64
# VAR_1567                 int64
# VAR_1568                 int64
# VAR_1569                 int64
# VAR_1570                 int64
# VAR_1571                 int64
# VAR_1572                 int64
# VAR_1573                 int64
# VAR_1574                 int64
# VAR_1575                 int64
# VAR_1576                 int64
# VAR_1577                 int64
# VAR_1578                 int64
# VAR_1579                 int64
# VAR_1580                 int64
# VAR_1581                 int64
# VAR_1582                 int64
# VAR_1583                 int64
# VAR_1584                 int64
# VAR_1585                 int64
# VAR_1586                 int64
# VAR_1587                 int64
# VAR_1588                 int64
# VAR_1589                 int64
# VAR_1590                 int64
# VAR_1591                 int64
# VAR_1592                 int64
# VAR_1593                 int64
# VAR_1594                 int64
# VAR_1595                 int64
# VAR_1596                 int64
# VAR_1597                 int64
# VAR_1598                 int64
# VAR_1599                 int64
# VAR_1600                 int64
# VAR_1601                 int64
# VAR_1602                 int64
# VAR_1603                 int64
# VAR_1604                 int64
# VAR_1605                 int64
# VAR_1606                 int64
# VAR_1607                 int64
# VAR_1608                 int64
# VAR_1609                 int64
# VAR_1610                 int64
# VAR_1611                 int64
# VAR_1612                 int64
# VAR_1613                 int64
# ...
# VAR_1626                 int64
# VAR_1627                 int64
# VAR_1628                 int64
# VAR_1629                 int64
# VAR_1630                 int64
# VAR_1631                 int64
# VAR_1632                 int64
# VAR_1633                 int64
# VAR_1634                 int64
# VAR_1635                 int64
# VAR_1636                 int64
# VAR_1637                 int64
# VAR_1638                 int64
# VAR_1639                 int64
# VAR_1640                 int64
# VAR_1641                 int64
# VAR_1642                 int64
# VAR_1643                 int64
# VAR_1644                 int64
# VAR_1645                 int64
# VAR_1646                 int64
# VAR_1647                 int64
# VAR_1648                 int64
# VAR_1649                 int64
# VAR_1650                 int64
# VAR_1651                 int64
# VAR_1652                 int64
# VAR_1653                 int64
# VAR_1654                 int64
# VAR_1655                 int64
# VAR_1656                 int64
# VAR_1657                 int64
# VAR_1658                 int64
# VAR_1659                 int64
# VAR_1660                 int64
# VAR_1661                 int64
# VAR_1662                 int64
# VAR_1663                 int64
# VAR_1664                 int64
# VAR_1665                 int64
# VAR_1666                 int64
# VAR_1667                 int64
# VAR_1668                 int64
# VAR_1669                 int64
# VAR_1670                 int64
# VAR_1671                 int64
# VAR_1672                 int64
# VAR_1673                 int64
# VAR_1674                 int64
# VAR_1675                 int64
# VAR_1676                 int64
# VAR_1677                 int64
# VAR_1678                 int64
# VAR_1679                 int64
# VAR_1680                 int64
# VAR_1681                 int64
# VAR_1682                 int64
# VAR_1683                 int64
# VAR_1684                 int64
# VAR_1685                 int64
# VAR_1686                 int64
# VAR_1687                 int64
# VAR_1688                 int64
# VAR_1689                 int64
# VAR_1690                 int64
# VAR_1691                 int64
# VAR_1692                 int64
# VAR_1693                 int64
# VAR_1694                 int64
# VAR_1695                 int64
# VAR_1696                 int64
# VAR_1697                 int64
# VAR_1698                 int64
# VAR_1699                 int64
# VAR_1700                 int64
# VAR_1701                 int64
# VAR_1702                 int64
# VAR_1703                 int64
# VAR_1704                 int64
# VAR_1705                 int64
# VAR_1706                 int64
# VAR_1707                 int64
# VAR_1708                 int64
# VAR_1709                 int64
# VAR_1710                 int64
# VAR_1711                 int64
# VAR_1712                 int64
# VAR_1713                 int64
# VAR_1714                 int64
# VAR_1715                 int64
# VAR_1716                 int64
# VAR_1717                 int64
# VAR_1718                 int64
# VAR_1719                 int64
# VAR_1720                 int64
# VAR_1721                 int64
# VAR_1722                 int64
# VAR_1723                 int64
# VAR_1724                 int64
# VAR_1725                 int64
# VAR_1726                 int64
# VAR_1727                 int64
# VAR_1728                 int64
# VAR_1729                 int64
# VAR_1730                 int64
# VAR_1731                 int64
# VAR_1732                 int64
# VAR_1733                 int64
# VAR_1734                 int64
# VAR_1735                 int64
# VAR_1736                 int64
# VAR_1737                 int64
# VAR_1738                 int64
# VAR_1739                 int64
# VAR_1740                 int64
# VAR_1741                 int64
# VAR_1742                 int64
# VAR_1743                 int64
# VAR_1744                 int64
# VAR_1745                 int64
# VAR_1746                 int64
# VAR_1747                 int64
# VAR_1748                 int64
# VAR_1749                 int64
# VAR_1750                 int64
# VAR_1751                 int64
# VAR_1752                 int64
# VAR_1753                 int64
# VAR_1754                 int64
# VAR_1755                 int64
# VAR_1756                 int64
# VAR_1757                 int64
# VAR_1758                 int64
# VAR_1759                 int64
# VAR_1760                 int64
# VAR_1761                 int64
# VAR_1762                 int64
# VAR_1763                 int64
# VAR_1764                 int64
# VAR_1765                 int64
# VAR_1766                 int64
# VAR_1767                 int64
# VAR_1768                 int64
# VAR_1769                 int64
# VAR_1770                 int64
# VAR_1771                 int64
# VAR_1772                 int64
# VAR_1773                 int64
# VAR_1774                 int64
# VAR_1775                 int64
# VAR_1776                 int64
# VAR_1777                 int64
# VAR_1778                 int64
# VAR_1779                 int64
# VAR_1780                 int64
# VAR_1781                 int64
# VAR_1782                 int64
# VAR_1783                 int64
# VAR_1784                 int64
# VAR_1785                 int64
# VAR_1786                 int64
# VAR_1787                 int64
# VAR_1788                 int64
# VAR_1789                 int64
# VAR_1790                 int64
# VAR_1791                 int64
# VAR_1792                 int64
# VAR_1793                 int64
# VAR_1794                 int64
# VAR_1795                 int64
# VAR_1796                 int64
# VAR_1797                 int64
# VAR_1798                 int64
# VAR_1799                 int64
# VAR_1800                 int64
# VAR_1801                 int64
# VAR_1802                 int64
# VAR_1803                 int64
# VAR_1804                 int64
# VAR_1805                 int64
# VAR_1806                 int64
# VAR_1807                 int64
# VAR_1808                 int64
# VAR_1809                 int64
# VAR_1810                 int64
# VAR_1811                 int64
# VAR_1812                 int64
# VAR_1813                 int64
# VAR_1814                 int64
# VAR_1815                 int64
# VAR_1816                 int64
# VAR_1817                 int64
# VAR_1818                 int64
# VAR_1819                 int64
# VAR_1820                 int64
# VAR_1821                 int64
# VAR_1822                 int64
# VAR_1823                 int64
# VAR_1824                 int64
# VAR_1825                 int64
# VAR_1826                 int64
# VAR_1827                 int64
# VAR_1828                 int64
# VAR_1829                 int64
# VAR_1830                 int64
# VAR_1831                 int64
# VAR_1832                 int64
# VAR_1833                 int64
# VAR_1834                 int64
# VAR_1835                 int64
# VAR_1836                 int64
# VAR_1837                 int64
# VAR_1838                 int64
# VAR_1839                 int64
# VAR_1840                 int64
# VAR_1841                 int64
# VAR_1842                 int64
# VAR_1843                 int64
# VAR_1844                 int64
# VAR_1845                 int64
# VAR_1846                 int64
# VAR_1847                 int64
# VAR_1848                 int64
# VAR_1849                 int64
# VAR_1850                 int64
# VAR_1851                 int64
# VAR_1852                 int64
# VAR_1853                 int64
# VAR_1854                 int64
# VAR_1855                 int64
# VAR_1856                 int64
# VAR_1857                 int64
# VAR_1858                 int64
# VAR_1859                 int64
# VAR_1860                 int64
# VAR_1861                 int64
# VAR_1862                 int64
# VAR_1863                 int64
# VAR_1864                 int64
# VAR_1865                 int64
# VAR_1866                 int64
# VAR_1867                 int64
# VAR_1868                 int64
# VAR_1869                 int64
# VAR_1870                 int64
# VAR_1871                 int64
# VAR_1872                 int64
# VAR_1873                 int64
# VAR_1874                 int64
# VAR_1875                 int64
# VAR_1876                 int64
# VAR_1877                 int64
# VAR_1878                 int64
# VAR_1879                 int64
# VAR_1880                 int64
# VAR_1881                 int64
# VAR_1882                 int64
# VAR_1883                 int64
# VAR_1884                 int64
# VAR_1885                 int64
# VAR_1886                 int64
# VAR_1887                 int64
# VAR_1888                 int64
# VAR_1889                 int64
# VAR_1890                 int64
# VAR_1891                 int64
# VAR_1892                 int64
# VAR_1893                 int64
# VAR_1894                 int64
# VAR_1895                 int64
# VAR_1896                 int64
# VAR_1897                 int64
# VAR_1898                 int64
# VAR_1899                 int64
# VAR_1900                 int64
# VAR_1901                 int64
# VAR_1902                 int64
# VAR_1903                 int64
# VAR_1904                 int64
# VAR_1905                 int64
# VAR_1906                 int64
# VAR_1907                 int64
# VAR_1908                 int64
# VAR_1909                 int64
# VAR_1910                 int64
# VAR_1911                 int64
# VAR_1912                 int64
# VAR_1913                 int64
# VAR_1914                 int64
# VAR_1915                 int64
# VAR_1916                 int64
# VAR_1917                 int64
# VAR_1918                 int64
# VAR_1919                 int64
# VAR_1920                 int64
# VAR_1921                 int64
# VAR_1922                 int64
# VAR_1923                 int64
# VAR_1924                 int64
# VAR_1925                 int64
# VAR_1926                 int64
# VAR_1927                 int64
# VAR_1928                 int64
# VAR_1929                 int64
# VAR_1930                 int64
# VAR_1931                 int64
# VAR_1932                 int64
# VAR_1933                 int64
# VAR_0001_H               uint8
# VAR_0001_Q               uint8
# VAR_0001_R               uint8
# VAR_0005_B               uint8
# VAR_0005_C               uint8
# VAR_0005_N               uint8
# VAR_0005_S               uint8
# VAR_0237_AK              uint8
# VAR_0237_AL              uint8
# VAR_0237_AR              uint8
# VAR_0237_AZ              uint8
# VAR_0237_CA              uint8
# VAR_0237_CO              uint8
# VAR_0237_CT              uint8
# VAR_0237_DC              uint8
# VAR_0237_DE              uint8
# VAR_0237_FL              uint8
# VAR_0237_GA              uint8
# VAR_0237_HI              uint8
# VAR_0237_IA              uint8
# VAR_0237_ID              uint8
# VAR_0237_IL              uint8
# VAR_0237_IN              uint8
# VAR_0237_KS              uint8
# VAR_0237_KY              uint8
# VAR_0237_LA              uint8
# VAR_0237_MD              uint8
# VAR_0237_MI              uint8
# VAR_0237_MN              uint8
# VAR_0237_MO              uint8
# VAR_0237_MS              uint8
# VAR_0237_MT              uint8
# VAR_0237_NC              uint8
# VAR_0237_NE              uint8
# VAR_0237_NJ              uint8
# VAR_0237_NM              uint8
# VAR_0237_NV              uint8
# VAR_0237_NY              uint8
# VAR_0237_OH              uint8
# VAR_0237_OK              uint8
# VAR_0237_OR              uint8
# VAR_0237_PA              uint8
# VAR_0237_SC              uint8
# VAR_0237_SD              uint8
# VAR_0237_TN              uint8
# VAR_0237_TX              uint8
# VAR_0237_UT              uint8
# VAR_0237_VA              uint8
# VAR_0237_WA              uint8
# VAR_0237_WI              uint8
# VAR_0237_WV              uint8
# VAR_0237_WY              uint8
# VAR_0274_-1              uint8
# VAR_0274_AK              uint8
# VAR_0274_AL              uint8
# VAR_0274_AR              uint8
# VAR_0274_AZ              uint8
# VAR_0274_CA              uint8
# VAR_0274_CO              uint8
# VAR_0274_CT              uint8
# VAR_0274_DC              uint8
# VAR_0274_DE              uint8
# VAR_0274_EE              uint8
# VAR_0274_FL              uint8
# VAR_0274_GA              uint8
# VAR_0274_GS              uint8
# VAR_0274_HI              uint8
# VAR_0274_IA              uint8
# VAR_0274_ID              uint8
# VAR_0274_IL              uint8
# VAR_0274_IN              uint8
# VAR_0274_KS              uint8
# VAR_0274_KY              uint8
# VAR_0274_LA              uint8
# VAR_0274_MA              uint8
# VAR_0274_MD              uint8
# VAR_0274_ME              uint8
# VAR_0274_MI              uint8
# VAR_0274_MN              uint8
# VAR_0274_MO              uint8
# VAR_0274_MS              uint8
# VAR_0274_MT              uint8
# VAR_0274_NC              uint8
# VAR_0274_ND              uint8
# VAR_0274_NE              uint8
# VAR_0274_NH              uint8
# VAR_0274_NJ              uint8
# VAR_0274_NM              uint8
# VAR_0274_NV              uint8
# VAR_0274_NY              uint8
# VAR_0274_OH              uint8
# VAR_0274_OK              uint8
# VAR_0274_OR              uint8
# VAR_0274_PA              uint8
# VAR_0274_PR              uint8
# VAR_0274_RI              uint8
# VAR_0274_RN              uint8
# VAR_0274_RR              uint8
# VAR_0274_SC              uint8
# VAR_0274_SD              uint8
# VAR_0274_TN              uint8
# VAR_0274_TX              uint8
# VAR_0274_UT              uint8
# VAR_0274_VA              uint8
# VAR_0274_VT              uint8
# VAR_0274_WA              uint8
# VAR_0274_WI              uint8
# VAR_0274_WV              uint8
# VAR_0274_WY              uint8
# VAR_0283_-1              uint8
# VAR_0283_F               uint8
# VAR_0283_H               uint8
# VAR_0283_P               uint8
# VAR_0283_R               uint8
# VAR_0283_S               uint8
# VAR_0283_U               uint8
# VAR_0305_-1              uint8
# VAR_0305_F               uint8
# VAR_0305_H               uint8
# VAR_0305_M               uint8
# VAR_0305_P               uint8
# VAR_0305_R               uint8
# VAR_0305_S               uint8
# VAR_0305_U               uint8
# VAR_0325_-1              uint8
# VAR_0325_F               uint8
# VAR_0325_G               uint8
# VAR_0325_H               uint8
# VAR_0325_M               uint8
# VAR_0325_P               uint8
# VAR_0325_R               uint8
# VAR_0325_S               uint8
# VAR_0325_U               uint8
# VAR_0342_-1              uint8
# VAR_0342_AA              uint8
# VAR_0342_AB              uint8
# VAR_0342_AC              uint8
# VAR_0342_AD              uint8
# VAR_0342_AE              uint8
# VAR_0342_AF              uint8
# VAR_0342_AU              uint8
# VAR_0342_BA              uint8
# VAR_0342_BB              uint8
# VAR_0342_BC              uint8
# VAR_0342_BD              uint8
# VAR_0342_BE              uint8
# VAR_0342_BF              uint8
# VAR_0342_BU              uint8
# VAR_0342_CA              uint8
# VAR_0342_CB              uint8
# VAR_0342_CC              uint8
# VAR_0342_CD              uint8
# VAR_0342_CE              uint8
# VAR_0342_CF              uint8
# VAR_0342_CU              uint8
# VAR_0342_DA              uint8
# VAR_0342_DB              uint8
# VAR_0342_DC              uint8
# VAR_0342_DD              uint8
# VAR_0342_DE              uint8
# VAR_0342_DF              uint8
# VAR_0342_DU              uint8
# VAR_0342_EA              uint8
# VAR_0342_EB              uint8
# VAR_0342_EC              uint8
# VAR_0342_ED              uint8
# VAR_0342_EE              uint8
# VAR_0342_EF              uint8
# VAR_0342_EU              uint8
# VAR_0342_FA              uint8
# VAR_0342_FB              uint8
# VAR_0342_FC              uint8
# VAR_0342_FD              uint8
# VAR_0342_FE              uint8
# VAR_0342_FF              uint8
# VAR_0342_FU              uint8
# VAR_0342_UA              uint8
# VAR_0342_UB              uint8
# VAR_0342_UC              uint8
# VAR_0342_UD              uint8
# VAR_0342_UE              uint8
# VAR_0342_UF              uint8
# VAR_0342_UU              uint8
# VAR_0352_-1              uint8
# VAR_0352_O               uint8
# VAR_0352_R               uint8
# VAR_0352_U               uint8
# VAR_0353_-1              uint8
# VAR_0353_O               uint8
# VAR_0353_R               uint8
# VAR_0353_U               uint8
# VAR_0354_-1              uint8
# VAR_0354_O               uint8
# VAR_0354_R               uint8
# VAR_0354_U               uint8
# VAR_0466_-1              uint8
# VAR_0466_I               uint8
# VAR_0467_-1              uint8
# VAR_0467_Discharge NA    uint8
# VAR_0467_Discharged      uint8
# VAR_0467_Dismissed       uint8
# VAR_1934_-1              uint8
# VAR_1934_Discharge NA    uint8
# VAR_1934_Discharged      uint8
# VAR_1934_Dismissed       uint8
# dtypes: bool(4), float64(431), int64(1402), uint8(205)
# memory usage: 2.0 GB

# %%
# Split the data further into training and test datasets
if (splitDataset):
    X_train_df, X_test_df, y_train_df, y_test_df = train_test_split(X_original, y_original, test_size=splitPercentage, 
                                                                    stratify=y_original, random_state=seedNum)
else:
    X_train_df, y_train_df = X_original, y_original
    X_test_df, y_test_df = X_original, y_original
print("X_train_df.shape: {} y_train_df.shape: {}".format(X_train_df.shape, y_train_df.shape))
print("X_test_df.shape: {} y_test_df.shape: {}".format(X_test_df.shape, y_test_df.shape))
# Out:
# X_train_df.shape: (122622, 2042) y_train_df.shape: (122622,)
# X_test_df.shape: (21640, 2042) y_test_df.shape: (21640,)

# %% [markdown]
# ### 3.b) Feature Scaling and Data Pre-Processing

# %%
# Not applicable for this iteration of the project

# %% [markdown]
# ### 3.c) Training Data Balancing

# %%
# Not applicable for this iteration of the project

# %% [markdown]
# ### 3.d) Feature Selection

# %%
# Not applicable for this iteration of the project

# %% [markdown]
# ### 3.e) Display the Final Datasets for Model-Building

# %%
# Finalize the training and testing datasets for the modeling activities
X_train = X_train_df.to_numpy()
y_train = y_train_df.to_numpy()
X_test = X_test_df.to_numpy()
y_test = y_test_df.to_numpy()
print("X_train.shape: {} y_train.shape: {}".format(X_train.shape, y_train.shape))
print("X_test.shape: {} y_test.shape: {}".format(X_test.shape, y_test.shape))
# Out:
# X_train.shape: (122622, 2042) y_train.shape: (122622,)
# X_test.shape: (21640, 2042) y_test.shape: (21640,)

# %%
if (notifyStatus): email_notify("Data Cleaning and Transformation completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 4 - Model and Evaluate Algorithms
# After the data-prep, we next work on finding a workable model by evaluating a subset of machine learning algorithms that are good at exploiting the structure of the training. The typical evaluation tasks include:
#
# * Defining test options such as cross validation and the evaluation metric to use.
# * Spot checking a suite of linear and nonlinear machine learning algorithms.
# * Comparing the estimated accuracy of algorithms.
#
# For this project, we will evaluate one linear, two non-linear and four ensemble algorithms:
#
# Linear Algorithm: Logistic Regression
#
# Non-Linear Algorithm: Decision Trees (CART)
#
# Ensemble Algorithms: Bagged CART, Random Forest, Extra Trees, and Gradient Boosting
#
# The random number seed is reset before each run to ensure that the evaluation of each algorithm is performed using the same data splits. It ensures the results are directly comparable.

# %% [markdown]
# ### 4.a) Set test options and evaluation metric

# %%
# Set up Algorithms Spot-Checking Array
train_models = []
train_results = []
train_model_names = []
train_metrics = []
# train_models.append(('LGR', LogisticRegression(random_state=seedNum)))
# train_models.append(('CART', DecisionTreeClassifier(random_state=seedNum)))
# train_models.append(('BGT', BaggingClassifier(random_state=seedNum, n_jobs=n_jobs)))
# train_models.append(('RNF', RandomForestClassifier(random_state=seedNum, n_jobs=n_jobs)))
# train_models.append(('EXT', ExtraTreesClassifier(random_state=seedNum, n_jobs=n_jobs)))
# train_models.append(('GBM', GradientBoostingClassifier(random_state=seedNum)))
train_models.append(('XGB', XGBClassifier(random_state=seedNum, n_jobs=n_jobs, tree_method='gpu_hist')))

# %%
# Generate model in turn
startTimeModule = datetime.now()
for name, model in train_models:
	if (notifyStatus): email_notify("Algorithm "+name+" modeling has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))
	startTimeModule = datetime.now()
	kfold = KFold(n_splits=n_folds, shuffle=True, random_state=seedNum)
	cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring, n_jobs=n_jobs, verbose=1)
	train_results.append(cv_results)
	train_model_names.append(name)
	train_metrics.append(cv_results.mean())
	print("%s: %f (%f)" % (name, cv_results.mean(), cv_results.std()))
	print(model)
	print ('Model training time:', (datetime.now() - startTimeModule), '\n')
	if (notifyStatus): email_notify("Algorithm "+name+" modeling completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))
print ('Average metrics ('+scoring+') from all models:',np.mean(train_metrics))
print ('Total training time for all models:',(datetime.now() - startTimeModule))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# XGB: 0.770893 (0.001443)
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=888,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, tree_method='gpu_hist', verbosity=1)
# Model training time: 0:02:57.682428
#
# Average metrics (roc_auc) from all models: 0.7708926869037656
# Total training time for all models: 0:02:57.683303
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  3.0min finished

# %% [markdown]
# ### 4.b) Spot-checking baseline algorithms

# %%
fig = plt.figure(figsize=(16,12))
fig.suptitle('Algorithm Comparison - Spot Checking')
ax = fig.add_subplot(111)
plt.boxplot(train_results)
ax.set_xticklabels(train_model_names)
plt.show()

# %% [markdown]
# ## Section 5 - Improve Accuracy
# After we achieve a short list of machine learning algorithms with good level of accuracy, we can leverage ways to improve the accuracy of the models.

# %% [markdown]
# ### 5.a) Algorithm Tuning

# %%
# Set up the comparison array
tune_results = []
tune_model_names = []

# %%
# Tuning algorithm #1 - XGBoost with n_estimators = 500
startTimeModule = datetime.now()
if (notifyStatus): email_notify("Algorithm #1 tuning has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

tune_model1 = XGBClassifier(n_estimators=500, random_state=seedNum, n_jobs=n_jobs, tree_method='gpu_hist')
tune_model_names.append('XGB1')
paramGrid1 = dict(max_depth=np.array([3, 6, 9]), min_child_weight=np.array([1, 3, 5]))

kfold = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=seedNum)
grid1 = GridSearchCV(estimator=tune_model1, param_grid=paramGrid1, scoring=scoring, cv=kfold, n_jobs=n_jobs, verbose=2)
grid_result1 = grid1.fit(X_train, y_train)

print("Best: %f using %s" % (grid_result1.best_score_, grid_result1.best_params_))
tune_results.append(grid_result1.cv_results_['mean_test_score'])
means = grid_result1.cv_results_['mean_test_score']
stds = grid_result1.cv_results_['std_test_score']
params = grid_result1.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
print ('Model training time:',(datetime.now() - startTimeModule))
if (notifyStatus): email_notify("Algorithm #1 tuning completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] max_depth=3, min_child_weight=1 .................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .................. max_depth=3, min_child_weight=1, total=  43.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   45.1s remaining:    0.0s
# [CV] max_depth=3, min_child_weight=1 .................................
# [CV] .................. max_depth=3, min_child_weight=1, total=  43.4s
# [CV] max_depth=3, min_child_weight=1 .................................
# [CV] .................. max_depth=3, min_child_weight=1, total=  43.1s
# [CV] max_depth=3, min_child_weight=1 .................................
# [CV] .................. max_depth=3, min_child_weight=1, total=  43.2s
# [CV] max_depth=3, min_child_weight=1 .................................
# [CV] .................. max_depth=3, min_child_weight=1, total=  43.2s
# [CV] max_depth=3, min_child_weight=3 .................................
# [CV] .................. max_depth=3, min_child_weight=3, total=  42.9s
# [CV] max_depth=3, min_child_weight=3 .................................
# [CV] .................. max_depth=3, min_child_weight=3, total=  43.4s
# [CV] max_depth=3, min_child_weight=3 .................................
# [CV] .................. max_depth=3, min_child_weight=3, total=  43.1s
# [CV] max_depth=3, min_child_weight=3 .................................
# [CV] .................. max_depth=3, min_child_weight=3, total=  42.8s
# [CV] max_depth=3, min_child_weight=3 .................................
# [CV] .................. max_depth=3, min_child_weight=3, total=  42.8s
# [CV] max_depth=3, min_child_weight=5 .................................
# [CV] .................. max_depth=3, min_child_weight=5, total=  42.8s
# [CV] max_depth=3, min_child_weight=5 .................................
# [CV] .................. max_depth=3, min_child_weight=5, total=  43.3s
# [CV] max_depth=3, min_child_weight=5 .................................
# [CV] .................. max_depth=3, min_child_weight=5, total=  43.1s
# [CV] max_depth=3, min_child_weight=5 .................................
# [CV] .................. max_depth=3, min_child_weight=5, total=  43.0s
# [CV] max_depth=3, min_child_weight=5 .................................
# [CV] .................. max_depth=3, min_child_weight=5, total=  42.9s
# [CV] max_depth=6, min_child_weight=1 .................................
# [CV] .................. max_depth=6, min_child_weight=1, total=  49.8s
# [CV] max_depth=6, min_child_weight=1 .................................
# [CV] .................. max_depth=6, min_child_weight=1, total=  50.3s
# [CV] max_depth=6, min_child_weight=1 .................................
# [CV] .................. max_depth=6, min_child_weight=1, total=  50.1s
# [CV] max_depth=6, min_child_weight=1 .................................
# [CV] .................. max_depth=6, min_child_weight=1, total=  49.7s
# [CV] max_depth=6, min_child_weight=1 .................................
# [CV] .................. max_depth=6, min_child_weight=1, total=  49.6s
# [CV] max_depth=6, min_child_weight=3 .................................
# [CV] .................. max_depth=6, min_child_weight=3, total=  49.3s
# [CV] max_depth=6, min_child_weight=3 .................................
# [CV] .................. max_depth=6, min_child_weight=3, total=  49.9s
# [CV] max_depth=6, min_child_weight=3 .................................
# [CV] .................. max_depth=6, min_child_weight=3, total=  49.7s
# [CV] max_depth=6, min_child_weight=3 .................................
# [CV] .................. max_depth=6, min_child_weight=3, total=  49.7s
# [CV] max_depth=6, min_child_weight=3 .................................
# [CV] .................. max_depth=6, min_child_weight=3, total=  49.5s
# [CV] max_depth=6, min_child_weight=5 .................................
# [CV] .................. max_depth=6, min_child_weight=5, total=  49.1s
# [CV] max_depth=6, min_child_weight=5 .................................
# [CV] .................. max_depth=6, min_child_weight=5, total=  49.7s
# [CV] max_depth=6, min_child_weight=5 .................................
# [CV] .................. max_depth=6, min_child_weight=5, total=  49.3s
# [CV] max_depth=6, min_child_weight=5 .................................
# [CV] .................. max_depth=6, min_child_weight=5, total=  49.0s
# [CV] max_depth=6, min_child_weight=5 .................................
# [CV] .................. max_depth=6, min_child_weight=5, total=  48.9s
# [CV] max_depth=9, min_child_weight=1 .................................
# [CV] .................. max_depth=9, min_child_weight=1, total= 1.2min
# [CV] max_depth=9, min_child_weight=1 .................................
# [CV] .................. max_depth=9, min_child_weight=1, total= 1.3min
# [CV] max_depth=9, min_child_weight=1 .................................
# [CV] .................. max_depth=9, min_child_weight=1, total= 1.3min
# [CV] max_depth=9, min_child_weight=1 .................................
# [CV] .................. max_depth=9, min_child_weight=1, total= 1.3min
# [CV] max_depth=9, min_child_weight=1 .................................
# [CV] .................. max_depth=9, min_child_weight=1, total= 1.3min
# [CV] max_depth=9, min_child_weight=3 .................................
# [CV] .................. max_depth=9, min_child_weight=3, total= 1.2min
# [CV] max_depth=9, min_child_weight=3 .................................
# [CV] .................. max_depth=9, min_child_weight=3, total= 1.2min
# [CV] max_depth=9, min_child_weight=3 .................................
# [CV] .................. max_depth=9, min_child_weight=3, total= 1.2min
# [CV] max_depth=9, min_child_weight=3 .................................
# [CV] .................. max_depth=9, min_child_weight=3, total= 1.1min
# [CV] max_depth=9, min_child_weight=3 .................................
# [CV] .................. max_depth=9, min_child_weight=3, total= 1.2min
# [CV] max_depth=9, min_child_weight=5 .................................
# [CV] .................. max_depth=9, min_child_weight=5, total= 1.1min
# [CV] max_depth=9, min_child_weight=5 .................................
# [CV] .................. max_depth=9, min_child_weight=5, total= 1.1min
# [CV] max_depth=9, min_child_weight=5 .................................
# [CV] .................. max_depth=9, min_child_weight=5, total= 1.1min
# [CV] max_depth=9, min_child_weight=5 .................................
# [CV] .................. max_depth=9, min_child_weight=5, total= 1.1min
# [CV] max_depth=9, min_child_weight=5 .................................
# [CV] .................. max_depth=9, min_child_weight=5, total= 1.1min
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed: 42.3min finished
# Best: 0.781527 using {'max_depth': 6, 'min_child_weight': 5}
# 0.780910 (0.002034) with: {'max_depth': 3, 'min_child_weight': 1}
# 0.781067 (0.002223) with: {'max_depth': 3, 'min_child_weight': 3}
# 0.780934 (0.002339) with: {'max_depth': 3, 'min_child_weight': 5}
# 0.780992 (0.002445) with: {'max_depth': 6, 'min_child_weight': 1}
# 0.781076 (0.002349) with: {'max_depth': 6, 'min_child_weight': 3}
# 0.781527 (0.001784) with: {'max_depth': 6, 'min_child_weight': 5}
# 0.777777 (0.003042) with: {'max_depth': 9, 'min_child_weight': 1}
# 0.778922 (0.002922) with: {'max_depth': 9, 'min_child_weight': 3}
# 0.779690 (0.002297) with: {'max_depth': 9, 'min_child_weight': 5}
# Model training time: 0:43:10.778647

# %%
# Tuning algorithm #2 - XGBoost with n_estimators = 1000
startTimeModule = datetime.now()
if (notifyStatus): email_notify("Algorithm #2 tuning has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

tune_model2 = XGBClassifier(n_estimators=1000, random_state=seedNum, n_jobs=n_jobs, tree_method='gpu_hist')
tune_model_names.append('XGB2')
paramGrid2 = dict(max_depth=np.array([3, 6, 9]), min_child_weight=np.array([1, 3, 5]))

kfold = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=seedNum)
grid2 = GridSearchCV(estimator=tune_model2, param_grid=paramGrid2, scoring=scoring, cv=kfold, n_jobs=n_jobs, verbose=2)
grid_result2 = grid2.fit(X_train, y_train)

print("Best: %f using %s" % (grid_result2.best_score_, grid_result2.best_params_))
tune_results.append(grid_result2.cv_results_['mean_test_score'])
means = grid_result2.cv_results_['mean_test_score']
stds = grid_result2.cv_results_['std_test_score']
params = grid_result2.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
print ('Model training time:',(datetime.now() - startTimeModule))
if (notifyStatus): email_notify("Algorithm #2 tuning completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] max_depth=3, min_child_weight=1 .................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .................. max_depth=3, min_child_weight=1, total=  55.4s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   57.4s remaining:    0.0s
# [CV] max_depth=3, min_child_weight=1 .................................
# [CV] .................. max_depth=3, min_child_weight=1, total=  56.3s
# [CV] max_depth=3, min_child_weight=1 .................................
# [CV] .................. max_depth=3, min_child_weight=1, total=  54.2s
# [CV] max_depth=3, min_child_weight=1 .................................
# [CV] .................. max_depth=3, min_child_weight=1, total=  53.2s
# [CV] max_depth=3, min_child_weight=1 .................................
# [CV] .................. max_depth=3, min_child_weight=1, total=  57.1s
# [CV] max_depth=3, min_child_weight=3 .................................
# [CV] .................. max_depth=3, min_child_weight=3, total=  54.7s
# [CV] max_depth=3, min_child_weight=3 .................................
# [CV] .................. max_depth=3, min_child_weight=3, total=  56.2s
# [CV] max_depth=3, min_child_weight=3 .................................
# [CV] .................. max_depth=3, min_child_weight=3, total=  53.5s
# [CV] max_depth=3, min_child_weight=3 .................................
# [CV] .................. max_depth=3, min_child_weight=3, total=  53.0s
# [CV] max_depth=3, min_child_weight=3 .................................
# [CV] .................. max_depth=3, min_child_weight=3, total=  57.3s
# [CV] max_depth=3, min_child_weight=5 .................................
# [CV] .................. max_depth=3, min_child_weight=5, total=  54.8s
# [CV] max_depth=3, min_child_weight=5 .................................
# [CV] .................. max_depth=3, min_child_weight=5, total=  56.2s
# [CV] max_depth=3, min_child_weight=5 .................................
# [CV] .................. max_depth=3, min_child_weight=5, total=  53.4s
# [CV] max_depth=3, min_child_weight=5 .................................
# [CV] .................. max_depth=3, min_child_weight=5, total=  53.0s
# [CV] max_depth=3, min_child_weight=5 .................................
# [CV] .................. max_depth=3, min_child_weight=5, total=  57.2s
# [CV] max_depth=6, min_child_weight=1 .................................
# [CV] .................. max_depth=6, min_child_weight=1, total= 1.1min
# [CV] max_depth=6, min_child_weight=1 .................................
# [CV] .................. max_depth=6, min_child_weight=1, total= 1.2min
# [CV] max_depth=6, min_child_weight=1 .................................
# [CV] .................. max_depth=6, min_child_weight=1, total= 1.1min
# [CV] max_depth=6, min_child_weight=1 .................................
# [CV] .................. max_depth=6, min_child_weight=1, total= 1.1min
# [CV] max_depth=6, min_child_weight=1 .................................
# [CV] .................. max_depth=6, min_child_weight=1, total= 1.2min
# [CV] max_depth=6, min_child_weight=3 .................................
# [CV] .................. max_depth=6, min_child_weight=3, total= 1.1min
# [CV] max_depth=6, min_child_weight=3 .................................
# [CV] .................. max_depth=6, min_child_weight=3, total= 1.2min
# [CV] max_depth=6, min_child_weight=3 .................................
# [CV] .................. max_depth=6, min_child_weight=3, total= 1.1min
# [CV] max_depth=6, min_child_weight=3 .................................
# [CV] .................. max_depth=6, min_child_weight=3, total= 1.1min
# [CV] max_depth=6, min_child_weight=3 .................................
# [CV] .................. max_depth=6, min_child_weight=3, total= 1.2min
# [CV] max_depth=6, min_child_weight=5 .................................
# [CV] .................. max_depth=6, min_child_weight=5, total= 1.1min
# [CV] max_depth=6, min_child_weight=5 .................................
# [CV] .................. max_depth=6, min_child_weight=5, total= 1.2min
# [CV] max_depth=6, min_child_weight=5 .................................
# [CV] .................. max_depth=6, min_child_weight=5, total= 1.1min
# [CV] max_depth=6, min_child_weight=5 .................................
# [CV] .................. max_depth=6, min_child_weight=5, total= 1.1min
# [CV] max_depth=6, min_child_weight=5 .................................
# [CV] .................. max_depth=6, min_child_weight=5, total= 1.2min
# [CV] max_depth=9, min_child_weight=1 .................................
# [CV] .................. max_depth=9, min_child_weight=1, total= 1.9min
# [CV] max_depth=9, min_child_weight=1 .................................
# [CV] .................. max_depth=9, min_child_weight=1, total= 2.0min
# [CV] max_depth=9, min_child_weight=1 .................................
# [CV] .................. max_depth=9, min_child_weight=1, total= 1.9min
# [CV] max_depth=9, min_child_weight=1 .................................
# [CV] .................. max_depth=9, min_child_weight=1, total= 1.9min
# [CV] max_depth=9, min_child_weight=1 .................................
# [CV] .................. max_depth=9, min_child_weight=1, total= 2.0min
# [CV] max_depth=9, min_child_weight=3 .................................
# [CV] .................. max_depth=9, min_child_weight=3, total= 1.7min
# [CV] max_depth=9, min_child_weight=3 .................................
# [CV] .................. max_depth=9, min_child_weight=3, total= 1.8min
# [CV] max_depth=9, min_child_weight=3 .................................
# [CV] .................. max_depth=9, min_child_weight=3, total= 1.7min
# [CV] max_depth=9, min_child_weight=3 .................................
# [CV] .................. max_depth=9, min_child_weight=3, total= 1.7min
# [CV] max_depth=9, min_child_weight=3 .................................
# [CV] .................. max_depth=9, min_child_weight=3, total= 1.8min
# [CV] max_depth=9, min_child_weight=5 .................................
# [CV] .................. max_depth=9, min_child_weight=5, total= 1.6min
# [CV] max_depth=9, min_child_weight=5 .................................
# [CV] .................. max_depth=9, min_child_weight=5, total= 1.6min
# [CV] max_depth=9, min_child_weight=5 .................................
# [CV] .................. max_depth=9, min_child_weight=5, total= 1.6min
# [CV] max_depth=9, min_child_weight=5 .................................
# [CV] .................. max_depth=9, min_child_weight=5, total= 1.6min
# [CV] max_depth=9, min_child_weight=5 .................................
# [CV] .................. max_depth=9, min_child_weight=5, total= 1.7min
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed: 58.9min finished
# Best: 0.782386 using {'max_depth': 3, 'min_child_weight': 3}
# 0.782132 (0.002498) with: {'max_depth': 3, 'min_child_weight': 1}
# 0.782386 (0.002475) with: {'max_depth': 3, 'min_child_weight': 3}
# 0.781929 (0.002729) with: {'max_depth': 3, 'min_child_weight': 5}
# 0.779452 (0.002825) with: {'max_depth': 6, 'min_child_weight': 1}
# 0.779524 (0.001781) with: {'max_depth': 6, 'min_child_weight': 3}
# 0.779695 (0.001456) with: {'max_depth': 6, 'min_child_weight': 5}
# 0.780603 (0.003162) with: {'max_depth': 9, 'min_child_weight': 1}
# 0.780371 (0.002902) with: {'max_depth': 9, 'min_child_weight': 3}
# 0.779787 (0.002402) with: {'max_depth': 9, 'min_child_weight': 5}
# Model training time: 0:59:50.805193

# %%
# Tuning algorithm #3 - XGBoost with n_estimators = 1500
startTimeModule = datetime.now()
if (notifyStatus): email_notify("Algorithm #3 tuning has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

tune_model3 = XGBClassifier(n_estimators=1500, random_state=seedNum, n_jobs=n_jobs, tree_method='gpu_hist')
tune_model_names.append('XGB3')
paramGrid3 = dict(max_depth=np.array([3, 6, 9]), min_child_weight=np.array([1, 3, 5]))

kfold = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=seedNum)
grid3 = GridSearchCV(estimator=tune_model3, param_grid=paramGrid3, scoring=scoring, cv=kfold, n_jobs=n_jobs, verbose=2)
grid_result3 = grid3.fit(X_train, y_train)

print("Best: %f using %s" % (grid_result3.best_score_, grid_result3.best_params_))
tune_results.append(grid_result3.cv_results_['mean_test_score'])
means = grid_result3.cv_results_['mean_test_score']
stds = grid_result3.cv_results_['std_test_score']
params = grid_result3.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
print ('Model training time:',(datetime.now() - startTimeModule))
if (notifyStatus): email_notify("Algorithm #3 tuning completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] max_depth=3, min_child_weight=1 .................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .................. max_depth=3, min_child_weight=1, total= 1.1min
# [CV] max_depth=3, min_child_weight=1 .................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.1min remaining:    0.0s
# [CV] .................. max_depth=3, min_child_weight=1, total= 1.1min
# [CV] max_depth=3, min_child_weight=1 .................................
# [CV] .................. max_depth=3, min_child_weight=1, total= 1.1min
# [CV] max_depth=3, min_child_weight=1 .................................
# [CV] .................. max_depth=3, min_child_weight=1, total= 1.1min
# [CV] max_depth=3, min_child_weight=1 .................................
# [CV] .................. max_depth=3, min_child_weight=1, total= 1.1min
# [CV] max_depth=3, min_child_weight=3 .................................
# [CV] .................. max_depth=3, min_child_weight=3, total= 1.1min
# [CV] max_depth=3, min_child_weight=3 .................................
# [CV] .................. max_depth=3, min_child_weight=3, total= 1.2min
# [CV] max_depth=3, min_child_weight=3 .................................
# [CV] .................. max_depth=3, min_child_weight=3, total= 1.1min
# [CV] max_depth=3, min_child_weight=3 .................................
# [CV] .................. max_depth=3, min_child_weight=3, total= 1.1min
# [CV] max_depth=3, min_child_weight=3 .................................
# [CV] .................. max_depth=3, min_child_weight=3, total= 1.2min
# [CV] max_depth=3, min_child_weight=5 .................................
# [CV] .................. max_depth=3, min_child_weight=5, total= 1.1min
# [CV] max_depth=3, min_child_weight=5 .................................
# [CV] .................. max_depth=3, min_child_weight=5, total= 1.2min
# [CV] max_depth=3, min_child_weight=5 .................................
# [CV] .................. max_depth=3, min_child_weight=5, total= 1.1min
# [CV] max_depth=3, min_child_weight=5 .................................
# [CV] .................. max_depth=3, min_child_weight=5, total= 1.1min
# [CV] max_depth=3, min_child_weight=5 .................................
# [CV] .................. max_depth=3, min_child_weight=5, total= 1.2min
# [CV] max_depth=6, min_child_weight=1 .................................
# [CV] .................. max_depth=6, min_child_weight=1, total= 1.5min
# [CV] max_depth=6, min_child_weight=1 .................................
# [CV] .................. max_depth=6, min_child_weight=1, total= 1.5min
# [CV] max_depth=6, min_child_weight=1 .................................
# [CV] .................. max_depth=6, min_child_weight=1, total= 1.5min
# [CV] max_depth=6, min_child_weight=1 .................................
# [CV] .................. max_depth=6, min_child_weight=1, total= 1.4min
# [CV] max_depth=6, min_child_weight=1 .................................
# [CV] .................. max_depth=6, min_child_weight=1, total= 1.5min
# [CV] max_depth=6, min_child_weight=3 .................................
# [CV] .................. max_depth=6, min_child_weight=3, total= 1.4min
# [CV] max_depth=6, min_child_weight=3 .................................
# [CV] .................. max_depth=6, min_child_weight=3, total= 1.5min
# [CV] max_depth=6, min_child_weight=3 .................................
# [CV] .................. max_depth=6, min_child_weight=3, total= 1.4min
# [CV] max_depth=6, min_child_weight=3 .................................
# [CV] .................. max_depth=6, min_child_weight=3, total= 1.4min
# [CV] max_depth=6, min_child_weight=3 .................................
# [CV] .................. max_depth=6, min_child_weight=3, total= 1.5min
# [CV] max_depth=6, min_child_weight=5 .................................
# [CV] .................. max_depth=6, min_child_weight=5, total= 1.4min
# [CV] max_depth=6, min_child_weight=5 .................................
# [CV] .................. max_depth=6, min_child_weight=5, total= 1.5min
# [CV] max_depth=6, min_child_weight=5 .................................
# [CV] .................. max_depth=6, min_child_weight=5, total= 1.4min
# [CV] max_depth=6, min_child_weight=5 .................................
# [CV] .................. max_depth=6, min_child_weight=5, total= 1.4min
# [CV] max_depth=6, min_child_weight=5 .................................
# [CV] .................. max_depth=6, min_child_weight=5, total= 1.5min
# [CV] max_depth=9, min_child_weight=1 .................................
# [CV] .................. max_depth=9, min_child_weight=1, total= 2.5min
# [CV] max_depth=9, min_child_weight=1 .................................
# [CV] .................. max_depth=9, min_child_weight=1, total= 2.6min
# [CV] max_depth=9, min_child_weight=1 .................................
# [CV] .................. max_depth=9, min_child_weight=1, total= 2.5min
# [CV] max_depth=9, min_child_weight=1 .................................
# [CV] .................. max_depth=9, min_child_weight=1, total= 2.5min
# [CV] max_depth=9, min_child_weight=1 .................................
# [CV] .................. max_depth=9, min_child_weight=1, total= 2.6min
# [CV] max_depth=9, min_child_weight=3 .................................
# [CV] .................. max_depth=9, min_child_weight=3, total= 2.2min
# [CV] max_depth=9, min_child_weight=3 .................................
# [CV] .................. max_depth=9, min_child_weight=3, total= 2.3min
# [CV] max_depth=9, min_child_weight=3 .................................
# [CV] .................. max_depth=9, min_child_weight=3, total= 2.2min
# [CV] max_depth=9, min_child_weight=3 .................................
# [CV] .................. max_depth=9, min_child_weight=3, total= 2.2min
# [CV] max_depth=9, min_child_weight=3 .................................
# [CV] .................. max_depth=9, min_child_weight=3, total= 2.3min
# [CV] max_depth=9, min_child_weight=5 .................................
# [CV] .................. max_depth=9, min_child_weight=5, total= 2.1min
# [CV] max_depth=9, min_child_weight=5 .................................
# [CV] .................. max_depth=9, min_child_weight=5, total= 2.1min
# [CV] max_depth=9, min_child_weight=5 .................................
# [CV] .................. max_depth=9, min_child_weight=5, total= 2.1min
# [CV] max_depth=9, min_child_weight=5 .................................
# [CV] .................. max_depth=9, min_child_weight=5, total= 2.0min
# [CV] max_depth=9, min_child_weight=5 .................................
# [CV] .................. max_depth=9, min_child_weight=5, total= 2.2min
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed: 74.4min finished
# Best: 0.782261 using {'max_depth': 9, 'min_child_weight': 1}
# 0.782107 (0.002491) with: {'max_depth': 3, 'min_child_weight': 1}
# 0.781985 (0.002679) with: {'max_depth': 3, 'min_child_weight': 3}
# 0.781747 (0.002448) with: {'max_depth': 3, 'min_child_weight': 5}
# 0.778122 (0.002132) with: {'max_depth': 6, 'min_child_weight': 1}
# 0.778190 (0.001424) with: {'max_depth': 6, 'min_child_weight': 3}
# 0.777908 (0.001638) with: {'max_depth': 6, 'min_child_weight': 5}
# 0.782261 (0.003264) with: {'max_depth': 9, 'min_child_weight': 1}
# 0.781416 (0.002751) with: {'max_depth': 9, 'min_child_weight': 3}
# 0.780579 (0.002610) with: {'max_depth': 9, 'min_child_weight': 5}
# Model training time: 1:17:04.559925

# %%
print(grid_result2.best_params_.items())
# Out:
# dict_items([('max_depth', 3), ('min_child_weight', 3)])

# %%
# for key, value in grid_result1.best_params_.items():
#     best_paramKey1 = key
#     best_paramValue1 = value
# print("Captured the best parameter for algorithm #1:", best_paramKey1, '=', best_paramValue1)

# %% [markdown]
# ### 5.b) Compare Algorithms After Tuning

# %%
fig = plt.figure(figsize=(16,12))
fig.suptitle('Algorithm Comparison - Post Tuning')
ax = fig.add_subplot(111)
plt.boxplot(tune_results)
ax.set_xticklabels(tune_model_names)
plt.show()

# %% [markdown]
# ## Section 6 - Finalize Model
# Once we have narrow down to a model that we believe can make accurate predictions on unseen data, we are ready to finalize it. Finalizing a model may involve sub-tasks such as:
# * Using an optimal model tuned to make predictions on unseen data.
# * Creating a standalone model using the tuned parameters
# * Saving an optimal model to file for later use.

# %%
if (notifyStatus): email_notify("Model Validation and Final Model Creation has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 6.a) Measure predictions from the test dataset

# %%
test_model1 = XGBClassifier(n_estimators=1000, max_depth=3, min_child_weight=3, 
                            random_state=seedNum, n_jobs=n_jobs, tree_method='gpu_hist', verbose=2)
test_model1.fit(X_train, y_train)
predictions1 = test_model1.predict(X_test)
print('Accuracy Score:', accuracy_score(y_test, predictions1))
print('ROC/AUC Score:', roc_auc_score(y_test, predictions1))
print(confusion_matrix(y_test, predictions1))
print(classification_report(y_test, predictions1))
print(test_model1)
# Out:
# Accuracy Score: 0.7995378927911275
# ROC/AUC Score: 0.6286591440981955
# [[15746   862]
#  [ 3476  1556]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.95      0.88     16608
#            1       0.64      0.31      0.42      5032
#
#     accuracy                           0.80     21640
#    macro avg       0.73      0.63      0.65     21640
# weighted avg       0.78      0.80      0.77     21640
#
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=3, missing=None, n_estimators=1000, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=888,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, tree_method='gpu_hist', verbose=2,
#               verbosity=1)

# %% [markdown]
# ### 6.b) Create a standalone model using all available data

# %%
# Combining the training and testing datasets to form the complete dataset that will be used for training the final model
# X_complete = np.vstack((X_train, X_test))
# y_complete = np.concatenate((y_train, y_test))
# print("X_complete.shape: {} y_complete.shape: {}".format(X_complete.shape, y_complete.shape))
# final_model = test_model1.fit(X_complete, y_complete)
# print(final_model)

# %% [markdown]
# ### 6.c) Save the final model for later use

# %%
# modelName = 'FinalModel_BinaryClass.sav'
# dump(final_model, modelName)

# %%
if (notifyStatus): email_notify("Model Validation and Final Model Creation completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
print ('Total time for the script:',(datetime.now() - startTimeScript))
# Out:
# Total time for the script: 4:50:57.506403
