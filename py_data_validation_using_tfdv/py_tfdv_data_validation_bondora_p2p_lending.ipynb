# %% [markdown]
# # Data Validation for Bondora P2P Lending Using Python and TensorFlow Data Validation
# ### David Lowe
# ### August 30, 2021
#
# SUMMARY: The project aims to construct a data validation flow using TensorFlow Data Validation (TFDV) and document the end-to-end steps using a template. The Bondora P2P Lending dataset is a binary classification situation where we attempt to predict one of the two possible outcomes.
#
# INTRODUCTION: The Kaggle dataset owner retrieved this dataset from Bondora, a leading European peer-to-peer lending platform. The data comprises demographic and financial information of the borrowers and loan transactions. For investors, "peer-to-peer lending" or "P2P" offers an attractive way to diversify portfolios and enhance long-term performance. To make effective decisions, investors want to minimize the risk of default of each lending decision and realize the return that compensates for the risk. The retrieved data is a combined dataset of defaulted and non-defaulted loans between February 2009 and July 2021. We will try to predict the default risk using the available information.
#
# Additional Notes: I adapted this workflow from the TensorFlow Data Validation tutorial on TensorFlow.org (https://www.tensorflow.org/tfx/tutorials/data_validation/tfdv_basic). The plan is to build a robust TFDV script for validating datasets in building machine learning models.
#
# CONCLUSION: In this iteration, the data validation workflow helped to validate the features and structures of the training, validation, and test datasets. The workflow also generated statistics over different slices of data which can help track model and anomaly metrics.
#
# Dataset Used: Kaggle Bondora P2P Lending Loan Data
#
# Dataset ML Model: Binary classification with numerical and categorical attributes
#
# Dataset Reference: https://www.kaggle.com/sid321axn/bondora-peer-to-peer-lending-loan-data
#
# Dataset Attribute Description: https://www.bondora.com/en/public-reports
#
# Data validation for a machine learning project generally can be broken down into the following tasks:
#
# 1. Prepare Environment
# 2. Generate and Visualize Training Data Statistics
# 3. Check Anomalies in Validation Dataset
# 4. Check Anomalies in Test Dataset
# 5. Check for Data Drift and Skew
# 6. Display Stats for Data Slices
# 7. Finalize the Schema

# %% [markdown]
# ## Task 1 - Prepare Environment

# %% [markdown]
# ### 1.a) Load libraries and modules

# %%
# Set the random seed number for reproducible results
RNG_SEED = 8

# %%
# Import packages
import os
import pandas as pd
from datetime import datetime
from sklearn.model_selection import train_test_split

import tensorflow as tf
import tempfile, urllib, zipfile
import tensorflow_data_validation as tfdv
from tensorflow.python.lib.io import file_io
from tensorflow_data_validation.utils import slicing_util
from tensorflow_metadata.proto.v0.statistics_pb2 import DatasetFeatureStatisticsList, DatasetFeatureStatistics
from tensorflow_metadata.proto.v0 import schema_pb2

# %% [markdown]
# ### 1.b) Set up the controlling parameters and functions

# %%
# Begin the timer for the script processing
start_time_script = datetime.now()

# Set the percentage sizes for splitting the dataset
VAL_SET_RATIO = 0.2
TEST_SET_RATIO = 0.5

# Set TF's logger to only display errors to avoid internal warnings being shown
tf.get_logger().setLevel('ERROR')
print('TFDV version: {}'.format(tfdv.version.__version__))
# Out:
# TFDV version: 1.0.0

# %% [markdown]
# ### 1.c) Load dataset

# %%
# Read CSV data into a dataframe and mark the missing data as NaN
dataset_path = 'https://dainesanalytics.com/datasets/kaggle-bondora-p2p-lending/LoanData_Bondora.csv'
df_dataset_import = pd.read_csv(dataset_path, header=0)

# Take a peek at the dataframe after import
print(df_dataset_import.head())
# Out:
# /home/tensorflowml/appdev/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (34,38,80,82,83,89,90) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   ReportAsOfEOD                                LoanId  LoanNumber  \
# 0    2021-07-20  66AE108B-532B-4BB3-BAB7-0019A46412C1      483449
# 1    2021-07-20  D152382E-A50D-46ED-8FF2-0053E0C86A70      378148
# 2    2021-07-20  87342E13-66CB-483F-833A-007953E50C78      451831
# 3    2021-07-20  87227056-6BF9-410C-98D1-008F788E122A      349381
# 4    2021-07-20  2DDE6336-E466-4624-A337-00A0ED1A1468      443082
#
#            ListedOnUTC     BiddingStartedOn  BidsPortfolioManager  BidsApi  \
# 0  2016-03-23 16:07:19  2016-03-23 16:07:19                   970     1150
# 1  2015-06-25 11:02:28  2015-06-25 11:02:28                  1295        0
# 2  2016-01-14 10:00:21  2016-01-14 10:00:21                  2700      565
# 3  2015-03-24 15:55:44  2015-03-24 15:55:44                  1115        0
# 4  2015-12-17 10:12:00  2015-12-17 10:12:00                   305        0
#
#    BidsManual   UserName  NewCreditCustomer  ...  \
# 0         5.0   BO965519              False  ...
# 1      1705.0  BOA9K172A              False  ...
# 2      5835.0  BO7971663               True  ...
# 3       385.0  BO76151K3               True  ...
# 4       785.0  BOK423A63               True  ...
#
#   PreviousEarlyRepaymentsCountBeforeLoan GracePeriodStart GracePeriodEnd  \
# 0                                    0.0       2019-10-28     2020-01-27
# 1                                    1.0              NaN            NaN
# 2                                    0.0              NaN            NaN
# 3                                    1.0              NaN            NaN
# 4                                    0.0              NaN            NaN
#
#   NextPaymentDate NextPaymentNr NrOfScheduledPayments  ReScheduledOn  \
# 0             NaN           NaN                   NaN            NaN
# 1             NaN           NaN                   NaN            NaN
# 2             NaN           NaN                   NaN            NaN
# 3             NaN           NaN                   NaN            NaN
# 4             NaN           NaN                   NaN            NaN
#
#    PrincipalDebtServicingCost  InterestAndPenaltyDebtServicingCost  \
# 0                        0.00                                51.73
# 1                        0.00                                47.08
# 2                      259.67                              1659.60
# 3                        0.00                               215.05
# 4                        0.00                                 0.00
#
#    ActiveLateLastPaymentCategory
# 0                          31-60
# 1                           180+
# 2                           180+
# 3                           180+
# 4                           180+
#
# [5 rows x 112 columns]

# %%
# Standardize the class column to the name of target
df_dataset_import = df_dataset_import.rename(columns={'Status':'target'})

# %%
# Quickly handle some special data cleaning situations
df_dataset_import['NrOfDependants'] = df_dataset_import['NrOfDependants'].replace(['10Plus'], '11')
df_dataset_import['NrOfDependants'].fillna(0, inplace=True)
df_dataset_import['NrOfDependants'] = df_dataset_import['NrOfDependants'].astype('int')

# %%
df_dataset_import.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179235 entries, 0 to 179234
# Data columns (total 112 columns):
#  #    Column                                  Dtype
# ---   ------                                  -----
#  0    ReportAsOfEOD                           object
#  1    LoanId                                  object
#  2    LoanNumber                              int64
#  3    ListedOnUTC                             object
#  4    BiddingStartedOn                        object
#  5    BidsPortfolioManager                    int64
#  6    BidsApi                                 int64
#  7    BidsManual                              float64
#  8    UserName                                object
#  9    NewCreditCustomer                       bool
#  10   LoanApplicationStartedDate              object
#  11   LoanDate                                object
#  12   ContractEndDate                         object
#  13   FirstPaymentDate                        object
#  14   MaturityDate_Original                   object
#  15   MaturityDate_Last                       object
#  16   ApplicationSignedHour                   int64
#  17   ApplicationSignedWeekday                int64
#  18   VerificationType                        float64
#  19   LanguageCode                            int64
#  20   Age                                     int64
#  21   DateOfBirth                             float64
#  22   Gender                                  float64
#  23   Country                                 object
#  24   AppliedAmount                           float64
#  25   Amount                                  float64
#  26   Interest                                float64
#  27   LoanDuration                            int64
#  28   MonthlyPayment                          float64
#  29   County                                  float64
#  30   City                                    float64
#  31   UseOfLoan                               int64
#  32   Education                               float64
#  33   MaritalStatus                           float64
#  34   NrOfDependants                          int64
#  35   EmploymentStatus                        float64
#  36   EmploymentDurationCurrentEmployer       object
#  37   EmploymentPosition                      float64
#  38   WorkExperience                          object
#  39   OccupationArea                          float64
#  40   HomeOwnershipType                       float64
#  41   IncomeFromPrincipalEmployer             float64
#  42   IncomeFromPension                       float64
#  43   IncomeFromFamilyAllowance               float64
#  44   IncomeFromSocialWelfare                 float64
#  45   IncomeFromLeavePay                      float64
#  46   IncomeFromChildSupport                  float64
#  47   IncomeOther                             float64
#  48   IncomeTotal                             float64
#  49   ExistingLiabilities                     int64
#  50   LiabilitiesTotal                        float64
#  51   RefinanceLiabilities                    int64
#  52   DebtToIncome                            float64
#  53   FreeCash                                float64
#  54   MonthlyPaymentDay                       int64
#  55   ActiveScheduleFirstPaymentReached       bool
#  56   PlannedPrincipalTillDate                float64
#  57   PlannedInterestTillDate                 float64
#  58   LastPaymentOn                           object
#  59   CurrentDebtDaysPrimary                  float64
#  60   DebtOccuredOn                           object
#  61   CurrentDebtDaysSecondary                float64
#  62   DebtOccuredOnForSecondary               object
#  63   ExpectedLoss                            float64
#  64   LossGivenDefault                        float64
#  65   ExpectedReturn                          float64
#  66   ProbabilityOfDefault                    float64
#  67   DefaultDate                             object
#  68   PrincipalOverdueBySchedule              float64
#  69   PlannedPrincipalPostDefault             float64
#  70   PlannedInterestPostDefault              float64
#  71   EAD1                                    float64
#  72   EAD2                                    float64
#  73   PrincipalRecovery                       float64
#  74   InterestRecovery                        float64
#  75   RecoveryStage                           float64
#  76   StageActiveSince                        object
#  77   ModelVersion                            float64
#  78   Rating                                  object
#  79   EL_V0                                   float64
#  80   Rating_V0                               object
#  81   EL_V1                                   float64
#  82   Rating_V1                               object
#  83   Rating_V2                               object
#  84   target                                  object
#  85   Restructured                            bool
#  86   ActiveLateCategory                      object
#  87   WorseLateCategory                       object
#  88   CreditScoreEsMicroL                     object
#  89   CreditScoreEsEquifaxRisk                object
#  90   CreditScoreFiAsiakasTietoRiskGrade      object
#  91   CreditScoreEeMini                       float64
#  92   PrincipalPaymentsMade                   float64
#  93   InterestAndPenaltyPaymentsMade          float64
#  94   PrincipalWriteOffs                      float64
#  95   InterestAndPenaltyWriteOffs             float64
#  96   PrincipalBalance                        float64
#  97   InterestAndPenaltyBalance               float64
#  98   NoOfPreviousLoansBeforeLoan             float64
#  99   AmountOfPreviousLoansBeforeLoan         float64
#  100  PreviousRepaymentsBeforeLoan            float64
#  101  PreviousEarlyRepaymentsBefoleLoan       float64
#  102  PreviousEarlyRepaymentsCountBeforeLoan  float64
#  103  GracePeriodStart                        object
#  104  GracePeriodEnd                          object
#  105  NextPaymentDate                         object
#  106  NextPaymentNr                           float64
#  107  NrOfScheduledPayments                   float64
#  108  ReScheduledOn                           object
#  109  PrincipalDebtServicingCost              float64
#  110  InterestAndPenaltyDebtServicingCost     float64
#  111  ActiveLateLastPaymentCategory           object
# dtypes: bool(3), float64(62), int64(13), object(34)
# memory usage: 149.6+ MB

# %% [markdown]
# ### 1.d) Splitting Data into Sets

# %%
# Split the data further into training, validation, and test datasets
df_train, df_val_test = train_test_split(df_dataset_import, test_size=VAL_SET_RATIO, random_state=RNG_SEED)
df_val, df_test = train_test_split(df_val_test, test_size=TEST_SET_RATIO, random_state=RNG_SEED)

# Test data emulates the data that would be submitted for predictions, so it should not have the label column.
df_test = df_test.drop(['target'], axis=1)

print("Training dataset has {} records and {} columns.".format(df_train.shape[0], df_train.shape[1]))
print("Validation dataset has {} records and {} columns.".format(df_val.shape[0], df_val.shape[1]))
print("Test dataset has {} records and {} columns".format(df_test.shape[0], df_test.shape[1]))
# Out:
# Training dataset has 143388 records and 112 columns.
# Validation dataset has 17923 records and 112 columns.
# Test dataset has 17924 records and 111 columns

# %% [markdown]
# ## Task 2 - Generate and Visualize Training Data Statistics

# %% [markdown]
# ### 2.a) Remove Non-Essential Features

# %%
high_pct_null_features = []
total_records = df_train.shape[0]
for feature in df_train.columns:
    missing_records = df_train[feature].isnull().sum()
    missing_percentage = missing_records / total_records
    print('Feature', feature, 'has', missing_records,'missing rows. Percentage:', missing_percentage * 100)
    if missing_percentage >= 0.75:
        high_pct_null_features.append(feature)
print('Proposed lis of features for removal:', high_pct_null_features)
# Out:
# Feature ReportAsOfEOD has 0 missing rows. Percentage: 0.0
# Feature LoanId has 0 missing rows. Percentage: 0.0
# Feature LoanNumber has 0 missing rows. Percentage: 0.0
# Feature ListedOnUTC has 0 missing rows. Percentage: 0.0
# Feature BiddingStartedOn has 0 missing rows. Percentage: 0.0
# Feature BidsPortfolioManager has 0 missing rows. Percentage: 0.0
# Feature BidsApi has 0 missing rows. Percentage: 0.0
# Feature BidsManual has 0 missing rows. Percentage: 0.0
# Feature UserName has 0 missing rows. Percentage: 0.0
# Feature NewCreditCustomer has 0 missing rows. Percentage: 0.0
# Feature LoanApplicationStartedDate has 0 missing rows. Percentage: 0.0
# Feature LoanDate has 0 missing rows. Percentage: 0.0
# Feature ContractEndDate has 61098 missing rows. Percentage: 42.61026027282618
# Feature FirstPaymentDate has 0 missing rows. Percentage: 0.0
# Feature MaturityDate_Original has 0 missing rows. Percentage: 0.0
# Feature MaturityDate_Last has 0 missing rows. Percentage: 0.0
# Feature ApplicationSignedHour has 0 missing rows. Percentage: 0.0
# Feature ApplicationSignedWeekday has 0 missing rows. Percentage: 0.0
# Feature VerificationType has 41 missing rows. Percentage: 0.02859374564119731
# Feature LanguageCode has 0 missing rows. Percentage: 0.0
# Feature Age has 0 missing rows. Percentage: 0.0
# Feature DateOfBirth has 143388 missing rows. Percentage: 100.0
# Feature Gender has 38 missing rows. Percentage: 0.026501520350377998
# Feature Country has 0 missing rows. Percentage: 0.0
# Feature AppliedAmount has 0 missing rows. Percentage: 0.0
# Feature Amount has 0 missing rows. Percentage: 0.0
# Feature Interest has 0 missing rows. Percentage: 0.0
# Feature LoanDuration has 0 missing rows. Percentage: 0.0
# Feature MonthlyPayment has 5377 missing rows. Percentage: 3.749965129578486
# Feature County has 143388 missing rows. Percentage: 100.0
# Feature City has 143388 missing rows. Percentage: 100.0
# Feature UseOfLoan has 0 missing rows. Percentage: 0.0
# Feature Education has 41 missing rows. Percentage: 0.02859374564119731
# Feature MaritalStatus has 41 missing rows. Percentage: 0.02859374564119731
# Feature NrOfDependants has 0 missing rows. Percentage: 0.0
# Feature EmploymentStatus has 163 missing rows. Percentage: 0.11367757413451612
# Feature EmploymentDurationCurrentEmployer has 1278 missing rows. Percentage: 0.8912879738890285
# Feature EmploymentPosition has 143388 missing rows. Percentage: 100.0
# Feature WorkExperience has 114102 missing rows. Percentage: 79.57569671102185
# Feature OccupationArea has 74 missing rows. Percentage: 0.051608223840209785
# Feature HomeOwnershipType has 1329 missing rows. Percentage: 0.9268558038329566
# Feature IncomeFromPrincipalEmployer has 0 missing rows. Percentage: 0.0
# Feature IncomeFromPension has 0 missing rows. Percentage: 0.0
# Feature IncomeFromFamilyAllowance has 0 missing rows. Percentage: 0.0
# Feature IncomeFromSocialWelfare has 0 missing rows. Percentage: 0.0
# Feature IncomeFromLeavePay has 0 missing rows. Percentage: 0.0
# Feature IncomeFromChildSupport has 0 missing rows. Percentage: 0.0
# Feature IncomeOther has 0 missing rows. Percentage: 0.0
# Feature IncomeTotal has 0 missing rows. Percentage: 0.0
# Feature ExistingLiabilities has 0 missing rows. Percentage: 0.0
# Feature LiabilitiesTotal has 0 missing rows. Percentage: 0.0
# Feature RefinanceLiabilities has 0 missing rows. Percentage: 0.0
# Feature DebtToIncome has 41 missing rows. Percentage: 0.02859374564119731
# Feature FreeCash has 41 missing rows. Percentage: 0.02859374564119731
# Feature MonthlyPaymentDay has 0 missing rows. Percentage: 0.0
# Feature ActiveScheduleFirstPaymentReached has 0 missing rows. Percentage: 0.0
# Feature PlannedPrincipalTillDate has 99798 missing rows. Percentage: 69.59996652439536
# Feature PlannedInterestTillDate has 1582 missing rows. Percentage: 1.1033001366920525
# Feature LastPaymentOn has 5392 missing rows. Percentage: 3.7604262560325825
# Feature CurrentDebtDaysPrimary has 82393 missing rows. Percentage: 57.46157279549195
# Feature DebtOccuredOn has 82393 missing rows. Percentage: 57.46157279549195
# Feature CurrentDebtDaysSecondary has 77553 missing rows. Percentage: 54.08611599297012
# Feature DebtOccuredOnForSecondary has 77553 missing rows. Percentage: 54.08611599297012
# Feature ExpectedLoss has 2119 missing rows. Percentage: 1.4778084637487099
# Feature LossGivenDefault has 2119 missing rows. Percentage: 1.4778084637487099
# Feature ExpectedReturn has 2119 missing rows. Percentage: 1.4778084637487099
# Feature ProbabilityOfDefault has 2119 missing rows. Percentage: 1.4778084637487099
# Feature DefaultDate has 86243 missing rows. Percentage: 60.14659525204341
# Feature PrincipalOverdueBySchedule has 11867 missing rows. Percentage: 8.276145842050939
# Feature PlannedPrincipalPostDefault has 86243 missing rows. Percentage: 60.14659525204341
# Feature PlannedInterestPostDefault has 86243 missing rows. Percentage: 60.14659525204341
# Feature EAD1 has 86244 missing rows. Percentage: 60.14729266047368
# Feature EAD2 has 86244 missing rows. Percentage: 60.14729266047368
# Feature PrincipalRecovery has 86243 missing rows. Percentage: 60.14659525204341
# Feature InterestRecovery has 86243 missing rows. Percentage: 60.14659525204341
# Feature RecoveryStage has 53891 missing rows. Percentage: 37.584037715847906
# Feature StageActiveSince has 48441 missing rows. Percentage: 33.783161770859486
# Feature ModelVersion has 2119 missing rows. Percentage: 1.4778084637487099
# Feature Rating has 2205 missing rows. Percentage: 1.5377855887521967
# Feature EL_V0 has 139698 missing rows. Percentage: 97.42656289229224
# Feature Rating_V0 has 139698 missing rows. Percentage: 97.42656289229224
# Feature EL_V1 has 133000 missing rows. Percentage: 92.75532122632299
# Feature Rating_V1 has 133000 missing rows. Percentage: 92.75532122632299
# Feature Rating_V2 has 123236 missing rows. Percentage: 85.94582531313638
# Feature target has 0 missing rows. Percentage: 0.0
# Feature Restructured has 0 missing rows. Percentage: 0.0
# Feature ActiveLateCategory has 83395 missing rows. Percentage: 58.16037604262561
# Feature WorseLateCategory has 41927 missing rows. Percentage: 29.240243256060477
# Feature CreditScoreEsMicroL has 24253 missing rows. Percentage: 16.91424665941362
# Feature CreditScoreEsEquifaxRisk has 133557 missing rows. Percentage: 93.1437777219851
# Feature CreditScoreFiAsiakasTietoRiskGrade has 109811 missing rows. Percentage: 76.58311713671995
# Feature CreditScoreEeMini has 59517 missing rows. Percentage: 41.507657544564395
# Feature PrincipalPaymentsMade has 0 missing rows. Percentage: 0.0
# Feature InterestAndPenaltyPaymentsMade has 0 missing rows. Percentage: 0.0
# Feature PrincipalWriteOffs has 82545 missing rows. Percentage: 57.567578876893464
# Feature InterestAndPenaltyWriteOffs has 82545 missing rows. Percentage: 57.567578876893464
# Feature PrincipalBalance has 0 missing rows. Percentage: 0.0
# Feature InterestAndPenaltyBalance has 4189 missing rows. Percentage: 2.9214439144140374
# Feature NoOfPreviousLoansBeforeLoan has 5 missing rows. Percentage: 0.0034870421513655257
# Feature AmountOfPreviousLoansBeforeLoan has 5 missing rows. Percentage: 0.0034870421513655257
# Feature PreviousRepaymentsBeforeLoan has 49953 missing rows. Percentage: 34.83764331743242
# Feature PreviousEarlyRepaymentsBefoleLoan has 96293 missing rows. Percentage: 67.15554997628811
# Feature PreviousEarlyRepaymentsCountBeforeLoan has 5 missing rows. Percentage: 0.0034870421513655257
# Feature GracePeriodStart has 109937 missing rows. Percentage: 76.67099059893437
# Feature GracePeriodEnd has 109937 missing rows. Percentage: 76.67099059893437
# Feature NextPaymentDate has 90938 missing rows. Percentage: 63.420927832175636
# Feature NextPaymentNr has 53662 missing rows. Percentage: 37.42433118531537
# Feature NrOfScheduledPayments has 53662 missing rows. Percentage: 37.42433118531537
# Feature ReScheduledOn has 93025 missing rows. Percentage: 64.8764192261556
# Feature PrincipalDebtServicingCost has 82545 missing rows. Percentage: 57.567578876893464
# Feature InterestAndPenaltyDebtServicingCost has 82545 missing rows. Percentage: 57.567578876893464
# Feature ActiveLateLastPaymentCategory has 77553 missing rows. Percentage: 54.08611599297012
# Proposed lis of features for removal: ['DateOfBirth', 'County', 'City', 'EmploymentPosition', 'WorkExperience', 'EL_V0', 'Rating_V0', 'EL_V1', 'Rating_V1', 'Rating_V2', 'CreditScoreEsEquifaxRisk', 'CreditScoreFiAsiakasTietoRiskGrade', 'GracePeriodStart', 'GracePeriodEnd']

# %%
# Define non-essential features to remove
features_to_remove = {'ReportAsOfEOD','LoanId','LoanNumber','ListedOnUTC','BiddingStartedOn',
                      'BidsPortfolioManager','BidsApi','BidsManual','UserName','LoanApplicationStartedDate',
                      'LoanDate','ContractEndDate','FirstPaymentDate','MaturityDate_Original','MaturityDate_Last',
                      'DateOfBirth','DateOfBirth','County','City','EmploymentPosition',
                      'WorkExperience','EL_V0','Rating_V0','EL_V1','Rating_V1','Rating_V2',
                      'CreditScoreEsEquifaxRisk','CreditScoreFiAsiakasTietoRiskGrade',
                      'GracePeriodStart','GracePeriodEnd','NextPaymentDate','DefaultDate'}

# Collect features to whitelist while computing the statistics
features_to_keep = [col for col in df_dataset_import.columns if (col not in features_to_remove)]

# Instantiate a StatsOptions class and define the feature_whitelist property
options_train = tfdv.StatsOptions(feature_allowlist=features_to_keep)

# Review the features to generate the statistics
print(options_train.feature_allowlist)
print('Number of Features:', len(options_train.feature_allowlist))
# Out:
# ['NewCreditCustomer', 'ApplicationSignedHour', 'ApplicationSignedWeekday', 'VerificationType', 'LanguageCode', 'Age', 'Gender', 'Country', 'AppliedAmount', 'Amount', 'Interest', 'LoanDuration', 'MonthlyPayment', 'UseOfLoan', 'Education', 'MaritalStatus', 'NrOfDependants', 'EmploymentStatus', 'EmploymentDurationCurrentEmployer', 'OccupationArea', 'HomeOwnershipType', 'IncomeFromPrincipalEmployer', 'IncomeFromPension', 'IncomeFromFamilyAllowance', 'IncomeFromSocialWelfare', 'IncomeFromLeavePay', 'IncomeFromChildSupport', 'IncomeOther', 'IncomeTotal', 'ExistingLiabilities', 'LiabilitiesTotal', 'RefinanceLiabilities', 'DebtToIncome', 'FreeCash', 'MonthlyPaymentDay', 'ActiveScheduleFirstPaymentReached', 'PlannedPrincipalTillDate', 'PlannedInterestTillDate', 'LastPaymentOn', 'CurrentDebtDaysPrimary', 'DebtOccuredOn', 'CurrentDebtDaysSecondary', 'DebtOccuredOnForSecondary', 'ExpectedLoss', 'LossGivenDefault', 'ExpectedReturn', 'ProbabilityOfDefault', 'PrincipalOverdueBySchedule', 'PlannedPrincipalPostDefault', 'PlannedInterestPostDefault', 'EAD1', 'EAD2', 'PrincipalRecovery', 'InterestRecovery', 'RecoveryStage', 'StageActiveSince', 'ModelVersion', 'Rating', 'target', 'Restructured', 'ActiveLateCategory', 'WorseLateCategory', 'CreditScoreEsMicroL', 'CreditScoreEeMini', 'PrincipalPaymentsMade', 'InterestAndPenaltyPaymentsMade', 'PrincipalWriteOffs', 'InterestAndPenaltyWriteOffs', 'PrincipalBalance', 'InterestAndPenaltyBalance', 'NoOfPreviousLoansBeforeLoan', 'AmountOfPreviousLoansBeforeLoan', 'PreviousRepaymentsBeforeLoan', 'PreviousEarlyRepaymentsBefoleLoan', 'PreviousEarlyRepaymentsCountBeforeLoan', 'NextPaymentNr', 'NrOfScheduledPayments', 'ReScheduledOn', 'PrincipalDebtServicingCost', 'InterestAndPenaltyDebtServicingCost', 'ActiveLateLastPaymentCategory']
# Number of Features: 81

# %% [markdown]
# ### 2.b) Generate Statistics for Training Data

# %%
train_stats = tfdv.generate_statistics_from_dataframe(df_train, stats_options=options_train)

# get the number of features used to compute statistics
print(f"Number of features used: {len(train_stats.datasets[0].features)}")

# check the number of examples used
print(f"Number of examples used: {train_stats.datasets[0].num_examples}")

# check the column names of the first and last feature
print(f"First feature: {train_stats.datasets[0].features[0].path.step[0]}")
print(f"Last feature: {train_stats.datasets[0].features[-1].path.step[0]}")
# Out:
# Number of features used: 81
# Number of examples used: 143388
# First feature: NewCreditCustomer
# Last feature: ActiveLateLastPaymentCategory

# %% [markdown]
# ### 2.c) Visualize Training Statistics

# %%
tfdv.visualize_statistics(train_stats)
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %% [markdown]
# ### 2.d) Infer Training Schema

# %%
# Infer the data schema by using the training statistics previously generated
dataset_schema = tfdv.infer_schema(train_stats)

# Display the data schema
tfdv.display_schema(dataset_schema)
# Out:
#                                          Type  Presence Valency  \
# Feature name
# 'NewCreditCustomer'                       INT  required
# 'ApplicationSignedHour'                   INT  required
# 'ApplicationSignedWeekday'                INT  required
# 'VerificationType'                      FLOAT  optional  single
# 'LanguageCode'                            INT  required
# ...                                       ...       ...     ...
# 'NrOfScheduledPayments'                 FLOAT  optional  single
# 'ReScheduledOn'                         BYTES  optional  single
# 'PrincipalDebtServicingCost'            FLOAT  optional  single
# 'InterestAndPenaltyDebtServicingCost'   FLOAT  optional  single
# 'ActiveLateLastPaymentCategory'        STRING  optional  single
#
#                                                                 Domain
# Feature name
# 'NewCreditCustomer'                                                  -
# 'ApplicationSignedHour'                                              -
# 'ApplicationSignedWeekday'                                           -
# 'VerificationType'                                                   -
# 'LanguageCode'                                                       -
# ...                                                                ...
# 'NrOfScheduledPayments'                                              -
# 'ReScheduledOn'                                                      -
# 'PrincipalDebtServicingCost'                                         -
# 'InterestAndPenaltyDebtServicingCost'                                -
# 'ActiveLateLastPaymentCategory'        'ActiveLateLastPaymentCategory'
#
# [81 rows x 4 columns]
# /home/tensorflowml/appdev/lib/python3.8/site-packages/tensorflow_data_validation/utils/display_util.py:180: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('max_colwidth', -1)
#                                                                                                                                                        Values
# Domain
# 'Country'                            'EE', 'ES', 'FI', 'SK'
# 'EmploymentDurationCurrentEmployer'  'MoreThan5Years', 'Other', 'Retiree', 'TrialPeriod', 'UpTo1Year', 'UpTo2Years', 'UpTo3Years', 'UpTo4Years', 'UpTo5Years'
# 'Rating'                             'A', 'AA', 'B', 'C', 'D', 'E', 'F', 'HR'
# 'target'                             'Current', 'Late', 'Repaid'
# 'ActiveLateCategory'                 '1-7', '121-150', '151-180', '16-30', '180+', '31-60', '61-90', '8-15', '91-120'
# 'WorseLateCategory'                  '1-7', '121-150', '151-180', '16-30', '180+', '31-60', '61-90', '8-15', '91-120'
# 'CreditScoreEsMicroL'                'M', 'M1', 'M10', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9'
# 'ActiveLateLastPaymentCategory'      '1-7', '121-150', '151-180', '16-30', '180+', '31-60', '61-90', '8-15', '91-120'

# %% [markdown]
# ## Task 3 - Check Anomalies in Validation Dataset

# %% [markdown]
# ### 3.a) Generate Statistics for Validation Data

# %%
val_stats = tfdv.generate_statistics_from_dataframe(df_val, stats_options=options_train)

# get the number of features used to compute statistics
print(f"Number of features used: {len(val_stats.datasets[0].features)}")

# check the number of examples used
print(f"Number of examples used: {val_stats.datasets[0].num_examples}")

# check the column names of the first and last feature
print(f"First feature: {val_stats.datasets[0].features[0].path.step[0]}")
print(f"Last feature: {val_stats.datasets[0].features[-1].path.step[0]}")
# Out:
# Number of features used: 81
# Number of examples used: 17923
# First feature: NewCreditCustomer
# Last feature: ActiveLateLastPaymentCategory

# %% [markdown]
# ### 3.b) Compare Validation with Training Statistics

# %%
tfdv.visualize_statistics(lhs_statistics=val_stats, rhs_statistics=train_stats,
                          lhs_name='VAL_DATASET', rhs_name='TRAIN_DATASET')
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %% [markdown]
# ### 3.c) Detect Anomalies

# %%
val_anomalies = tfdv.validate_statistics(statistics=val_stats, schema=dataset_schema)
tfdv.display_anomalies(val_anomalies)
# Out:
# /home/tensorflowml/appdev/lib/python3.8/site-packages/tensorflow_data_validation/utils/display_util.py:217: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('max_colwidth', -1)
# <h4 style="color:green;">No anomalies found.</h4>

# %% [markdown]
# ### 3.d) Fix Validation Data Anomalies in Schema

# %%
# Not applicable in this iteration of the data validation exercise

# %% [markdown]
# ## Task 4 - Check Anomalies in Test Dataset

# %% [markdown]
# ### 4.a) Generate Statistics for Test Data

# %%
# Define a new statistics options by the tfdv.StatsOptions class for the serving data by passing the previously inferred schema
options_test = tfdv.StatsOptions(schema=dataset_schema, infer_type_from_schema=True, feature_allowlist=features_to_keep)

# %%
# Generate serving dataset statistics
test_stats = tfdv.generate_statistics_from_dataframe(df_test, stats_options=options_test)

# get the number of features used to compute statistics
print(f"Number of features used: {len(test_stats.datasets[0].features)}")

# check the number of examples used
print(f"Number of examples used: {test_stats.datasets[0].num_examples}")

# check the column names of the first and last feature
print(f"First feature: {test_stats.datasets[0].features[0].path.step[0]}")
print(f"Last feature: {test_stats.datasets[0].features[-1].path.step[0]}")
# Out:
# Number of features used: 80
# Number of examples used: 17924
# First feature: NewCreditCustomer
# Last feature: ActiveLateLastPaymentCategory

# %% [markdown]
# ### 4.b) Compare Test with Training Statistics

# %%
test_anomalies = tfdv.validate_statistics(statistics=test_stats, schema=dataset_schema)
tfdv.display_anomalies(test_anomalies)
# Out:
#              Anomaly short description      Anomaly long description
# Feature name
# 'target'      Column dropped            Column is completely missing

# %% [markdown]
# ### 4.c) Fix Test Data Anomalies in Schema

# %%
# Not applicable in this iteration of the data validation exercise

# %% [markdown]
# ### 4.d) Organize Schema based on Environment

# %%
# All features are by default in both TRAINING and SERVING environments.
dataset_schema.default_environment.append('TRAINING')
dataset_schema.default_environment.append('TESTING')

# %%
# Specify that 'target' feature is not in TEST environment.
tfdv.get_feature(dataset_schema, 'target').not_in_environment.append('TESTING')

# Re-calculate and re-display anomalies with the new environment parameters
test_anomalies = tfdv.validate_statistics(statistics=test_stats, schema=dataset_schema, environment='TESTING')
tfdv.display_anomalies(test_anomalies)
# Out:
# /home/tensorflowml/appdev/lib/python3.8/site-packages/tensorflow_data_validation/utils/display_util.py:217: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('max_colwidth', -1)
# <h4 style="color:green;">No anomalies found.</h4>

# %% [markdown]
# ## Task 5 - Check for Data Drift and Skew

# %%
# Not applicable in this iteration of the data validation exercise

# %% [markdown]
# ## Task 6 - Display Stats for Data Slices

# %%
def split_datasets(dataset_list):
    '''
    split datasets.

            Parameters:
                    dataset_list: List of datasets to split

            Returns:
                    datasets: sliced data
    '''
    datasets = []
    for dataset in dataset_list.datasets:
        proto_list = DatasetFeatureStatisticsList()
        proto_list.datasets.extend([dataset])
        datasets.append(proto_list)
    return datasets

# %%
def display_stats_at_index(index, datasets):
    '''
    display statistics at the specified data index

            Parameters:
                    index : index to show the anomalies
                    datasets: split data

            Returns:
                    display of generated sliced data statistics at the specified index
    '''
    if index < len(datasets):
        print(datasets[index].datasets[0].name)
        tfdv.visualize_statistics(datasets[index])

# %%
def sliced_stats_for_slice_fn(slice_fn, approved_cols, dataframe, schema):
    '''
    generate statistics for the sliced data.

            Parameters:
                    slice_fn : slicing definition
                    approved_cols: list of features to pass to the statistics options
                    dataframe: pandas dataframe to slice
                    schema: the schema

            Returns:
                    slice_info_datasets: statistics for the sliced dataset
    '''
    # Set the StatsOptions
    slice_stats_options = tfdv.StatsOptions(schema=schema,
                                            slice_functions=[slice_fn],
                                            infer_type_from_schema=True,
                                            feature_allowlist=approved_cols)
    
    # Convert Dataframe to CSV since `slice_functions` works only with `tfdv.generate_statistics_from_csv`
    CSV_PATH = 'slice_sample.csv'
    dataframe.to_csv(CSV_PATH)
    
    # Calculate statistics for the sliced dataset
    sliced_stats = tfdv.generate_statistics_from_csv(CSV_PATH, stats_options=slice_stats_options)
    
    # Split the dataset using the previously defined split_datasets function
    slice_info_datasets = split_datasets(sliced_stats)
    
    return slice_info_datasets

# %%
# # Generate slice function for one of the features
# slice_fn = slicing_util.get_feature_value_slicer(features={'NewCreditCustomer': None})

# # Generate stats for the sliced dataset
# slice_datasets = sliced_stats_for_slice_fn(slice_fn, features_to_keep, dataframe=df_train, schema=dataset_schema)

# # Print name of slices for reference
# print(f'Statistics generated for:\n')
# print('\n'.join([sliced.datasets[0].name for sliced in slice_datasets]))

# # Display at index 1 as an example
# display_stats_at_index(1, slice_datasets)

# %% [markdown]
# ## Task 7 - Finalize the Schema

# %%
# Create output directory
OUTPUT_DIR = "output"
file_io.recursive_create_dir(OUTPUT_DIR)

# Use TensorFlow text output format pbtxt to store the schema
schema_file = os.path.join(OUTPUT_DIR, 'schema.pbtxt')

# write_schema_text function expect the defined schema and output path as parameters
tfdv.write_schema_text(dataset_schema, schema_file)

# %%
print ('Total time for the script:',(datetime.now() - start_time_script))
# Out:
# Total time for the script: 0:00:42.161264
